# %%
df = spark.read.csv('/Users/zhujinghong/Downloads/5003\ project/pre_data/US_pre.csv',header=True)

# %%
df.cache()
# Out:
# DataFrame[category_id: string, trending_date: string, title: string, channel_title: string, publish_time: string, tags: string, views: string, likes: string, dislikes: string, comment_count: string, category_title: string]

# %%
df.printSchema()
# Out:
# root
#  |-- category_id: string (nullable = true)
#  |-- trending_date: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- publish_time: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- views: string (nullable = true)
#  |-- likes: string (nullable = true)
#  |-- dislikes: string (nullable = true)
#  |-- comment_count: string (nullable = true)
#  |-- category_title: string (nullable = true)

# %%
from pyspark.sql.functions import col , column
cols=['category_id','views','likes','dislikes','comment_count']
for col in cols:
    df=df.withColumn('%s'%col ,df[col].cast('int'))

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
import pyspark.sql.functions as f
import os

# %%
# dataframe需要先注册成是一个Table或者View才能继续用SQL语言处理
df.createOrReplaceTempView("df")

# %% [markdown]
# ### preprocessing of category_title

# %%
# category_title存在null：原因category_id=29不存在
df.select('category_title').distinct().show()
df.select('category_title').distinct().count()
df.select('category_title','category_id').filter(f.isnull('category_title')).show()
# Out:
# +--------------------+
# |      category_title|
# +--------------------+
# |               Shows|
# |           Education|
# |              Gaming|
# |       Entertainment|
# |     Travel & Events|
# |Science & Technology|
# |              Sports|
# |       Howto & Style|
# |Nonprofits & Acti...|
# |    Film & Animation|
# |      People & Blogs|
# |     News & Politics|
# |      Pets & Animals|
# |    Autos & Vehicles|
# |               Music|
# |              Comedy|
# +--------------------+
#
# +--------------+-----------+
# |category_title|category_id|
# +--------------+-----------+
# +--------------+-----------+

# %%
df.count()
# Out:
# 40898

# %%
df.filter(df["category_title"]!='').count()
# Out:
# 40898

# %%
df=df.filter(df["category_title"]!='')

# %%
df.createOrReplaceTempView("df")

# %% [markdown]
# # Analysis

# %% [markdown]
# ### channel_title

# %%
# the most popular channel_title
channel = spark.sql("SELECT channel_title, COUNT(*) as freq FROM df GROUP BY channel_title ORDER BY freq DESC")
channel.show(10, False)
# Out:
# +--------------------------------------+----+
# |channel_title                         |freq|
# +--------------------------------------+----+
# |ESPN                                  |202 |
# |The Tonight Show Starring Jimmy Fallon|197 |
# |Netflix                               |193 |
# |TheEllenShow                          |192 |
# |Vox                                   |192 |
# |The Late Show with Stephen Colbert    |187 |
# |Jimmy Kimmel Live                     |185 |
# |Late Night with Seth Meyers           |183 |
# |Screen Junkies                        |182 |
# |NBA                                   |181 |
# +--------------------------------------+----+
# only showing top 10 rows

# %%
# Top popular channel_title every day
cha_day = spark.sql("SELECT trending_date, channel_title, COUNT(*) as freq FROM df GROUP BY trending_date, channel_title ORDER BY freq DESC")
cha_day.show()
# Out:
# +-------------+--------------------+----+
# |trending_date|       channel_title|freq|
# +-------------+--------------------+----+
# |     18.15.05|Kurzgesagt – In a...|   2|
# |     18.15.05|       New Amsterdam|   2|
# |     18.22.03|       Kensuke Koike|   1|
# |     18.18.03|            The View|   1|
# |     18.31.03|     Great Big Story|   1|
# |     18.08.06|   Jimmy Kimmel Live|   1|
# |     17.22.11|        RealLifeLore|   1|
# |     18.15.05|    Marques Brownlee|   1|
# |     18.18.02|          Bill Gates|   1|
# |     18.24.05|        TheEllenShow|   1|
# |     18.16.01|                 NFL|   1|
# |     18.30.03|         Matt Stonie|   1|
# |     18.22.05|    Lucas and Marcus|   1|
# |     18.29.04|                 FBE|   1|
# |     18.13.06|        Dude Perfect|   1|
# |     17.25.12|            wdwmagic|   1|
# |     18.18.02| Half as Interesting|   1|
# |     18.28.02|        JamesBayVEVO|   1|
# |     18.04.06|       BuzzFeedVideo|   1|
# |     18.05.02| Philadelphia Eagles|   1|
# +-------------+--------------------+----+
# only showing top 20 rows

# %%
# Average comment_count by channel_title
avg_comment = spark.sql(
    "SELECT channel_title, AVG(comment_count)as avg_comment FROM df GROUP BY channel_title ORDER BY avg_comment DESC")
avg_comment.show()
# Out:
# +-------------------+------------------+
# |      channel_title|       avg_comment|
# +-------------------+------------------+
# |   Logan Paul Vlogs|         619598.75|
# |ChildishGambinoVEVO|         406051.56|
# |            ibighit|          397718.3|
# |  YouTube Spotlight| 360841.8888888889|
# |       David Dobrik|297095.44444444444|
# |     The ACE Family|190508.55555555556|
# |TheAngryGrandpaShow|        164311.375|
# |        Collins Key|         143776.25|
# |   jypentertainment|      118367.34375|
# |       Call of Duty|103034.87804878049|
# |          Manny Mua|          101972.5|
# |   ArianaGrandeVevo| 99891.46511627907|
# |        Dwarf Mamba|           96720.5|
# |      LuisFonsiVEVO|           95342.7|
# |        jeffreestar| 79203.52631578948|
# |       Desimpedidos|           78330.0|
# |  Алексей Навальный|           77462.0|
# |CJENMMUSIC Official| 76064.36363636363|
# |        TheOdd1sOut| 73067.71428571429|
# |         EminemVEVO|           71878.0|
# +-------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### category_title

# %%
# the number of category_title
distinct_ct = spark.sql("SELECT COUNT(DISTINCT(category_title)) FROM df")
distinct_ct.show()
# Out:
# +------------------------------+
# |count(DISTINCT category_title)|
# +------------------------------+
# |                            16|
# +------------------------------+

# %%
# 1-1 Top 10 category_title
top_cat = spark.sql("SELECT category_title, COUNT(*) as freq FROM df GROUP BY category_title ORDER BY freq DESC")
top_cat.show(10)
# Out:
# +--------------------+----+
# |      category_title|freq|
# +--------------------+----+
# |       Entertainment|9944|
# |               Music|6467|
# |       Howto & Style|4142|
# |              Comedy|3453|
# |      People & Blogs|3208|
# |     News & Politics|2485|
# |Science & Technology|2397|
# |    Film & Animation|2342|
# |              Sports|2170|
# |           Education|1655|
# +--------------------+----+
# only showing top 10 rows

# %%
# 1-2 Top popular category_title every day
top_cat_day = spark.sql("SELECT trending_date, category_title, COUNT(*) as freq FROM df GROUP BY trending_date, category_title ORDER BY freq DESC")
top_cat_day.show()
# Out:
# +-------------+--------------+----+
# |trending_date|category_title|freq|
# +-------------+--------------+----+
# |     18.14.05| Entertainment|  61|
# |     18.27.03| Entertainment|  60|
# |     18.26.03| Entertainment|  60|
# |     18.24.05| Entertainment|  59|
# |     18.28.03| Entertainment|  59|
# |     17.18.12| Entertainment|  59|
# |     18.25.03| Entertainment|  59|
# |     18.22.05| Entertainment|  59|
# |     18.25.05| Entertainment|  58|
# |     18.08.05| Entertainment|  58|
# |     18.04.04| Entertainment|  58|
# |     18.11.05| Entertainment|  58|
# |     18.05.04| Entertainment|  57|
# |     17.15.12| Entertainment|  57|
# |     18.09.05| Entertainment|  57|
# |     18.16.05| Entertainment|  57|
# |     18.29.03| Entertainment|  57|
# |     18.17.05| Entertainment|  57|
# |     18.06.05| Entertainment|  57|
# |     18.07.05| Entertainment|  57|
# +-------------+--------------+----+
# only showing top 20 rows

# %%
# 2-1 Average views count by category_title
avg_views = spark.sql(
    "SELECT category_title, AVG(views)as avg_views FROM df GROUP BY category_title ORDER BY avg_views DESC")
avg_views.show()
# Out:
# +--------------------+------------------+
# |      category_title|         avg_views|
# +--------------------+------------------+
# |               Music|  6204776.02304005|
# |    Film & Animation| 3103216.127241674|
# |Nonprofits & Acti...|2963884.0701754387|
# |              Gaming|2607597.7708333335|
# |       Entertainment| 2067689.247988737|
# |              Sports|2029128.4059907834|
# |      People & Blogs|1530550.0822942643|
# |              Comedy|1480239.3831450911|
# |Science & Technology|1449087.5064664164|
# |    Autos & Vehicles|1355965.4088541667|
# |       Howto & Style| 982861.3882182521|
# |               Shows| 903527.3333333334|
# |     Travel & Events| 855612.4912718205|
# |      Pets & Animals| 831143.4663043479|
# |           Education|  713097.177039275|
# |     News & Politics|  592792.951307847|
# +--------------------+------------------+

# %%
# 2-2 Average likes count by category_title
avg_likes = spark.sql(
    "SELECT category_title, AVG(likes)as avg_likes FROM df GROUP BY category_title ORDER BY avg_likes DESC")
avg_likes.show()
# Out:
# +--------------------+------------------+
# |      category_title|         avg_likes|
# +--------------------+------------------+
# |Nonprofits & Acti...|259923.61403508772|
# |               Music|219046.34931189113|
# |              Gaming| 84288.68137254902|
# |    Film & Animation| 70708.76473099914|
# |              Comedy|62593.776426295975|
# |      People & Blogs| 58089.25654613466|
# |       Entertainment|53221.361625100566|
# |              Sports| 45444.66036866359|
# |       Howto & Style|    39236.09150169|
# |Science & Technology| 34315.81518564873|
# |           Education|29757.073716012084|
# |      Pets & Animals| 21055.11086956522|
# |               Shows|18993.666666666668|
# |     Travel & Events|12034.127182044887|
# |    Autos & Vehicles|11056.395833333334|
# |     News & Politics| 7298.667605633803|
# +--------------------+------------------+

# %%
# 2-3 Average dislikes count by category_title
avg_dislikes = spark.sql(
    "SELECT category_title, AVG(dislikes)as avg_dislikes FROM df GROUP BY category_title ORDER BY avg_dislikes DESC")
avg_dislikes.show()
# Out:
# +--------------------+------------------+
# |      category_title|      avg_dislikes|
# +--------------------+------------------+
# |Nonprofits & Acti...| 58076.85964912281|
# |              Gaming|11227.525735294117|
# |               Music| 7912.998917581568|
# |       Entertainment| 4314.622184231697|
# |      People & Blogs|3172.9625935162094|
# |    Film & Animation|2592.2818104184457|
# |              Sports|2365.2981566820276|
# |              Comedy| 2090.931364031277|
# |Science & Technology|1890.6545682102628|
# |     News & Politics| 1681.887726358149|
# |       Howto & Style|1318.7595364558185|
# |     Travel & Events| 848.1047381546134|
# |           Education| 816.7021148036254|
# |    Autos & Vehicles| 632.8385416666666|
# |      Pets & Animals| 573.2380434782609|
# |               Shows|429.96491228070175|
# +--------------------+------------------+

# %% [markdown]
# #### Create df1: trending_date->year, month

# %%
from pyspark.sql.functions import split, explode, concat
df = df.withColumn('trending_date' ,df['trending_date'].cast('string'))
# year
df1 = df.withColumn("date", split(df['trending_date'],''))\
        .withColumn("date", concat(f.col("date")[0], f.col("date")[1]))\
        .withColumnRenamed('date','year')
df1.printSchema()
# Out:
# root
#  |-- category_id: integer (nullable = true)
#  |-- trending_date: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- publish_time: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- views: integer (nullable = true)
#  |-- likes: integer (nullable = true)
#  |-- dislikes: integer (nullable = true)
#  |-- comment_count: integer (nullable = true)
#  |-- category_title: string (nullable = true)
#  |-- year: string (nullable = true)

# %%
# month
df1 = df1.withColumn("date", split(df['trending_date'],''))\
         .withColumn("date", concat(f.col("date")[6], f.col("date")[7]))\
         .withColumnRenamed('date','month')
df1.printSchema()
# Out:
# root
#  |-- category_id: integer (nullable = true)
#  |-- trending_date: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- publish_time: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- views: integer (nullable = true)
#  |-- likes: integer (nullable = true)
#  |-- dislikes: integer (nullable = true)
#  |-- comment_count: integer (nullable = true)
#  |-- category_title: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- month: string (nullable = true)

# %%
df1.createOrReplaceTempView("df1")

# %%
# Top popular category title in every year
top_cat_year = spark.sql("SELECT year, category_title, COUNT(*) as freq FROM df1 GROUP BY year, category_title ORDER BY freq DESC")
top_cat_year.show()
# Out:
# +----+--------------------+----+
# |year|      category_title|freq|
# +----+--------------------+----+
# |  18|       Entertainment|7605|
# |  18|               Music|4904|
# |  18|       Howto & Style|3263|
# |  18|              Comedy|2559|
# |  18|      People & Blogs|2443|
# |  17|       Entertainment|2339|
# |  18|Science & Technology|1871|
# |  18|    Film & Animation|1808|
# |  18|     News & Politics|1717|
# |  18|              Sports|1697|
# |  17|               Music|1563|
# |  18|           Education|1293|
# |  17|              Comedy| 894|
# |  17|       Howto & Style| 879|
# |  17|     News & Politics| 768|
# |  17|      People & Blogs| 765|
# |  18|      Pets & Animals| 737|
# |  18|              Gaming| 731|
# |  17|    Film & Animation| 534|
# |  17|Science & Technology| 526|
# +----+--------------------+----+
# only showing top 20 rows

# %%
top_cat_year.filter(top_cat_year['year']=='17').show()
top_cat_year.filter(top_cat_year['year']=='18').show()
# Out:
# +----+--------------------+----+
# |year|      category_title|freq|
# +----+--------------------+----+
# |  17|       Entertainment|2339|
# |  17|               Music|1563|
# |  17|              Comedy| 894|
# |  17|       Howto & Style| 879|
# |  17|     News & Politics| 768|
# |  17|      People & Blogs| 765|
# |  17|    Film & Animation| 534|
# |  17|Science & Technology| 526|
# |  17|              Sports| 473|
# |  17|           Education| 362|
# |  17|      Pets & Animals| 183|
# |  17|    Autos & Vehicles| 105|
# |  17|     Travel & Events| 101|
# |  17|              Gaming|  85|
# |  17|Nonprofits & Acti...|  14|
# |  17|               Shows|   9|
# +----+--------------------+----+
#
# +----+--------------------+----+
# |year|      category_title|freq|
# +----+--------------------+----+
# |  18|       Entertainment|7605|
# |  18|               Music|4904|
# |  18|       Howto & Style|3263|
# |  18|              Comedy|2559|
# |  18|      People & Blogs|2443|
# |  18|Science & Technology|1871|
# |  18|    Film & Animation|1808|
# |  18|     News & Politics|1717|
# |  18|              Sports|1697|
# |  18|           Education|1293|
# |  18|      Pets & Animals| 737|
# |  18|              Gaming| 731|
# |  18|     Travel & Events| 300|
# |  18|    Autos & Vehicles| 279|
# |  18|               Shows|  48|
# |  18|Nonprofits & Acti...|  43|
# +----+--------------------+----+

# %%
# Top popular category title in 2017 and 2018
df2 = df1.filter(df1['year']=='17')
df3 = df1.filter(df1['year']=='18')
df2.createOrReplaceTempView("df2") 
df3.createOrReplaceTempView("df3")

# %%
# 2017
top_cat_month_17 = spark.sql("SELECT month, category_title,\
                              COUNT(*) as freq FROM df2 GROUP BY month,\
                              category_title ORDER BY freq DESC")
top_cat_month_17.show()
# Out:
# +-----+--------------------+----+
# |month|      category_title|freq|
# +-----+--------------------+----+
# |   12|       Entertainment|1549|
# |   12|               Music| 950|
# |   11|       Entertainment| 790|
# |   11|               Music| 613|
# |   12|              Comedy| 579|
# |   12|       Howto & Style| 560|
# |   12|     News & Politics| 547|
# |   12|      People & Blogs| 518|
# |   12|    Film & Animation| 360|
# |   11|       Howto & Style| 319|
# |   11|              Comedy| 315|
# |   12|Science & Technology| 289|
# |   12|              Sports| 278|
# |   11|      People & Blogs| 247|
# |   11|Science & Technology| 237|
# |   12|           Education| 224|
# |   11|     News & Politics| 221|
# |   11|              Sports| 195|
# |   11|    Film & Animation| 174|
# |   11|           Education| 138|
# +-----+--------------------+----+
# only showing top 20 rows

# %%
# 2017.12
top_cat_month_17.select('*').filter(top_cat_month_17['month']=='12').show()
# Out:
# +-----+--------------------+----+
# |month|      category_title|freq|
# +-----+--------------------+----+
# |   12|       Entertainment|1549|
# |   12|               Music| 950|
# |   12|              Comedy| 579|
# |   12|       Howto & Style| 560|
# |   12|     News & Politics| 547|
# |   12|      People & Blogs| 518|
# |   12|    Film & Animation| 360|
# |   12|Science & Technology| 289|
# |   12|              Sports| 278|
# |   12|           Education| 224|
# |   12|      Pets & Animals| 127|
# |   12|     Travel & Events|  76|
# |   12|              Gaming|  63|
# |   12|    Autos & Vehicles|  58|
# |   12|Nonprofits & Acti...|  13|
# |   12|               Shows|   9|
# +-----+--------------------+----+

# %%
# 2018
top_cat_month_18 = spark.sql("SELECT month, category_title, COUNT(*) as freq FROM df3 GROUP BY month, category_title ORDER BY freq DESC")
top_cat_month_18.show()
# Out:
# +-----+---------------+----+
# |month| category_title|freq|
# +-----+---------------+----+
# |   05|  Entertainment|1681|
# |   03|  Entertainment|1537|
# |   01|  Entertainment|1288|
# |   02|  Entertainment|1243|
# |   04|  Entertainment|1160|
# |   05|          Music|1116|
# |   03|          Music| 810|
# |   03|  Howto & Style| 810|
# |   02|          Music| 777|
# |   01|          Music| 758|
# |   04|          Music| 747|
# |   06|          Music| 696|
# |   06|  Entertainment| 696|
# |   05|  Howto & Style| 613|
# |   04|  Howto & Style| 557|
# |   01|  Howto & Style| 551|
# |   03|         Comedy| 524|
# |   02|News & Politics| 521|
# |   03| People & Blogs| 508|
# |   05|         Comedy| 506|
# +-----+---------------+----+
# only showing top 20 rows

# %%
# 2018.05
top_cat_month_18.select('*').filter(top_cat_month_18['month']=='05').show()
# Out:
# +-----+--------------------+----+
# |month|      category_title|freq|
# +-----+--------------------+----+
# |   05|       Entertainment|1681|
# |   05|               Music|1116|
# |   05|       Howto & Style| 613|
# |   05|              Comedy| 506|
# |   05|      People & Blogs| 399|
# |   05|    Film & Animation| 353|
# |   05|Science & Technology| 332|
# |   05|              Sports| 330|
# |   05|     News & Politics| 274|
# |   05|           Education| 206|
# |   05|              Gaming| 179|
# |   05|      Pets & Animals| 101|
# |   05|     Travel & Events|  28|
# |   05|               Shows|  19|
# |   05|    Autos & Vehicles|   9|
# |   05|Nonprofits & Acti...|   5|
# +-----+--------------------+----+

# %% [markdown]
# ### title_length

# %%
from pyspark.sql.types import StringType, DoubleType, IntegerType, StructField, StructType
titleLength = spark.sql("SELECT title as title from df")\
                   .rdd.map(lambda x: list(x)).flatMap(lambda x: x)\
                   .map(lambda x: (x,len(x))).reduceByKey(lambda a,b:a)\
                   .repartition(1).sortBy(lambda x:x[1],False)
titleLengthSchema = StructType([StructField("Title", StringType(), True),\
                                StructField("Length", IntegerType(), True)])                                                           
titleLengthDF = spark.createDataFrame(titleLength, titleLengthSchema)
titleLengthDF = titleLengthDF.filter(titleLengthDF["Title"]!='')
titleLengthDF.collect()
# Out:
# [Row(Title="Stephen A.: Cavs 'were an absolute disgrace' in 2nd half of Game 2 vs. Celtics | SportsCenter | ESPN", Length=100),
#  Row(Title='The epic late-night Fortnite stream featuring Drake, JuJu Smith-Schuster, Ninja, Travis Scott | ESPN', Length=100),
#  Row(Title='Stephen A.: Kevin Durant looked like he wanted no part of LeBron James in Game 1 | First Take | ESPN', Length=100),
#  Row(Title='Patrick Beverley calls in to tell Will he knows nothing about basketball | The Will Cain Show | ESPN', Length=100),
#  Row(Title='Boxing with Evander Holyfield & Joel McHale | Kevin Hart: What The Fit Ep 8 | Laugh Out Loud Network', Length=100),
#  Row(Title='Ronaldo knocks out Juventus with last minute penalty kick | 2017-18 UEFA Champions League Highlights', Length=100),
#  Row(Title='Anthony Davis 53 Pts, 17 Rebs, 5 Blks! 2018.02.26 New Orleans Pelicans vs Phoenix Suns | FreeDawkins', Length=100),
#  Row(Title='The Twelfth Doctor Regenerates: Peter Capaldi to Jodie Whittaker - Doctor Who Christmas Special 2017', Length=100),
#  Row(Title='Revlon Live Boldly | Anthem with Ashley Graham, Adwoa Aboah, Imaan Hammam, Raquel Zimmerman | Revlon', Length=100),
#  Row(Title='PART 1 | Gwen Stefani with Blake Shelton | Instagram | December 24, 2017 | Christmas Eve with family', Length=100),
#  Row(Title='Black Panther Cast Touches a Chameleon, a Guinea Pig, and Other Weird Stuff | Fear Box | Vanity Fair', Length=100),
#  Row(Title='INDIAN STREET FOOD of YOUR DREAMS in Kolkata, India | ENTER CURRY HEAVEN + BEST STREET FOOD in India', Length=100),
#  Row(Title='LeBron James admits he was ripping Phil Jackson and thinks DeShaun Watson should be the Browns qu...', Length=100),
#  Row(Title="Allen Iverson on Thunder's playoff struggles: They need to make something happen | First Take | ESPN", Length=100),
#  Row(Title="Canada Soccer's Women's National Team v USA International Friendly LIVE from Avaya Stadium, San Jose", Length=100),
#  Row(Title="Fifth Harmony’s Normani Kordei Performs 'Bootylicious' by Destiny's Child  | Lip Sync Battle Preview", Length=100),
#  Row(Title='Stephen A. sides with Reggie Miller: Magic Johnson should speak up on LaVar Ball | First Take | ESPN', Length=100),
#  Row(Title="Comedian Tig Notaro Says It's A 'Huge Relief' Louis CK Was 'Removed' From Comedy Industry | The View", Length=100),
#  Row(Title='Amazon CEO Jeff Bezos and brother Mark give a rare interview about growing up and secrets to success', Length=100),
#  Row(Title='Ben Simmons does something on defense vs LeBron James that we almost never see | SportsCenter | ESPN', Length=100),
#  Row(Title='U2: Live in der Berliner U-Bahnlinie U2: „Get Out Of Your Own Way“, „Sunday Bloody Sunday“ und „One“', Length=100),
#  Row(Title='Rony Abovitz, founder of Magic Leap, and Adam Silver, NBA Commissioner | Full interview | Code Media', Length=100),
#  Row(Title="Jeffrey Tambor Fired From 'Transparent' Following Amazon Investigation Into Sexual Misconduct Allega", Length=100),
#  Row(Title="I tried to recreate my favorite artist's work with makeup | Alex Pardee Inspired Bodypaint Tutorial", Length=99),
#  Row(Title='Amtrak Train Carrying Republican Lawmakers To A Retreat Hits Garbage Truck | Velshi & Ruhle | MSNBC', Length=99),
#  Row(Title='Police Just Found A Missing Texas Reporter Who Said She Was Being Followed By Suspicious Man | TIME', Length=99),
#  Row(Title='Ramsay Shuts Down Restaurant After Finding RAW Chicken Next to Cooked Chicken! | Kitchen Nightmares', Length=99),
#  Row(Title="Hear what Nick Saban, Tua Tagovailoa, & Da'Ron Payne said following Alabama's epic win over Georgia", Length=99),
#  Row(Title='CNN’s Alisyn Camerota Confronts Literal Nazi Running For GOP Congressional Seat in Insane Interview', Length=99),
#  Row(Title='Margot Robbie HEART RATE MONITOR ft. Cara Delevingne, Alexander Skarsgård & Bullet For My Valentine', Length=99),
#  Row(Title='Shawn Mendes - Lost in Japan - Choreography by Jake Kodish ft Sean Lew, Kaycee Rice, Jade Chynoweth', Length=99),
#  Row(Title='Live It Up (Official Video) - Nicky Jam feat. Will Smith & Era Istrefi (2018 FIFA World Cup Russia)', Length=99),
#  Row(Title='Star Wars The Last Jedi Scores An A Cinemascore And 2nd Largest Opening Ever - The John Campea Show', Length=99),
#  Row(Title="Timothée Chalamet Donates Woody Allen Movie Salary To Time's Up | News Flash | Entertainment Weekly", Length=99),
#  Row(Title='The Last Jedi Cast Answers YOUR Questions, Behind the Scenes of the Red Carpet Live Stream, & More!', Length=99),
#  Row(Title="A janitor's son is bullied by rich kids. So his dad stands up for him in the most heartwarming way.", Length=99),
#  Row(Title='How to use DeWalt Batteries on Ryobi Tools for $30 | Building a DeWalt to Ryobi Adapter - 42Fab #16', Length=99),
#  Row(Title="Christina Aguilera's Whitney Houston Tribute At AMAs Is Breathtaking | AMAs 2017 | Access Hollywood", Length=99),
#  Row(Title='Jalen shuts down Will saying Kevin Durant will surpass LeBron James this season | First Take | ESPN', Length=99),
#  Row(Title='#AboveTheNoise feat. Serena Williams, Neymar Jr., Cara Delevingne, Michael K. Williams, and Kris Wu', Length=99),
#  Row(Title="Stephen A. Smith: Warriors' Game 6 win vs. Rockets was an 'unbelievable show' | SportsCenter | ESPN", Length=99),
#  Row(Title='FULL COVERAGE?! New IT Cosmetics BYE BYE FOUNDATION [First Impression Review] 15 DAYS OF FOUNDATION', Length=99),
#  Row(Title="A social worker has the worst day of his life. Then, a homeless man shows him what 'bad' really is.", Length=99),
#  Row(Title='Will Ferrell Left Speechless as Mark Wahlberg Reveals He Has a Third Nipple! | Good Morning Britain', Length=99),
#  Row(Title='Philadelphia Eagles Super Bowl Parade 2018: MVP Nick Foles, team celebrate championship  | ABC News', Length=99),
#  Row(Title="'Lord of the Rings' TV Series Gets Multi-Season Order At Amazon | News Flash | Entertainment Weekly", Length=99),
#  Row(Title="Stephen A.: 'I'd be shocked' if Cavaliers win more than one game vs. Warriors | SportsCenter | ESPN", Length=99),
#  Row(Title='Aly Raisman On Dr. Larry Nassar’s Medical Treatment: I Didn’t Know It Was Abuse | Megyn Kelly TODAY', Length=99),
#  Row(Title="Kids Interview The 'Star Wars: The Last Jedi' Cast With Daisy Ridley, Mark Hamill & More | PeopleTV", Length=99),
#  Row(Title='Live It Up - Nicky Jam feat. Will Smith & Era Istrefi (2018 FIFA World Cup Russia) (Official Audio)', Length=99),
#  Row(Title='PANCAKE ART CHALLENGE 4!!! Learn How To Make Mario Odyssey Star Wars Jedi Nintendo Food DIY Pancake', Length=99),
#  Row(Title='Mirai Nagasu Makes History As The First American Woman To Land A Triple Axel At The Olympics | TIME', Length=99),
#  Row(Title='Justice League | “Come Together” | Todrick Hall, J.Fla, Mario Bautista, Samantha Harvey, Clara Marz', Length=99),
#  Row(Title='Tom Brady Hangs Up On Boston Radio Hosts After Insult About Daughter | SI Wire | Sports Illustrated', Length=99),
#  Row(Title="'Call Me by Your Name' star Timothee Chalamet on the time he embarrassed himself with Saoirse Ronan", Length=99),
#  Row(Title='Marcellus Wiley has officially lost it after the Clippers trade Blake Griffin to the Pistons | ESPN', Length=99),
#  Row(Title='John Cena vs. Braun Strowman vs. Elias - Winner Enters Elimination Chamber Last: Raw, Feb. 5, 2018', Length=98),
#  Row(Title="RHOA: Kim Zolciak-Biermann Says Kenya Moore's Husband Doesn't Exist (Season 10, Episode 4) | Bravo", Length=98),
#  Row(Title='How To Make a CHINESE FRIED RICE TAKEOUT CAKE and FORTUNE COOKIES | Yolanda Gampp | How To Cake It', Length=98),
#  Row(Title="Zurcaroh: Golden Buzzer Worthy Aerial Dance Group Impresses Tyra Banks - America's Got Talent 2018", Length=98),
#  Row(Title='Full sequence: LeBron James blocks Victor Oladipo, hits game-winning 3 in Game 5 vs. Pacers | ESPN', Length=98),
#  Row(Title="'Riverdale' Season 2: Josie Takes Center Stage In The Upcoming 3 Part Episode | Sweetwater Secrets", Length=98),
#  Row(Title="Stephen A. shares theory on why Spurs' Kawhi Leonard isn't playing this season | First Take | ESPN", Length=98),
#  Row(Title="Maisie Williams HEART RATE MONITOR feat. Eddie Redmayne | GAME OF THRONES SEASON 8 'SPOILERS' (!?)", Length=98),
#  Row(Title='State of the Union 2018 live stream: President Donald Trump delivers first SOTU Address | ABC News', Length=98),
#  Row(Title='Kellyanne Conway on Roy Moore This Week Abc: Trump’s Not Being Briefed On This Bit By Bit 11/12/17', Length=98),
#  Row(Title="Stephen A. goes off on Kevin Durant: I don't want to hear you miss Steph Curry | First Take | ESPN", Length=98),
#  Row(Title='Some NFL players call for an end to Thursday night football after 8 players were injured last week', Length=98),
#  Row(Title='The Legend of Zelda: Breath of the Wild - Expansion Pass: DLC Pack 2 The Champions’ Ballad Trailer', Length=98),
#  Row(Title='EXTREME Mexican Street Food! BLOOD + CACTUS Tacos and SPICY Street Market TACO Tour in Mexico City', Length=98),
#  Row(Title='Donkey and Woman Who Both Lost Children Celebrate Their Emotional Journey | The Dodo Party Animals', Length=98),
#  Row(Title='Stephen A. speculates what LeBron James told Lonzo Ball after Lakers-Cavaliers | First Take | ESPN', Length=98),
#  Row(Title='Chris Brown , Cardi B , Lil Kim , Remy Ma , Yo Gotti Live Hot 97 Hot For The Holidays Concert 2017', Length=98),
#  Row(Title='Stephen A.: Kyrie Irving was tired of being treated like less than a superstar | First Take | ESPN', Length=98),
#  Row(Title="Rep. Nancy Pelosi (D-CA) finds out she's given the longest-continuous speech in the House (C-SPAN)", Length=98),
#  Row(Title='Stephen A. calls benching Malcolm Butler right before game classless and cruel | First Take | ESPN', Length=98),
#  Row(Title='First Take debates impact of Steph Curry and Kyrie Irving injuries on playoffs | First Take | ESPN', Length=98),
#  Row(Title='GOT Creators Making New Star Wars Films, Up Close with the Falcon, and YOUR Solo Teaser Reactions!', Length=98),
#  Row(Title='Bonus Scenes: LA Rams Push Kevin to the Limit | Kevin Hart: What The Fit | Laugh Out Loud Network', Length=97),
#  Row(Title='Cole Sprouse on Interning at the Met and His Artistic Aspirations | Met Gala 2018 With Liza Koshy', Length=97),
#  Row(Title='Marc Spelmann gets the first Golden Buzzer of 2018 | Auditions Week 1 | Britain’s Got Talent 2018', Length=97),
#  Row(Title='GOD LEVEL Street Food in Mexico - Sandwich NINJA with SUPER FAST Cutting Skills + Mexican Chicken', Length=97),
#  Row(Title='Queen Biopic Stops Production, Avengers Fighting Alien Cannon Fodder Again - The John Campea Show', Length=97),
#  Row(Title="Stephen A. hyped over Kevin Durant's Game 3: He was an absolute superstar | NBA at the Mic | ESPN", Length=97),
#  Row(Title="Stephen A. openly confesses why he's getting annoyed talking about Lonzo Ball | First Take | ESPN", Length=97),
#  Row(Title='Liza Koshy Touches a Bearded Dragon, Chinchilla & Other Weird Stuff in the Fear Box | Vanity Fair', Length=97),
#  Row(Title='Did Tyler Predict Khloe Kardashian’s Drama With Tristan? | Hollywood Medium with Tyler Henry | E!', Length=97),
#  Row(Title='Houston Rockets vs Minnesota Timberwolves - Full Game Highlights  | Game 3 | April 21, 2018 | NBA', Length=97),
#  Row(Title="Former Trump Adviser Rick Gates Is About To Plead Guilty In Robert Mueller's Investigation | TIME", Length=97),
#  Row(Title='Universal Studios For Celebration Of Harry Potter Expo 2018 | WB Studio Tour, Movie Props & More!', Length=97),
#  Row(Title="Le Batard grills MLB commish on Derek Jeter slashing Marlins' payroll | Dan Le Batard Show | ESPN", Length=97),
#  Row(Title="Saoirse Ronan on Harassment, Need to Know There's Support Here No Matter What | Close Up With THR", Length=97),
#  Row(Title='Harper Grace Auditions for American Idol With Down-home Original Tune - American Idol 2018 on ABC', Length=97),
#  Row(Title='Mexican STREET FOOD Tour in Oaxaca, Mexico | BEST Street Food in Mexico + HUGE Mexican Breakfast!', Length=97),
#  Row(Title='Sen. Kirsten Gillibrand Talks Allegations Against Steve Wynn, Calling For Al Franken To Step Down', Length=97),
#  Row(Title="Snoop Dogg Weighs In On Kanye's Controversial Comments, Friendship With Martha Stewart | The View", Length=97),
#  Row(Title="Rise of the TMNT Official Live Stream Character Art Reveal ft. Andre 'Black Nerd' & Kevin Eastman", Length=97),
#  Row(Title='D-Generation X and Scott Hall share a Too Sweet moment with The Bálor Club: Raw 25, Jan. 22, 2018', Length=97),
#  Row(Title='Sturm Friederike - Grandiose Pilotenleistung am Airport Düsseldorf bei bis zu 110 km/h Seitenwind', Length=97),
#  Row(Title='Footage of how Tom Cruise broke his ankle while filming his latest movie - The Graham Norton Show', Length=97),
#  Row(Title='Richard Jefferson and Tracy McGrady have strong reactions to Dwane Casey firing | The Jump | ESPN', Length=97),
#  Row(Title='Stephen A. hilariously goes off on Max for changing take on Pelicans-Warriors | First Take | ESPN', Length=97),
#  Row(Title='Olympian Simone Biles: Larry Nassar ‘Took A Part Of Me That I Can’t Get Back’ | Megyn Kelly TODAY', Length=97),
#  Row(Title='1899-1902 British Emergency Ration Field Service Oldest MRE Beef Eaten Survival Food Review Test', Length=96),
#  Row(Title='This Giant Kielbasa Helped a Michelin-starred Restaurant Start Buying Whole Animals — Prime Time', Length=96),
#  Row(Title="Black Panther's Director Ryan Coogler Breaks Down a Fight Scene | Notes on a Scene | Vanity Fair", Length=96),
#  Row(Title="Michael Ketterer: Father Of 6 Scores Golden Buzzer From Simon Cowell - America's Got Talent 2018", Length=96),
#  Row(Title='AMAZING CANADIAN FOOD | INSANELY HUGE Christmas Turkey DINNER FEAST and EGGS BREAKFAST in CANADA', Length=96),
#  Row(Title='Stephen A. has an announcement: 76ers are going to Eastern Conference Finals | First Take | ESPN', Length=96),
#  Row(Title='Royal Weddings, Then and Now: Princess Diana, Kate Middleton, and Meghan Markle | The New Yorker', Length=96),
#  Row(Title="Star Wars: The Last Jedi Cast on Carrie Fisher's Final Performance | E! Live from the Red Carpet", Length=96),
#  Row(Title='The Talk - Nicole Eggert Recounts Abuse Timeline by Scott Baio; Shares Co-Stars New Claims Filed', Length=96),
#  Row(Title='How Do South Koreans Feel About Joint Team With North Korea (Winter Olympics 2018)  | ASIAN BOSS', Length=96),
#  Row(Title='will.i.am’s Mother Wouldn’t Let Him Be In Michael Jackson’s Music Video | The Graham Norton Show', Length=96),
#  Row(Title='Ruby Riot, Liv Morgan & Sarah Logan emerge with a surprise attack: SmackDown LIVE, Nov. 21, 2017', Length=96),
#  Row(Title="Lily Marston’s Cozy, Gray-Toned Living & Dining Room Makeover | OMG We're Coming Over | Mr. Kate", Length=96),
#  Row(Title="J.T. Barrett cuts through the Wolverines' defense, Michigan leads to 14-7 | FOX COLLEGE FOOTBALL", Length=96),
#  Row(Title="Inside Zedd's $16 Million Mansion That Has a Skittles Machine | Open Door | Architectural Digest", Length=96),
#  Row(Title='Chloe Kim Eats Churros Made Especially For Her After Winning Gold At The Winter Olympics | TODAY', Length=96),
#  Row(Title='Star Wars: The Last Jedi Has Second Largest Opening Ever Amidst Mixed Fan Reactions - Movie Talk', Length=96),
#  Row(Title='Testing Nail Products from Wish Nails Remove Toes Hollow Nail Polish Peel-off Nails Wish Buy Now', Length=96),
#  Row(Title="Foudy reports on Mirai Nagasu's historic triple axel at Winter Olympics | Golic and Wingo | ESPN", Length=96),
#  Row(Title="Michelle Williams Recalls Being Mistaken for the Destiny's Child Singer at a Concert (Exclusive)", Length=96),
#  Row(Title='INDIAN STREET FOOD Tour DEEP in PUNJAB, INDIA | BEST STREET FOOD in INDIA and BEST CURRY HEAVEN!', Length=96),
#  Row(Title='Hamilton – “Wrote My Way Out” (Nas, Dave East, Lin-Manuel Miranda & Aloe Blacc) [Official Video]', Length=96),
#  Row(Title='Yale Graduation Speaker Breaks Up with Boyfriend During Speech | Rebecca Shaw and Ben Kronengold', Length=96),
#  Row(Title='Azealia Banks GOES OFF On Remy Ma For Saying The Female Rap Game Was Nothing Until She Came Home', Length=96),
#  Row(Title="Stephen A. on Cavaliers' NBA Finals Game 4: 'It was an embarrassing effort' | SC with SVP | ESPN", Length=96),
#  Row(Title='Are Critics What Killed Justice League? Sony Pay Too Much For Tarantino? - The John Campea Show', Length=95),
#  Row(Title='Parris Campbell takes the screen pass 57 yards to the house | Highlights | FOX COLLEGE FOOTBALL', Length=95),
#  Row(Title='Sumo Wrestling with Conan O’Brien | Kevin Hart: What The Fit Episode 1 | Laugh Out Loud Network', Length=95),
#  Row(Title='Rey Mysterio makes a shocking return in the Royal Rumble Match: Royal Rumble 2018 (WWE Network)', Length=95),
#  Row(Title="Margot Robbie: How Hollywood's Horrible Situation Brings Actresses Together | Close Up With THR", Length=95),
#  Row(Title='MAYWEATHER CHECKS DANA WHITE FOR USING NAME TO RENEW FOX DEAL; ENDS UFC RUMORS ONCE AND FOR ALL', Length=95),
#  Row(Title='Jet Packinski Touches a Hairless Rat, Rooster & Other Weird Stuff in the Fear Box | Vanity Fair', Length=95),
#  Row(Title='AJ Styles & Daniel Bryan warn Brock Lesnar about what awaits him: SmackDown LIVE, Nov. 14, 2017', Length=95),
#  Row(Title="Wanna Be Startin' Somethin' w/ the Stars! | Lip Sync Battle Live: A Michael Jackson Celebration", Length=95),
#  Row(Title='Molly Makes Egg-in-a-Hole Sandwich with Bacon and Cheddar | From the Test Kitchen | Bon Appétit', Length=95),
#  Row(Title="Stephen A. and Max debate Rockets' chances to beat Warriors in NBA playoffs | First Take | ESPN", Length=95),
#  Row(Title='Helping the Police Find a Gun Underwater to Solve a Criminal Case! (Metal Detecting Underwater)', Length=95),
#  Row(Title='The BIGGEST Moments From the 2018 Grammys: Kesha, Bruno Mars, Kendrick Lamar, & Hillary Clinton', Length=95),
#  Row(Title="MAYWEATHER REVEALS COMEBACK OFFER, FIGHTING IN UFC; POPPIN MAD SH*T: THERE'S ONLY ONE GOAT...ME", Length=95),
#  Row(Title='Joel Embiid on win over Clippers, scuffle with Willie Reed and using social media | NBA on ESPN', Length=95),
#  Row(Title='Meet Nathan Chen, the Figure Skater Who Brought Athleticism to Artistry | NYT - Winter Olympics', Length=95),
#  Row(Title='Teeny Weeny Challenge #3 How Small Can I Bake a Gingerbread House? How To Cook That Ann Reardon', Length=95),
#  Row(Title="West Ham's Josh Cullen loses tooth after kick to the face, plays on | 2017-18 FA Cup Highlights", Length=95),
#  Row(Title='Could Kevin Feige Save DC? Does Alita Battle Angel Look Great Or Terrible? The John Campea Show', Length=95),
#  Row(Title='President Donald Trump Pardons His First Thanksgiving Turkey At White House Ceremony | NBC News', Length=95),
#  Row(Title='How To Make a Easter GIANT PEEP CAKE | With Yellow Velvet Cake | Yolanda Gampp | How To Cake It', Length=95),
#  Row(Title='Jemele Hill Talks Tweets About Trump, National Anthem Protests, Suspension From ESPN | The View', Length=95),
#  Row(Title='NBA Countdown debates if Ben Simmons is the best all-around rookie ever | NBA Countdown | ESPN', Length=94),
#  Row(Title="Benjamin Glaze Auditions for American Idol With Nick Jonas' Levels - American Idol 2018 on ABC", Length=94),
#  Row(Title='7.3 Magnitude Earthquake Along Iraq-Iran Border Leaves At Least 400 Dead, 7,200 Injured | TIME', Length=94),
#  Row(Title='Idol EXPOSES Dark Side of KPOP | STORYTIME experiences with SCANDALS, Slave Contracts and more', Length=94),
#  Row(Title="Cardi B Talks Grammy Nomination, JAY-Z, Engagement at Clive Davis' Pre-Grammy Gala | Billboard", Length=94),
#  Row(Title='SPOILERS! The Twelfth Doctor Regenerates – Peter Capaldi to Jodie Whittaker - Doctor Who - BBC', Length=94),
#  Row(Title='Manhattan Express Big Apple Roller Coaster 4K 60FPS NYNY Las Vegas Hotel Casino Front Seat POV', Length=94),
#  Row(Title='Andre The Giant Official Trailer #2 ft. Vince McMahon, Hulk Hogan, Arnold Schwarzenegger | HBO', Length=94),
#  Row(Title='How To Make A THANKSGIVING ROAST HAM Out Of Pink Vanilla CAKE | Yolanda Gampp | How To Cake It', Length=94),
#  Row(Title='Stephen A. Smith: Dwane Casey rescued DeMar DeRozan by benching him Game 3 | First Take | ESPN', Length=94),
#  Row(Title='Stephen A. changes his mind: 76ers will beat Cavaliers to reach NBA Finals | First Take | ESPN', Length=94),
#  Row(Title="Alien Covenant Sequel Cancelled? Mark Hamill's Opinion Of The Last Jedi - The John Campea Show", Length=94),
#  Row(Title='AJ Styles reacts to the WWE Title Handicap Match at Royal Rumble: SmackDown LIVE, Jan. 9, 2018', Length=94),
#  Row(Title='Machine Gun Kelly, X Ambassadors & Bebe Rexha - Home (from Bright: The Album) [Official Audio]', Length=94),
#  Row(Title='Jaylen Brown delivers emotional press conference after losing his best friend | Boston Celtics', Length=94),
#  Row(Title='AJ Styles calls out Jinder Mahal for a WWE Championship Rematch: SmackDown LIVE, Nov. 21, 2017', Length=94),
#  Row(Title='WATCH LIVE: Florida Gov. Rick Scott announcing major action plan to keep Florida students safe', Length=94),
#  Row(Title='FBI Admits It Failed To Investigate Tip About Accused Florida School Shooter In January | TIME', Length=94),
#  Row(Title='Terry Crews - The Resurrection of Brooklyn Nine-Nine & Redefining Masculinity | The Daily Show', Length=94),
#  Row(Title="Tracy McGrady on Isaiah Thomas to the Lakers: He can't bring an ego with him | The Jump | ESPN", Length=94),
#  Row(Title="First Take reacts: Kyrie Irving says contract extension doesn't make sense | First Take | ESPN", Length=94),
#  Row(Title="LaVar Ball gets real during interview with ESPN before LiAngelo and LaMelo's first game | ESPN", Length=94),
#  Row(Title="Danny Masterson Fired From Netflix Series 'The Ranch' Amid Rape Allegations | Access Hollywood", Length=94),
#  Row(Title='NFL Star Antonio Brown Shows Off His Insane Mansion and Sneaker Collection On Complex Closets', Length=93),
#  Row(Title='Joel Embiid has a message for a certain someone after being named NBA All-Star starter | ESPN', Length=93),
#  Row(Title='Catie Turner Sings Once Upon a Dream From Sleeping Beauty - Disney Night - American Idol 2018', Length=93),
#  Row(Title="Groundhog Day 2018: Punxsutawney Phil's winter prediction live from Gobbler's Knob | ABC News", Length=93),
#  Row(Title="MY 98 YEAR OLD DAD'S REACTION WHEN HE FINDS OUT HOW OLD HE REALLY IS! (WARNING:FOUL LANGUAGE)", Length=93),
#  Row(Title='Iman Shumpert On Falling In Love w/ Teyana Taylor | Teyana & Iman | Premieres March 26th 9/8c', Length=93),
#  Row(Title='MUST WATCH!! Viewer calls News Anchor the NWORD LIVE: How the news anchor responds priceless!', Length=93),
#  Row(Title="Baby Hippo Fiona's Special Moments:  Never-before-seen Videos from Care Team - Cincinnati Zoo", Length=93),
#  Row(Title="Maryse goes overboard prepping for Carmella and Big Cass' arrival: Total Divas, Nov. 15, 2017", Length=93),
#  Row(Title="Stephen A. Smith slams the Philadelphia 76ers for its 'Trust The Process' | First Take | ESPN", Length=93),
#  Row(Title='Cavs players reportedly upset with LeBron; did Magic quietly snub Luke? | SportsNation | ESPN', Length=93),
#  Row(Title='The Cast of Star Wars: The Last Jedi Talk Kylo Ren, Jedi Controversy, Harrison Ford & Secrets', Length=93),
#  Row(Title='Tiffany Haddish thanks her bullies for making her rich, forces George Stephanopoulos to dance', Length=93),
#  Row(Title='Who Matt Reeves Wants As Batman, Is Basmati Blues Culturally Insensitive? The John Campe Show', Length=93),
#  Row(Title='Nick Foles used basketball to lead Super Bowl-winning drive for Eagles | NFL Primetime | ESPN', Length=93),
#  Row(Title='Jason Derulo - Colors (Official Music Video) The Coca-Cola Anthem for the 2018 FIFA World Cup', Length=93),
#  Row(Title='How To Do Thanksgiving Makeup That Has Nothing To Do With The 566 Federally Recognized Tribes', Length=93),
#  Row(Title='Marcin Szatanik | Fiat 126p | QUICK OFF & TRUE RALLY FANS | Darvit Walimska Wiosna 2018 | GRB', Length=93),
#  Row(Title='Behind-the-Scenes: See How Elon Musk Celebrated the Falcon Heavy Launch | National Geographic', Length=93),
#  Row(Title='Full Actresses Roundtable: Saoirse Ronan, Jennifer Lawrence, Mary J Blige | Close Up With THR', Length=93),
#  Row(Title='Goat Yoga with Khloé Kardashian | Kevin Hart: What The Fit Episode 4 | Laugh Out Loud Network', Length=93),
#  Row(Title="Stefon Diggs Makes Miracle TD Catch on Last Play, Vikings Win! 🦄 | Can't-Miss Play | NFL HLs", Length=92),
#  Row(Title='Watch SpaceX Launch A Tesla Roadster To Mars On The Falcon Heavy Rocket — And Why It Matters', Length=92),
#  Row(Title='Harper Grace Sings Original Tune R.I.P. for Her Solo Performance - American Idol 2018 on ABC', Length=92),
#  Row(Title='Black Panther Scores Second Largest 2nd Weekend Box Office In History - The John Campea Show', Length=92),
#  Row(Title="Infinity War's Directors Break Down the Thor and Guardians of the Galaxy Scene | Vanity Fair", Length=92),
#  Row(Title='Max boldly predicts Anthony Davis will overtake LeBron James next season | First Take | ESPN', Length=92),
#  Row(Title='Golden State Warriors vs San Antonio Spurs Full Game Highlights / Game 3 / 2018 NBA Playoffs', Length=92),
#  Row(Title="Watch Tesla's Secret Santa Mode!  Easter Egg with Icy Roads, Reindeer, Jingle Bells and More", Length=92),
#  Row(Title='Film Theory: Willy Wonka and the Golden Ticket SCAM! (Willy Wonka and the Chocolate Factory)', Length=92),
#  Row(Title='Gruffydd wows with OUT OF THIS WORLD vocals and bags a GOLDEN BUZZER! | Auditions | BGT 2018', Length=92),
#  Row(Title='That Time a Guy Parachuted Onto Devils Tower and No One Could Figure Out How to Get Him Down', Length=92),
#  Row(Title='North Korea Accidentally Hit One Of Its Own Cities With A Ballistic Missile Last Year | CNBC', Length=92),
#  Row(Title="Allison Janney Demonstrates Meryl Streep's Secret Kissing Technique | The Graham Norton Show", Length=92),
#  Row(Title='Kevin Hart on Lavar Ball and His Least Favorite Son | Cold As Balls | Laugh Out Loud Network', Length=92),
#  Row(Title='Jimmy Fallon, Anna Kendrick, Darlene Love & The Roots Sing Christmas (Classroom Instruments)', Length=92),
#  Row(Title='Stephen A. and Max ask Steph Curry about injury and Warriors vs. Rockets | First Take | ESPN', Length=92),
#  Row(Title='Rihanna on Her Divine Dress and Co-Hosting With Anna Wintour | Met Gala 2018 With Liza Koshy', Length=92),
#  Row(Title="An Expert's Take On The Symbolism In Childish Gambino’s Viral ‘This Is America’ Video | TIME", Length=92),
#  Row(Title="All the best reactions to James Harden's nasty cross of Wesley Johnson | SportsCenter | ESPN", Length=92),
#  Row(Title='DORITOS BLAZE vs. MTN DEW ICE | Super Bowl Commercial with Peter Dinklage and Morgan Freeman', Length=92),
#  Row(Title='Kyrie Irving on Conspiracy Theories, Tightening His Handle, and Going to the Celtics (Ep. 4)', Length=92),
#  Row(Title="Laura Govan Addresses Rumors Of Pregnancy & Affair With Vincent Herbert: He's So Not My Type", Length=92),
#  Row(Title='IS IT EVER ENOUGH? | CHIT CHAT GRWM | NEW YEARS GOALS, NEW YOUTUBERS, HELPING EACHOTHER etc.', Length=92),
#  Row(Title='Trae Young Oklahoma vs. Wichita State - Full Coverage | 12.16.17 | 29 Pts, 10 Ast, #1 PICK!', Length=91),
#  Row(Title="The Talk - Eve Reacts to Nicki Minaj's Racy Magazine Cover, 'I just don't think it's right'", Length=91),
#  Row(Title="Paul Allen's Radio Call of the Minnesota Vikings' Unbelievable Miracle Touchdown vs. Saints", Length=91),
#  Row(Title="Pelican Invades Director's Tent On The Galápagos Islands - Blue Planet II Behind The Scenes", Length=91),
#  Row(Title='Rams vs. Titans: The Super Bowl that was Decided by an Inch | Grudge Match | NFL Highlights', Length=91),
#  Row(Title='Jennifer Lawrence Reveals The Inspiration For Her Jersey Accent From American Hustle | WWHL', Length=91),
#  Row(Title='Deputy Attorney General Rosenstein: The indictment charges 13 Russian nationals... (C-SPAN)', Length=91),
#  Row(Title='Game Rewind: Watch Loyola Chicago advance to their first Final Four since 1963 in 9 minutes', Length=91),
#  Row(Title="Scuba Diving the World's Largest Urban Whitewater Course for Lost GoPros! (Huge Item Found)", Length=91),
#  Row(Title='Hugh Jackman On Keeping His 21-Year Marriage Strong: The Crazy Ups & Crazy Downs | PeopleTV', Length=91),
#  Row(Title='Stephen A. and Max react to LeBron James and Cavaliers sweeping Raptors | First Take | ESPN', Length=91),
#  Row(Title='Ron Burgundy narrates MLS opener between the Seattle Sounders and the Los Angeles FC | ESPN', Length=91),
#  Row(Title='Alan Walker, Keala Settle & The Greatest Showman Ensemble - This Is Me (Alan Walker Relift)', Length=91),
#  Row(Title='Deep Bore Into Antarctica Finds Freezing Ice, Not Melting as Expected | National Geographic', Length=91),
#  Row(Title="Cristiano Ronaldo's ridiculous bicycle kick vs. Juventus in UEFA Champions League | ESPN FC", Length=91),
#  Row(Title='Final full sequence that sent Cavaliers vs. Warriors to OT [Game 1, 2018 NBA Finals] | ESPN', Length=91),
#  Row(Title='President Donald Trump Honors Billy Graham As Body Lies In State At U.S. Capitol | NBC News', Length=91),
#  Row(Title='The Fiorentina game comes to a halt in the 13th minute as they pay tribute to Davide Astori', Length=91),
#  Row(Title='Masters Of The Sun: The Zombie Chronicles Augmented Reality Experience Release Date Trailer', Length=91),
#  Row(Title="Normani Kordei of Fifth Harmony Channels Destiny's Child for Bootylicious | Lip Sync Battle", Length=91),
#  Row(Title='Firefighting with Niecy Nash | Kevin Hart: What The Fit Episode 14 | Laugh Out Loud Network', Length=91),
#  Row(Title='J. Balvin, Willy William - Mi Gente (Alesso Remix) with Anwar Jibawi [Official Music Video]', Length=91),
#  Row(Title='Jersey Shore Cast Reacts To Pauly D’s OG Casting Tape | Jersey Shore: Family Vacation | MTV', Length=91),
#  Row(Title='State of the Union Address 2018 and Democratic response: Coverage and live stream from CBSN', Length=91),
#  Row(Title='Machine Gun Kelly, X Ambassadors & Bebe Rexha - Home (from Bright: The Album) [Music Video]', Length=91),
#  Row(Title="Stephen A.: Kevin Hart 'got his feelings hurt' by Dwyane Wade vs. 76ers | First Take | ESPN", Length=91),
#  Row(Title="Daisy Ridley talks about spending time with Carrie Fisher on the set of 'The Force Awakens'", Length=91),
#  Row(Title='Mara Justine Sings Run To You by Whitney Houston - Top 24 Solos - American Idol 2018 on ABC', Length=91),
#  Row(Title="The Talk - Piers Morgan Goes Off on Omarosa, from 'Celebrity Apprentice' to the White House", Length=91),
#  Row(Title="Dutch reporters tell US ambassador: 'This is the Netherlands, you have to answer questions'", Length=91),
#  Row(Title='2017-11-30-中國文化大學彩虹縮時(Taiwan,Taipei,CCU)   Three hour time-lapse photography of the rainbow', Length=91),
#  Row(Title='Nick Jonas HEART RATE MONITOR feat. Selena Gomez, Joe Jonas & Jack Black | STRONG LANGUAGE!', Length=91),
#  Row(Title="Joe Biden Speaks With Meghan McCain About His Late Son Beau's Battle With Cancer | The View", Length=91),
#  Row(Title='Pelican Invades Directors Tent On The Galápagos Islands - Blue Planet II Behind The Scenes', Length=90),
#  Row(Title="Draymond Green on his reaction during Fergie's National Anthem, new All Star format & more", Length=90),
#  Row(Title='Casting Mirror Polished Brass Ball from Molten Brass (Japanese Aluminium Foil Ball Sequel)', Length=90),
#  Row(Title='Helen Mirren, Donald Sutherland Talk Oscars Honor, #TimesUp Movement, Golden Globes & More', Length=90),
#  Row(Title='House Speaker Paul Ryan: ‘Don’t Forget This Is A Big Tax Cut For Families As Well’ | TODAY', Length=90),
#  Row(Title='Tommy Wiseau Breaks Down a Scene from The Disaster Artist | Notes on a Scene | Vanity Fair', Length=90),
#  Row(Title='The Making Of “Wakanda” With Ludwig Göransson | Presented By Marvel Studio’s Black Panther', Length=90),
#  Row(Title='Lucas The Spider Creator Explains How He Makes People Fall In Love With Spiders | The Dodo', Length=90),
#  Row(Title='Billions Season 3 (2018) | Official Trailer | Damian Lewis & Paul Giamatti SHOWTIME Series', Length=90),
#  Row(Title='GRAPEFRUIT PEEL STEAK Bistec de Toronja | HARD TIMES - recipes from times of food scarcity', Length=90),
#  Row(Title='Steve Kerr reminisces with Scottie Pippen about their Bulls playoff runs | The Jump | ESPN', Length=90),
#  Row(Title="Skip and Shannon react to Lance's antics in Game 4 loss to LeBron's Cavaliers | UNDISPUTED", Length=90),
#  Row(Title='The Spy Who Dumped Me (2018 Movie) Teaser Trailer – Mila Kunis, Kate McKinnon, Sam Heughan', Length=90),
#  Row(Title='3D Printing Metal with the Iro3D Desktop Metal 3D Printer - Solid High Carbon Steel Parts!', Length=90),
#  Row(Title='You Make It Feel Like Christmas (Live From “Gwen Stefani’s You Make It Feel Like Christ...', Length=90),
#  Row(Title='(HD VERSION) Kelly Clarkson & P!nk Everybody Hurts LIVE at the 2017 American Music Awards!', Length=90),
#  Row(Title='Beauty Gurus Dragging Kylie Cosmetics Brush Set - Jeffree, Manny, James Charles, Laura Lee', Length=90),
#  Row(Title='Victoria’s Secret Model Sara Sampaio’s Easy Bombshell Makeup Look | Beauty Secrets | Vogue', Length=90),
#  Row(Title="Courtney Hadwin: 13-Year-Old Golden Buzzer Winning Performance - America's Got Talent 2018", Length=90),
#  Row(Title='How To Make A GIANT CANDY CANE Cake w. SURPRISE INSIDE | PEPPERMINT MOCHA | How To Cake It', Length=90),
#  Row(Title='Uncle Drew (2018 Movie) Official Trailer – Kyrie Irving, Shaquille O’Neal, Tiffany Haddish', Length=90),
#  Row(Title='‘A Change Is Gonna Come’ for Lifford after he gets a GOLDEN BUZZER! | Auditions | BGT 2018', Length=90),
#  Row(Title='Panel Of Women Who Have Accused President Trump Of Misconduct Hold Press Conference | TIME', Length=90),
#  Row(Title='First kiss, epic carriage ride! | Prince Harry and Meghan Markle - The Royal Wedding - BBC', Length=90),
#  Row(Title='Martin Garrix & David Guetta - So Far Away (feat. Jamie Scott & Romy Dya) (Official Video)', Length=90),
#  Row(Title='Judge Faith Jenkins On Syndicated Court TV, Fair Representation For Heinous Crimes  + More', Length=90),
#  Row(Title="A Federal Judge In Philadelphia Blocks President Trump's Birth Control Restrictions | TIME", Length=90),
#  Row(Title='David Guetta & Afrojack ft Charli XCX & French Montana - Dirty Sexy Money (Official Video)', Length=90),
#  Row(Title="Russell Westbrook pushes away Denver Nuggets fan after fan gets in Westbrook's face | ESPN", Length=90),
#  Row(Title="Stephanie McMahon announces the first-ever Women's Royal Rumble Match: Raw, Dec. 18, 2017", Length=89),
#  Row(Title='Kelly Clarkson - Miss Independent / Love So Soft [2017 American Music Awards Performance]', Length=89),
#  Row(Title='Yellow Labrador dumped after being used for breeding puppies.  Look how happy she is now!', Length=89),
#  Row(Title='U.S. Will Move Embassy To Jerusalem Next Year, Vows Vice President Pence In Israel | TIME', Length=89),
#  Row(Title="Selena Gomez Tearfully Accepts Woman of the Year Award at Billboard's Women in Music 2017", Length=89),
#  Row(Title='Disney Resort Tour | Yacht & Beach Club Resort Hotel Grounds Tour, Pool Locations & More!', Length=89),
#  Row(Title='Lost Voice Guy has the audience ROARING with unique comedy routine | Auditions | BGT 2018', Length=89),
#  Row(Title='Carrie Underwood Opens Up About Her Accident, New Music, & Athletic Clothing Line | TODAY', Length=89),
#  Row(Title='WWSB Channel 7:   Sarasota Police stepping up pedestrian and bicyclist safety enforcement', Length=89),
#  Row(Title="Does Gwen Stefani Know If Blake Shelton Is People's Sexiest Man Alive? | Access Hollywood", Length=89),
#  Row(Title='YouTube Live at E3 2018: Monday with Ninja, Marshmello, PlayStation, Ubisoft, Todd Howard', Length=89),
#  Row(Title="Lupita Nyong'o - Why Black Panther Is a Different Kind of Superhero Movie: The Daily Show", Length=89),
#  Row(Title='Why Avengers Infinity War Will Succeed Where Justice League Failed - The John Campea Show', Length=89),
#  Row(Title="Stephen A. Smith goes off after Game 2: It's time to bench JR Smith | SportsCenter | ESPN", Length=89),
#  Row(Title='James Harden Triple-Double 2017.11.09 vs Cavs - 35 Pts, 13 Asts, 11 Rebs, 5 Stls, 2 GOOD!', Length=89),
#  Row(Title="John Krasinski Breaks Down A Quiet Place's Lantern Scene | Notes on a Scene | Vanity Fair", Length=89),
#  Row(Title='Gabby Barrett Sings I Have Nothing by Whitney Houston - Top 5 - American Idol 2018 on ABC', Length=89),
#  Row(Title="Shawn Mendes - There's Nothing Holdin' Me Back (Live From The 2017 American Music Awards)", Length=89),
#  Row(Title='How To Make a Pink Construction Hat out of Vanilla CAKE! | Yolanda Gampp | How To Cake It', Length=89),
#  Row(Title='Sean Evans, Matty Matheson, and Miss Info Judge a Stunt Burger Showdown | The Burger Show', Length=89),
#  Row(Title="Jalen Rose on LeBron James: He's actually gotten better at basketball | First Take | ESPN", Length=89),
#  Row(Title='Uncle Drew (2018 Movie) Teaser Trailer – Kyrie Irving, Shaquille O’Neal, Tiffany Haddish', Length=88),
#  Row(Title='SNL’s Kate McKinnon and Beth Kobliner talk money with kids. Fun with financial literacy!', Length=88),
#  Row(Title='Inside FC Barcelona’s ambitious plan to reinvent the Camp Nou, by Wired and Audifootball', Length=88),
#  Row(Title='Democrats, Republicans reach deal to reopen federal government | ABC News Special Report', Length=88),
#  Row(Title='Top 5 most stunning moments in Olympic Short Track Speed Skating  | Highlights Listicles', Length=88),
#  Row(Title='Best Wired Moments of the NBA Christmas Day Games (Kyrie, Draymond, John Wall and More!)', Length=88),
#  Row(Title='Official Ram Trucks Super Bowl Commercial | Dr. Martin Luther King, Jr. | Built to Serve', Length=88),
#  Row(Title="Mirror-Polished Japanese Foil Ball Challenge Crushed in a Hydraulic Press-What's Inside?", Length=88),
#  Row(Title='DJ Khaled Shows Off His Custom Dapper Dan Gucci Jackets Made By The Legendary Dapper Dan', Length=88),
#  Row(Title='How to record Slow Motion Sounds (Exploding Tomato at 60,000fps) - Smarter Every Day 184', Length=88),
#  Row(Title='And the WINNER of Britain’s Got Talent 2018 is... LOST VOICE GUY! | The Final | BGT 2018', Length=88),
#  Row(Title='Meet Chloe Kim, the Snowboarder Who Makes the Halfpipe Look Easy | NYT - Winter Olympics', Length=88),
#  Row(Title='The Legend of Zelda: Breath of the Wild DLC Dev. Talk - ft. Mr. Aonuma & Mr. Fujibayashi', Length=88),
#  Row(Title='Deyshia Hargrave, Louisiana Teacher Arrested At School Board Meeting, Speaks Out | TODAY', Length=88),
#  Row(Title='STEPH CURRY and OMRI CASSPI, postgame GSW (9-3) vs MIN: peaking?, turnovers, Casspi role', Length=88),
#  Row(Title='Confrontation Between Lifeguard, Bodysurfer Caught On Camera In Redondo Beach Goes Viral', Length=88),
#  Row(Title="'I have dad moves': Barack Obama discusses dancing on David Letterman's new Netflix show", Length=88),
#  Row(Title='The Best Love Advice I Can Give. (real adult relationships, self love, and so much more)', Length=88),
#  Row(Title='INSANE! SpaceX Falcon Heavy Side Boosters Landing Simultaneously at Kennedy Space Center', Length=88),
#  Row(Title="BTS Sings Camila Cabello's 'Havana' & Shows Off Some Red Carpet Dance Moves! | AMAs 2017", Length=88),
#  Row(Title="The Bella Twins' emotional rollercoaster return to the ring! | Royal Rumble 2018: Part 2", Length=88),
#  Row(Title='Cleveland Cavaliers vs Toronto Raptors Full Game Highlights / Game 4 / 2018 NBA Playoffs', Length=88),
#  Row(Title='The Kissing Booth Cast Kisses A Hairless Cat & Other Weird Stuff | Kiss & Tell | Netflix', Length=88),
#  Row(Title='Jason Derulo - Colors (Official Music Video) The Coca-Cola Anthem for the 2018 World Cup', Length=88),
#  Row(Title='Star Wars The Last Jedi First Reactions And World Premiere Report - The John Campea Show', Length=88),
#  Row(Title="Jimmy Kimmel monologue - Jan 11, 2018 | Trump Slurs Immigrants from 'sh*thole countries'", Length=88),
#  Row(Title='The Men Of Avengers: Infinity War” Compare Themselves To Different Meats  - CONAN on TBS', Length=88),
#  Row(Title='Vanderpump Rules: Lisa Confronts Sandoval for Talking Crap (Season 6, Episode 1) | Bravo', Length=88),
#  Row(Title='This Is Us - Aftershow: Season 2 Episode 14 (Digital Exclusive - Presented by Chevrolet)', Length=88),
#  Row(Title='Mark Hamill Didn’t Tell Carrie Fisher the Big Star Wars Secret | The Graham Norton Show', Length=87),
#  Row(Title='Andy Samberg | Breakfast Club in memoriam tribute | 2018 Film Independent Spirit Awards', Length=87),
#  Row(Title='Cleveland Cavaliers vs Boston Celtics Full Game Highlights / Game 6 / 2018 NBA Playoffs', Length=87),
#  Row(Title="Dana White clarifies McGregor's status as lightweight champ, makes predictions for 2018", Length=87),
#  Row(Title="Homeless and abused, this Pit Bull didn't lose HOPE that something amazing will happen!", Length=87),
#  Row(Title="Francia Raisa Explains How She Became Selena Gomez's Kidney Donor | Body Stories | SELF", Length=87),
#  Row(Title='I never moaned once! Gary Oldman on his Oscar winning performance as Winston Churchill.', Length=87),
#  Row(Title='John Cena On His Split From Nikki Bella: ‘I Had My Heart Broken Out Of Nowhere’ | TODAY', Length=87),
#  Row(Title='24 HOUR BOX FORT PRISON ESCAPE ROOM!! 📦🚔 Secret UNDERGROUND Tunnel, SPY GADGETS & More!', Length=87),
#  Row(Title="Rebel Wilson's does her Pitch Perfect audition - The Graham Norton Show: 2017 - BBC One", Length=87),
#  Row(Title='Lester Holt Reports From North Korea On Rogue Nation’s Olympic Ambitions | Sunday TODAY', Length=87),
#  Row(Title='Conor McGregor talks about Floyd Mayweather in UFC, his future, Ronda Rousey on 1/31/18', Length=87),
#  Row(Title='The Last Jedi Cast Touches Bearded Dragons & Other Weird Stuff | Fear Box | Vanity Fair', Length=87),
#  Row(Title='Blake Griffin gets candid about Clippers during interview after trade to Pistons | ESPN', Length=87),
#  Row(Title="Fletcher Cox & Kevin Hart's Hilarious Post Super Bowl LII Interview | NFL GameDay Prime", Length=87),
#  Row(Title='LeBron James teases what his dunk contest might look like during pregame warmups | ESPN', Length=87),
#  Row(Title='Michelle Sussett Sings Remember Me From Coco - Disney Night - American Idol 2018 on ABC', Length=87),
#  Row(Title='Ariana Grande, Jimmy & The Roots Sing No Tears Left to Cry w/ Nintendo Labo Instruments', Length=87),
#  Row(Title="Between the Scenes - Justin Timberlake's Confusing Halftime Performance: The Daily Show", Length=87),
#  Row(Title='Foo Fighters - Everlong/Christmas (Baby Please Come Home)/ Linus And Lucy (Live At SNL)', Length=87),
#  Row(Title='Rudimental - These Days feat. Jess Glynne, Macklemore & Dan Caplen [Live at Abbey Road]', Length=87),
#  Row(Title="Hawaii's Slow-Moving Natural Disaster & Google Home's Etiquette Lesson | The Daily Show", Length=87),
#  Row(Title='Tom Cruise Reacts to Slow-Mo Footage of How He Broke His Ankle | The Graham Norton Show', Length=87),
#  Row(Title='President Bill Clinton On Dictators, Democracy, & Why We Need Immigrants More Than Ever', Length=87),
#  Row(Title='The Big Ugly - Dramatic Rescue of a Fallen Big Wave Surfer - #Drone - Nazaré, Portugal', Length=86),
#  Row(Title='Model Aircraft Styled 3D Printed Air Engine, Experimental, 10 by 3.8 Propeller at 1PSI', Length=86),
#  Row(Title='Matthieu Ricard Leads a Meditation on Altruistic Love and Compassion | Talks at Google', Length=86),
#  Row(Title='Stephen A. Smith reacts to Tyronn Lue stepping away from Cavaliers | First Take | ESPN', Length=86),
#  Row(Title='The Legend of Zelda: Breath of the Wild Expansion Pass - The Champions’ Ballad Trailer', Length=86),
#  Row(Title='Weitsprung: Alyn Camara im T-Rex Kostüm | Teil 2 | Beginner gegen Gewinner | ProSieben', Length=86),
#  Row(Title='FIRST LOOK: Donald Trump animatronic debuts in Hall of Presidents at Walt Disney World', Length=86),
#  Row(Title='President Donald Trump Makes Statement From White House On Asia Trip (Full) | NBC News', Length=86),
#  Row(Title='Charlamagne Tha God & Joe Budden Present: This Year Was Dope/Trash 2017 (Full Episode)', Length=86),
#  Row(Title='[ English ] WS2812 Flexstrip overheating by short circuit. Common error done by people', Length=86),
#  Row(Title='Game Theory: FNAF, The Theory That Changed EVERYTHING!! (FNAF 6 Ultimate Custom Night)', Length=86),
#  Row(Title="'Wonder Woman' Director Patty Jenkins on Picking The Right Project | Close Up With THR", Length=86),
#  Row(Title="Sade - Flower of the Universe (From Disney's A Wrinkle in Time) [Official Lyric Video]", Length=86),
#  Row(Title='How This Insta-Famous Sugarfina Chocolate Bar Is Made | How Stuff Is Made | Refinery29', Length=86),
#  Row(Title='Ed Sheeran Tattoo’d Saoirse Ronan’s Handwriting Onto Himself! | The Graham Norton Show', Length=86),
#  Row(Title='The author of the 5:2 diet explains why eating healthy is more important than exercise', Length=86),
#  Row(Title='Matt the Radar Technician in Star Wars Battlefront 2!  New Battlefront 2 Mod Gameplay!', Length=86),
#  Row(Title='New Cartoon - The Bagheads - Full Episode - From GO! Cartoons Only on Cartoon Hangover', Length=86),
#  Row(Title='Glam Masters | Official Trailer | New Series Premieres February 28 at 10/9c | Lifetime', Length=86),
#  Row(Title="Dion Lewis' 103-Yd Kick Return TD vs. Denver! | Can't-Miss Play | NFL Wk 10 Highlights", Length=86),
#  Row(Title='How to Make 29 Handmade Pasta Shapes With 4 Types of Dough | Handcrafted | Bon Appétit', Length=86),
#  Row(Title='Imagine Dragons, Miss Congeniality - Whatever It Takes (Miss Congeniality Remix/Audio)', Length=86),
#  Row(Title='Bella Thorne - Burn so Bright from the Midnight Sun Original Motion Picture Soundtrack', Length=86),
#  Row(Title="70 People from 70 Countries Sing Their Country's National Anthem | Condé Nast Traveler", Length=86),
#  Row(Title='Ed Sheeran Tattooed Saoirse Ronan’s Handwriting Onto Himself! | The Graham Norton Show', Length=86),
#  Row(Title="Inside Ricky Martin's Serene Los Angeles Home | Celebrity Homes | Architectural Digest", Length=86),
#  Row(Title='Scuba Diving and Fishing Underwater in a Crystal Clear Pond! (Caught a Fish 26ft Deep)', Length=86),
#  Row(Title='Tegan and Sara present The Con X: Covers – Floorplan – Sara Bareilles [OFFICIAL VIDEO]', Length=86),
#  Row(Title='This Week in Chaos: Nunes & BIEs | February 7, 2018 Act 1, Pt. 2 | Full Frontal on TBS', Length=86),
#  Row(Title='Jane Fonda And Lily Tomlin On ‘Grace And Frankie,’ Friendship, Female Equality | TODAY', Length=86),
#  Row(Title='Thank You Peter Capaldi | Doctor Who Christmas | Christmas Night @ 9/8c on BBC America', Length=86),
#  Row(Title='Top 5 Programming Languages to Learn to Get a Job at Google, Facebook, Microsoft, etc.', Length=86),
#  Row(Title="Christina Aguilera Surprises Farrah Moan During Untucked: RuPaul's Drag Race Season 10", Length=86),
#  Row(Title="Scared abandoned dog hides in a spot that we couldn't reach, so I had no choice but...", Length=86),
#  Row(Title='Royal Wedding: Prince Harry and Meghan Markle Exchange First Kiss as Husband and Wife', Length=85),
#  Row(Title='DIY STUDY HACKS! How To Be PRODUCTIVE After School + Study Tips to Get BETTER GRADES!', Length=85),
#  Row(Title="Benedict Cumberbatch, Tom Hiddleston and Tom Holland dish on 'Avengers: Infinity War'", Length=85),
#  Row(Title='The Assassination of Gianni Versace: American Crime Story | Season 2: First Look | FX', Length=85),
#  Row(Title='THE HOUSE OF TOMORROW Official Trailer (2018) Asa Butterfield, Nick Offerman Movie HD', Length=85),
#  Row(Title='John Legend And Zara Larsson Perform God Only Knows At Nobel Peace Prize Concert 2017', Length=85),
#  Row(Title="The Weeknd BLASTS H&M Over Racist 'Monkey' Ad Featuring Black Child, ENDS Partnership", Length=85),
#  Row(Title='Al Franken Resigns; Donald Trump Jr. Testifies in Russia Investigation: A Closer Look', Length=85),
#  Row(Title='Multiple Casualties And Injuries Reported As Amtrak Train Derails Near Seattle | TIME', Length=85),
#  Row(Title='Michael Shannon Puts $2.10 in Coins Up His Nose | Secret Talent Theatre | Vanity Fair', Length=85),
#  Row(Title="PRETTYMUCH Ain’t Scared Of Nick - They’ve Got Simon Cowell | Wild 'N Out | #Wildstyle", Length=85),
#  Row(Title='Legendary Rocker Tom Petty Died From Accidental Overdose Of Medications, Coroner Says', Length=85),
#  Row(Title='Amy Schumer Shares Her Experience with Gray-Area Rape | SuperSoul Conversations | OWN', Length=85),
#  Row(Title='Are Jessica Chastain & Bryce Dallas Howard The Same Person!? | The Graham Norton Show', Length=85),
# ...
#  Row(Title="Mindy Kaling's Daughter Had the Perfect Reaction to Entering Oprah's House", Length=74),
#  Row(Title="Xscape's Tamika Scott Falls During Epic Wardrobe Malfunction Onstage | TMZ", Length=74),
#  Row(Title='Shameer Rayes brings ALL of the moves to our stage! | Auditions | BGT 2018', Length=74),
#  Row(Title='Kevin Hart Lives His Truth And Opens Up About Being Irresponsible And More', Length=74),
#  Row(Title="FLOYD MAYWEATHER KILLS UFC TALK; DENIES DANA WHITE CLAIM: I'M NOT DOING IT", Length=74),
#  Row(Title='BASE jumping into a plane mid-air. (Extended Version) | A Door In  The Sky', Length=74),
#  Row(Title="Eagles' Home Radio Call of the Last Play of Super Bowl 52 | NFL Highlights", Length=74),
#  Row(Title='Timelapse shows Bali volcano Mount Agung spewing ash after minor eruptions', Length=74),
#  Row(Title='It’s Just Water Weight | Kevin Hart: What The Fit | Laugh Out Loud Network', Length=74),
#  Row(Title='Dallas Mavericks caoch Rick Carlisle sounds off on ESPN Lavar Ball article', Length=74),
#  Row(Title='Garry Kasparov Answers Chess Questions From Twitter | Tech Support | WIRED', Length=74),
#  Row(Title='Professional Makeup Artist Watching Me Do my Makeup — WHAT DID WE LEARN??', Length=73),
#  Row(Title='5 Times Scientists Were Very Wrong About New Discoveries, Because of Hope', Length=73),
#  Row(Title='Hailee Steinfeld & Alesso Let Me Go ft Florida Georgia Line,watt AMA live', Length=73),
#  Row(Title='WATCH: AL Democratic Senate candidate Doug Jones speaks on election night', Length=73),
#  Row(Title='Raw Superstars visit the National Civil Rights Museum: Raw, Jan. 15, 2018', Length=73),
#  Row(Title='Is The Last Jedi the Most Divisive Star Wars Movie Ever? (SPOILERS) - SJU', Length=73),
#  Row(Title='Floyd Mayweather Talks Potential MMA Fight | SHOWTIME CHAMPIONSHIP BOXING', Length=73),
#  Row(Title='Eagles Fans Flood Streets In Philly For Super Bowl Celebration | NBC News', Length=73),
#  Row(Title="Don't Worry, He Won't Get Far On Foot - Official Trailer | Amazon Studios", Length=73),
#  Row(Title="'Winchester' Clip Shows Spooky House in Helen Mirren's Haunting New Movie", Length=73),
#  Row(Title='Kendrick Lamar wins International Male Solo Artist | The BRIT Awards 2018', Length=73),
#  Row(Title='Kelly Oubre Punches John Wall in the Lead during warriors wizards scuffle', Length=73),
#  Row(Title='The Ultimate Expensive Burger Tasting with Adam Richman | The Burger Show', Length=73),
#  Row(Title='Lili Reinhart and Camila Mendes Read Absurd Riverdale Fan Theories | ELLE', Length=73),
#  Row(Title='I pranked him... then I BOUGHT him his DREAM CAR!! **emotional surprise**', Length=73),
#  Row(Title='Bastille - World Gone Mad (from Bright: The Album) [Official Music Video]', Length=73),
#  Row(Title='Dylan Minnette on 13 Reasons Why, High School & Looking Like Jimmy Kimmel', Length=73),
#  Row(Title='Jerry Rice Answers Football Questions From Twitter | Tech Support | WIRED', Length=73),
#  Row(Title='Hillary Clinton On Why She’s Not Running For President Again | Teen Vogue', Length=73),
#  Row(Title='17+ MOMENTS WE’RE LEAVING BEHIND IN 2017 (ft. Kingsley) | Collabmas Day 1', Length=73),
#  Row(Title='Miguel - Come Through and Chill (Official Video) ft. J. Cole, Salaam Remi', Length=73),
#  Row(Title='5 Days of Calligraphy Hand Lettering | Try Living With Lucie | Refinery29', Length=73),
#  Row(Title='Clean Bandit - I Miss You feat. Julia Michaels in the Radio 1 Live Lounge', Length=73),
#  Row(Title='Second Woman Accuses Sen. Al Franken Of Inappropriate Touching | The View', Length=73),
#  Row(Title='Hear the Otherworldly Sounds of Skating on Thin Ice | National Geographic', Length=73),
#  Row(Title='Michelle Obama Talks with Birthday Girl Ellen About Post-White House Life', Length=73),
#  Row(Title="What's the difference between hibernation and sleep? - Sheena Lee Faherty", Length=73),
#  Row(Title="The Cast of ‘All That’ Is Here & No One Can Handle It | Wild 'N Out | MTV", Length=73),
#  Row(Title='Ryan Reynolds Explains the Deadpool Leak | Best of The Graham Norton Show', Length=73),
#  Row(Title='Tom Holland Felt Insecure On The Set Of Avengers - The Graham Norton Show', Length=73),
#  Row(Title='COLLEGE KIDS REACT TO K-POP (BTS, MONSTA X, SEVENTEEN, TWICE, Red Velvet)', Length=73),
#  Row(Title='Meghan Trainor Watches Fan Covers On YouTube | You Sang My Song | Glamour', Length=73),
#  Row(Title='MOTOR SPORT - Cardi B x Migos x Nicki Minaj Dance | Matt Steffanina cover', Length=73),
#  Row(Title='Carla Makes Granola Cluster Cookies | From the Test Kitchen | Bon Appétit', Length=73),
#  Row(Title='Maddie Poppe Wins American Idol 2018 - Finale - American Idol 2018 on ABC', Length=73),
#  Row(Title='ABANDONED IN PARIS WITH NO MONEY FOR 24 HOURS (Wild Night with Strangers)', Length=73),
#  Row(Title='Daniel Kaluuya Hugged Oprah at the Golden Globes | The Graham Norton Show', Length=73),
#  Row(Title='Novak Djokovic v Hyeon Chung match highlights (4R) | Australian Open 2018', Length=73),
#  Row(Title="Jon Gruden on Raiders job: There's a good chance | Golic and Wingo | ESPN", Length=73),
#  Row(Title="Rose Leslie Won't Let Kit Harington Read Game of Thrones Scripts Near Her", Length=73),
#  Row(Title='Drew Barrymore Fact Checks Beauty Tutorials Based On Her Movies | Glamour', Length=73),
#  Row(Title="Stephen A. and Max react to LeBron James' broken hand | First Take | ESPN", Length=73),
#  Row(Title="How Lush's Popular Shampoo Bars Are Made | How Stuff Is Made | Refinery29", Length=73),
#  Row(Title='The Cult of the Jersey Diner Burger, with Padma Lakshmi | The Burger Show', Length=73),
#  Row(Title='Russell chats to Emmy award winning host of Last Week Tonight John Oliver', Length=73),
#  Row(Title='24 HOUR BOX FORT PRISON ESCAPE ROOM!! 📦🚔 UNDERWATER PRISON, Scuba & More!', Length=73),
#  Row(Title='Rita Ora Owns “I’m Too Sexy” by Right Said Fred | Lip Sync Battle Preview', Length=73),
#  Row(Title='OjO Commuter Scooter®- Light Electric Vehicle for the Bike Lane & Beyond!', Length=73),
#  Row(Title='Christina Aguilera - Whitney Houston Tribute (2017 American Music Awards)', Length=73),
#  Row(Title='Jayson Tatum Full Highlights 2017.11.14 at Nets - 19 Pts, 3 Stls, SMOOTH!', Length=73),
#  Row(Title='Khloe Kardashian Is Continuing to Workout During Her Pregnancy | Lorraine', Length=73),
#  Row(Title='Snow Patrol - What If This Is All The Love You Ever Get? (Official Video)', Length=73),
#  Row(Title='Kendrick lamar / U2 / Dave Chappelle  - XXX / DNA Grammy 2018 Performance', Length=73),
#  Row(Title='Instant Karma: Woman Breaks Her Leg While Stealing A Package From A Porch', Length=73),
#  Row(Title='50 Cent Goes Undercover on Reddit, Twitter & Instagram | Actually Me | GQ', Length=73),
#  Row(Title='Ryan Reynolds Explains the Deadpool Leak | Best of the Graham Norton Show', Length=73),
#  Row(Title='The Algorithm That Will Keep You Buying On Cyber Monday | Mach | NBC News', Length=73),
#  Row(Title='Liverpool vs. Manchester City | 2017-18 UEFA Champions League Highlights', Length=72),
#  Row(Title='Oprah Winfrey Receives Cecil B. de Mille Award at the 2018 Golden Globes', Length=72),
#  Row(Title='Rich Brian Experiences Peak Bromance While Eating Spicy Wings | Hot Ones', Length=72),
#  Row(Title='Demi Lovato - Sorry Not Sorry (Live From The 2017 American Music Awards)', Length=72),
#  Row(Title='Instant classic: Relive UMBC’s incredible win over Virginia in 8 minutes', Length=72),
#  Row(Title='Blindfolded Cake Decorating Challenge!  | How To Cake It | Yolanda Gampp', Length=72),
#  Row(Title='Kevin Durant and LeBron James Duel, Each Score 32 Pts | January 15, 2018', Length=72),
#  Row(Title='Superstar: Brandon Victor Dixon - Jesus Christ Superstar Live in Concert', Length=72),
#  Row(Title='Chadwick Boseman gets emotional while discussing impact of Black Panther', Length=72),
#  Row(Title='Christina Aguilera Watches Erika Jayne Crush “Fighter” | Lip Sync Battle', Length=72),
#  Row(Title='VFX Expert Breaks Down The History of Shrinking People in Movies | WIRED', Length=72),
#  Row(Title='Fifth Harmony’s Ally Brooke is Selena AND J-Lo | Lip Sync Battle Preview', Length=72),
#  Row(Title='Emily Blunt and James McAvoy Explain a Typical British Day | Vanity Fair', Length=72),
#  Row(Title='KUWTK | Katch the Two Night Kardashian Event this Sunday and Monday | E!', Length=72),
#  Row(Title='Rooster Teeth and Sean Evans Sample New York City BBQ | Sean in the Wild', Length=72),
#  Row(Title='Crosswalk the Musical on Broadway (w/ Hugh Jackman, Zendaya & Zac Efron)', Length=72),
#  Row(Title='FIA GT World Cup 2017. Qualification Race Macau Grand Prix. Huge Pile Up', Length=72),
#  Row(Title='I tried following a Kylie Jenner Makeup Tutorial... Realizing things😂...', Length=72),
#  Row(Title='Robert Wagner called person of interest in mysterious Natalie Wood death', Length=72),
#  Row(Title='BLIND(folded) CAKE DECORATING CONTEST (with Molly Burke) // Grace Helbig', Length=72),
#  Row(Title='How to Waterproof Electronics || Nail Polish, Silicone, Potting Compound', Length=72),
#  Row(Title='2 wingsuit flyers BASE jump into a plane in mid-air. | A Door In The Sky', Length=72),
#  Row(Title='Kim Kardashian and Kanye West Welcome Baby Girl Via Surrogate I TMZ News', Length=72),
#  Row(Title='Debating the Western Conference All-Star starters | NBA Countdown | ESPN', Length=72),
#  Row(Title='Real Madrid vs. Bayern Munich | 2017-18 UEFA Champions League Highlights', Length=72),
#  Row(Title='Log Cabin TIMELAPSE Built By ONE MAN In The Forest (Real Life Minecraft)', Length=72),
#  Row(Title='Mom Who Went Blind When She Was Shot in Las Vegas Massacre Can See Again', Length=72),
#  Row(Title="Grey's Anatomy 14x09 Promo 1-800-799-7233 (HD) Season 14 Episode 9 Promo", Length=72),
#  Row(Title='Terry Crews: Kevin Hart Tried To Play Mind Games With Me  - CONAN on TBS', Length=72),
#  Row(Title="Alison Brie's GLOW Co-Stars Freaked Out Over Her Golden Globe Nomination", Length=72),
#  Row(Title='Danny MacAskill trial biking in Düsseldorf. | Straight from the athletes', Length=72),
#  Row(Title='Going To Dinner With A Blind Girl In COMPLETE DARKNESS feat. Molly Burke', Length=72),
#  Row(Title='Jamie Dornan Had an Awkward ‘James Bond’ Moment | The Graham Norton Show', Length=72),
#  Row(Title='Japanese Food Tour with Frank Pinello and Sakura Yagi | Sean in the Wild', Length=72),
#  Row(Title='Tiffany Haddish Details Her Dinners with Barbra Streisand & Taylor Swift', Length=72),
#  Row(Title='Trump and Republicans Rush to Pass Their Radical Tax Plan: A Closer Look', Length=72),
#  Row(Title='Shawn Mendes - In My Blood (Live From The Billboard Music Awards / 2018)', Length=72),
#  Row(Title='Willie Reed and Joel Embiid Fight！Embiid saying HE CANT FUCKIN GUARD ME!', Length=72),
#  Row(Title="John Krasinski Couldn't Believe Stephen King's Reaction to A Quiet Place", Length=72),
#  Row(Title='Bayern Munich vs. Real Madrid | 2017-18 UEFA Champions League Highlights', Length=72),
#  Row(Title='The History of Fortnite Battle Royale - Did You Know Gaming? Feat. Remix', Length=72),
#  Row(Title='The Final Countdown - Europe (Vintage Cabaret Cover) ft. Gunhild Carling', Length=72),
#  Row(Title="Dog Cries Every Time He's Touched — Until He Meets This Woman | The Dodo", Length=72),
#  Row(Title='Daniel Kaluuya wins the EE Rising Star Award | EE BAFTA Film Awards 2018', Length=72),
#  Row(Title='Kathie Lee And Hoda Audition For ‘The Voice’ And Nail It Sort Of | TODAY', Length=72),
#  Row(Title='Jimmy Fallon and Paul Rudd Recreate King of Wishful Thinking Music Video', Length=72),
#  Row(Title='70 People Try 70 Tongue-Twisters From 70 Countries | Condé Nast Traveler', Length=72),
#  Row(Title='Kid Hilariously Steals Baby Jesus From Manger During Live Nativity Scene', Length=72),
#  Row(Title='Surfers Tackle Ultra Rare Slurpee Waves in Winter Blizzard - The Inertia', Length=72),
#  Row(Title='EXCLUSIVE: Reginae Carter Reveals What Changed After That Beef with Khia', Length=72),
#  Row(Title='Skelly the Skeleton Robot wishing you a Merry Christmas & Happy New Year', Length=72),
#  Row(Title='High End vs. Drugstore Cruelty Free Makeup | Beauty With Mi | Refinery29', Length=72),
#  Row(Title='Chris Stapleton - Midnight Train To Memphis (Live From SNL Studios/2018)', Length=72),
#  Row(Title="Nichola Joss's Top 3 Facial Massage Techniques | SUPERSTARS | Feelunique", Length=72),
#  Row(Title='Pre-Aztec Skeletons Found Arranged in Spiral Shape | National Geographic', Length=72),
#  Row(Title="Why It's Illegal to be Named Brfxxccxxmnpcccclllmmnprxvclmnckssqlbb11116", Length=72),
#  Row(Title='Deyshia Hargrave Speaks Out About Being Arrested at School Board Meeting', Length=72),
#  Row(Title='Why a New York Ice Cream Shop is Releasing Ham Ice Cream — The Meat Show', Length=72),
#  Row(Title='Blockchain Expert Explains One Concept in 5 Levels of Difficulty | WIRED', Length=72),
#  Row(Title='Riverdale | Chapter Twenty-Three: The Blackboard Jungle Trailer | The CW', Length=72),
#  Row(Title='Robot Muscle, Photovoltaic Roads, Milking Platypus, Hero Rats… Mind Blow', Length=72),
#  Row(Title='Matt Lauer: ‘There Are No Words To Express My Sorrow And Regret’ | TODAY', Length=72),
#  Row(Title='How Chloe Kim Became America’s Snowboarding Superstar | NBC Nightly News', Length=72),
#  Row(Title='DJ Khaled - I Believe (from Disney’s A WRINKLE IN TIME) ft. Demi Lovato', Length=71),
#  Row(Title='Longest Snake On Earth Eats A Deer Whole | Wildest Islands Of Indonesia', Length=71),
#  Row(Title='Jason Derulo - Colors (Coca-Cola® Anthem for the 2018 FIFA World CupTM)', Length=71),
#  Row(Title="KUWTK | Kourtney Kardashian Explains Ex Scott's Reaction to Her BF | E!", Length=71),
#  Row(Title="Everything Yolanda Hadid Eats In a Day | Food Diaries | Harper's BAZAAR", Length=71),
#  Row(Title='Daisy Ridley Builds A Millennium Falcon (While Answering Our Questions)', Length=71),
#  Row(Title='The Break with Michelle Wolf | Featuring a Strong Female Lead | Netflix', Length=71),
#  Row(Title='Have Yourself A Merry Little Christmas (ft. Tori Kelly) - Jacob Collier', Length=71),
#  Row(Title='Maia and Alex Shibutani, Ice Dancing Siblings, Talk Firsts | Teen Vogue', Length=71),
#  Row(Title='Watch Courtroom Erupt In Applause After Larry Nassar Sentencing | MSNBC', Length=71),
#  Row(Title='Barry the Blind Dog Destroys New Toy: How Long Will It Take? | The Dodo', Length=71),
#  Row(Title='Curved iPhones Are Coming, iOS 12 Siri Overhaul & Apple Ditching Intel!', Length=71),
#  Row(Title='Why Jerusalem can make or break peace between Israelis and Palestinians', Length=71),
#  Row(Title='Hang with Timothée Chalamet and Armie Hammer Before the Oscars // Omaze', Length=71),
#  Row(Title="Russo bros FINALLY explain Hawkeye 'absence' for Avengers: Infinity War", Length=71),
#  Row(Title='Officials provide update after Ohio 7th-grader shoots himself at school', Length=71),
#  Row(Title='The Greatest Showman | Rewrite The Stars ft. Zendaya | 20th Century FOX', Length=71),
#  Row(Title="Joey Graceffa's Enchanted Gaming Room Makeover! | OMG We're Coming Over", Length=71),
#  Row(Title='Undercover footage from inside secretive Presidents Club Charity Dinner', Length=71),
#  Row(Title="It's true, wife and I are getting a divorce.  Here's whats next for us.", Length=71),
#  Row(Title='2018 Grammy Nominations ANNOUNCED - Kendrick Lamar, Jay-Z, Bruno & MORE', Length=71),
#  Row(Title='Royal wedding 2018: Lip-reader on what Meghan and Harry said - BBC News', Length=71),
#  Row(Title="Camila Cabello Loves Ikeas's Meatballs | Elvis Duran Inteview Highlight", Length=71),
#  Row(Title='Jordan Peele Breaks Down Get Out Fan Theories from Reddit | Vanity Fair', Length=71),
#  Row(Title='Sia, David Guetta & Afrojack - Helium (Sia vs. David Guetta & Afrojack)', Length=71),
#  Row(Title="Donald Trump Jr. Says India's Poorest Have Something Special | NBC News", Length=71),
#  Row(Title='Charlie Puth (feat. Boyz II Men) - If You Leave Me Now (Studio Session)', Length=71),
#  Row(Title='Real or FAKE ANIME?? Pt. 5 - ACTION/ADVENTURE EDITION! | Thomas Sanders', Length=71),
#  Row(Title='Slide Into Strength | Kevin Hart: What The Fit | Laugh Out Loud Network', Length=71),
#  Row(Title="HOLO CAPPUCCINO | DIY Diamond Cappuccino test (maybe don't drink this?)", Length=71),
#  ...]

# %%
titleLengthDF.createOrReplaceTempView("titleLengthDF")
length = spark.sql("SELECT Length, COUNT(*) as freq FROM titleLengthDF GROUP BY Length, Length ORDER BY freq DESC")
length.show()
# Out:
# +------+----+
# |Length|freq|
# +------+----+
# |    42| 157|
# |    44| 145|
# |    48| 144|
# |    43| 143|
# |    51| 142|
# |    41| 140|
# |    39| 139|
# |    47| 137|
# |    45| 131|
# |    49| 130|
# |    46| 129|
# |    36| 127|
# |    52| 122|
# |    37| 120|
# |    54| 119|
# |    33| 116|
# |    34| 116|
# |    50| 116|
# |    38| 115|
# |    53| 115|
# +------+----+
# only showing top 20 rows

# %%
# word count
from pyspark.sql.types import StringType, DoubleType, IntegerType, StructField, StructType
wordCount = spark.sql("SELECT LOWER(title) as title from df")\
                 .rdd.flatMap(lambda line:line['title'].split()).map(lambda word:(word,1)).reduceByKey(lambda a,b:a+b).repartition(1).sortBy(lambda x:x[1],False)
wordCountSchema = StructType([StructField("word", StringType(), True),StructField("count", IntegerType(), True)])
wordCountDF = spark.createDataFrame(wordCount, wordCountSchema)
wordCountDF = wordCountDF.filter(wordCountDF["word"]!='')
wordCountDF.take(300)
# Out:
# [Row(word='-', count=11440),
#  Row(word='|', count=10649),
#  Row(word='the', count=9935),
#  Row(word='a', count=4682),
#  Row(word='to', count=4272),
#  Row(word='in', count=3358),
#  Row(word='of', count=3129),
#  Row(word='with', count=2756),
#  Row(word='on', count=2344),
#  Row(word='and', count=2296),
#  Row(word='&', count=2020),
#  Row(word='my', count=2009),
#  Row(word='i', count=1988),
#  Row(word='trailer', count=1943),
#  Row(word='video)', count=1938),
#  Row(word='how', count=1816),
#  Row(word='for', count=1765),
#  Row(word='is', count=1623),
#  Row(word='(official', count=1613),
#  Row(word='2018', count=1610),
#  Row(word='official', count=1589),
#  Row(word='you', count=1589),
#  Row(word='at', count=1129),
#  Row(word='from', count=1123),
#  Row(word='ft.', count=1049),
#  Row(word='what', count=923),
#  Row(word='new', count=908),
#  Row(word='this', count=856),
#  Row(word='makeup', count=810),
#  Row(word='me', count=789),
#  Row(word='it', count=774),
#  Row(word='music', count=736),
#  Row(word='we', count=735),
#  Row(word='first', count=693),
#  Row(word='2017', count=683),
#  Row(word='2', count=674),
#  Row(word='why', count=671),
#  Row(word='by', count=644),
#  Row(word='[official', count=632),
#  Row(word='day', count=598),
#  Row(word='out', count=590),
#  Row(word='your', count=585),
#  Row(word='vs.', count=584),
#  Row(word='make', count=568),
#  Row(word='game', count=559),
#  Row(word='about', count=558),
#  Row(word='full', count=545),
#  Row(word='black', count=534),
#  Row(word='show', count=519),
#  Row(word='star', count=511),
#  Row(word='that', count=510),
#  Row(word='his', count=508),
#  Row(word='are', count=496),
#  Row(word='her', count=494),
#  Row(word='live', count=481),
#  Row(word='10', count=478),
#  Row(word='up', count=472),
#  Row(word='5', count=463),
#  Row(word='vs', count=460),
#  Row(word='do', count=459),
#  Row(word='video]', count=457),
#  Row(word='teaser', count=454),
#  Row(word='best', count=448),
#  Row(word='[hd]', count=445),
#  Row(word='season', count=438),
#  Row(word='movie', count=433),
#  Row(word='(audio)', count=430),
#  Row(word='love', count=419),
#  Row(word='will', count=417),
#  Row(word='super', count=415),
#  Row(word='all', count=415),
#  Row(word='challenge', count=409),
#  Row(word='most', count=409),
#  Row(word='like', count=405),
#  Row(word='christmas', count=401),
#  Row(word='video', count=394),
#  Row(word='–', count=392),
#  Row(word='or', count=381),
#  Row(word='james', count=378),
#  Row(word='time', count=376),
#  Row(word='last', count=373),
#  Row(word='(lyric', count=370),
#  Row(word='get', count=367),
#  Row(word='1', count=366),
#  Row(word='one', count=364),
#  Row(word='john', count=359),
#  Row(word='diy', count=359),
#  Row(word='life', count=359),
#  Row(word='review', count=357),
#  Row(word='test', count=356),
#  Row(word='not', count=356),
#  Row(word='made', count=352),
#  Row(word='news', count=351),
#  Row(word='bowl', count=348),
#  Row(word='be', count=348),
#  Row(word='x', count=344),
#  Row(word='face', count=344),
#  Row(word='house', count=339),
#  Row(word='can', count=339),
#  Row(word='so', count=334),
#  Row(word='highlights', count=332),
#  Row(word='+', count=330),
#  Row(word='top', count=330),
#  Row(word='american', count=326),
#  Row(word='cat', count=321),
#  Row(word='food', count=319),
#  Row(word='world', count=318),
#  Row(word='perfect', count=315),
#  Row(word='(2018)', count=313),
#  Row(word='things', count=311),
#  Row(word='cake', count=307),
#  Row(word='down', count=305),
#  Row(word='more', count=305),
#  Row(word='if', count=304),
#  Row(word='ever', count=303),
#  Row(word='no', count=302),
#  Row(word='an', count=301),
#  Row(word='/', count=301),
#  Row(word='look', count=299),
#  Row(word='real', count=293),
#  Row(word='as', count=292),
#  Row(word='big', count=291),
#  Row(word='making', count=288),
#  Row(word='talk', count=286),
#  Row(word='tried', count=282),
#  Row(word='inside', count=280),
#  Row(word='after', count=277),
#  Row(word="don't", count=272),
#  Row(word='wars', count=272),
#  Row(word='giant', count=271),
#  Row(word='4', count=268),
#  Row(word='our', count=267),
#  Row(word='every', count=266),
#  Row(word='watch', count=264),
#  Row(word="it's", count=264),
#  Row(word='—', count=264),
#  Row(word='cardi', count=258),
#  Row(word='trailers', count=258),
#  Row(word='when', count=257),
#  Row(word='who', count=256),
#  Row(word='have', count=254),
#  Row(word='3', count=252),
#  Row(word='battle', count=250),
#  Row(word='off', count=247),
#  Row(word='react', count=246),
#  Row(word='home', count=244),
#  Row(word='youtube', count=243),
#  Row(word='people', count=242),
#  Row(word='snl', count=241),
#  Row(word='trump', count=239),
#  Row(word='beauty', count=237),
#  Row(word='take', count=237),
#  Row(word='got', count=236),
#  Row(word='everything', count=235),
#  Row(word='man', count=233),
#  Row(word='night', count=231),
#  Row(word='week', count=231),
#  Row(word='questions', count=231),
#  Row(word='voice', count=230),
#  Row(word='awards', count=229),
#  Row(word='into', count=228),
#  Row(word='does', count=227),
#  Row(word='tutorial', count=226),
#  Row(word='honest', count=226),
#  Row(word='espn', count=224),
#  Row(word='was', count=222),
#  Row(word='netflix', count=222),
#  Row(word='kids', count=222),
#  Row(word='ball', count=220),
#  Row(word='nfl', count=220),
#  Row(word='cast', count=219),
#  Row(word='wedding', count=214),
#  Row(word='school', count=213),
#  Row(word='box', count=212),
#  Row(word='meghan', count=210),
#  Row(word='makes', count=210),
#  Row(word='goes', count=209),
#  Row(word='year', count=209),
#  Row(word='tbs', count=207),
#  Row(word='go', count=206),
#  Row(word='part', count=206),
#  Row(word='try', count=204),
#  Row(word='adam', count=204),
#  Row(word='dog', count=204),
#  Row(word='commercial', count=202),
#  Row(word='nba', count=202),
#  Row(word='royal', count=202),
#  Row(word='has', count=201),
#  Row(word='bts', count=200),
#  Row(word='apple', count=200),
#  Row(word='their', count=199),
#  Row(word='jedi', count=195),
#  Row(word='infinity', count=195),
#  Row(word='back', count=195),
#  Row(word='smith', count=194),
#  Row(word='(live', count=194),
#  Row(word='over', count=193),
#  Row(word='mom', count=192),
#  Row(word='hot', count=190),
#  Row(word='never', count=190),
#  Row(word='know', count=190),
#  Row(word='iphone', count=188),
#  Row(word='ready', count=187),
#  Row(word='girl', count=187),
#  Row(word='(feat.', count=187),
#  Row(word='bbc', count=185),
#  Row(word='hd', count=185),
#  Row(word='vogue', count=185),
#  Row(word='kevin', count=184),
#  Row(word='audio]', count=184),
#  Row(word='michael', count=183),
#  Row(word='scene', count=183),
#  Row(word='bad', count=183),
#  Row(word='8', count=183),
#  Row(word='red', count=182),
#  Row(word='song', count=182),
#  Row(word='chris', count=181),
#  Row(word='wrong', count=181),
#  Row(word='grace', count=181),
#  Row(word='wired', count=180),
#  Row(word='getting', count=179),
#  Row(word='kim', count=178),
#  Row(word='tv', count=175),
#  Row(word='march', count=175),
#  Row(word='chocolate', count=174),
#  Row(word='should', count=172),
#  Row(word='golden', count=172),
#  Row(word='slow', count=171),
#  Row(word='wild', count=170),
#  Row(word='lyric', count=170),
#  Row(word='baby', count=170),
#  Row(word='war', count=170),
#  Row(word='shawn', count=169),
#  Row(word='blind', count=168),
#  Row(word='cooking', count=167),
#  Row(word='prince', count=167),
#  Row(word='just', count=167),
#  Row(word='b', count=166),
#  Row(word='secret', count=166),
#  Row(word='final', count=165),
#  Row(word='film', count=165),
#  Row(word='nbc', count=164),
#  Row(word='story', count=164),
#  Row(word='during', count=163),
#  Row(word='hair', count=163),
#  Row(word='mendes', count=163),
#  Row(word='fair', count=163),
#  Row(word='national', count=163),
#  Row(word='stephen', count=162),
#  Row(word='gets', count=161),
#  Row(word='he', count=160),
#  Row(word='white', count=160),
#  Row(word='open', count=158),
#  Row(word='breaks', count=158),
#  Row(word='behind', count=158),
#  Row(word='scott', count=157),
#  Row(word='camila', count=157),
#  Row(word='history', count=157),
#  Row(word='fox', count=157),
#  Row(word='see', count=157),
#  Row(word='being', count=157),
#  Row(word='feat.', count=156),
#  Row(word='(ft.', count=156),
#  Row(word='jennifer', count=156),
#  Row(word='light', count=156),
#  Row(word='lost', count=155),
#  Row(word='lip', count=155),
#  Row(word='minutes', count=155),
#  Row(word='theory:', count=154),
#  Row(word='holiday', count=154),
#  Row(word='w/', count=152),
#  Row(word='e!', count=152),
#  Row(word='heart', count=151),
#  Row(word='makeover', count=151),
#  Row(word='high', count=151),
#  Row(word='justin', count=150),
#  Row(word='car', count=150),
#  Row(word='ice', count=150),
#  Row(word="i'm", count=150),
#  Row(word='interview', count=150),
#  Row(word='fan', count=149),
#  Row(word='call', count=149),
#  Row(word='family', count=148),
#  Row(word='marvel', count=148),
#  Row(word='scenes', count=147),
#  Row(word='bon', count=147),
#  Row(word='fashion', count=146),
#  Row(word='boy', count=145),
#  Row(word='vanity', count=145),
#  Row(word='again', count=144),
#  Row(word='shopping', count=144),
#  Row(word='old', count=144),
#  Row(word='good', count=143),
#  Row(word='dude', count=143),
#  Row(word='little', count=142),
#  Row(word='earth', count=141),
#  Row(word='doctor', count=141),
#  Row(word='plays', count=141),
#  Row(word='special', count=140),
#  Row(word='did', count=140)]

# %% [markdown]
# ### tags

# %%
from pyspark.sql.types import StringType, DoubleType, IntegerType, StructField, StructType
wordCount = spark.sql("SELECT LOWER(tags) as tags from df")\
                 .rdd.flatMap(lambda line:line['tags'].split("|"))\
                 .map(lambda word:(word,1)).reduceByKey(lambda a,b:a+b)\
                 .repartition(1).sortBy(lambda x:x[1],False)
wordCountSchema = StructType([StructField("word", StringType(), True),\
                              StructField("count", IntegerType(), True)])
wordCountDF = spark.createDataFrame(wordCount, wordCountSchema)
wordCountDF = wordCountDF.filter(wordCountDF["word"]!='')
wordCountDF.take(300)
# Out:
# [Row(word='"funny"', count=4136),
#  Row(word='"comedy"', count=3642),
#  Row(word='"how to"', count=1700),
#  Row(word='"music"', count=1659),
#  Row(word='"pop"', count=1632),
#  Row(word='[none]', count=1532),
#  Row(word='"trailer"', count=1411),
#  Row(word='"food"', count=1279),
#  Row(word='"2018"', count=1271),
#  Row(word='"news"', count=1253),
#  Row(word='"review"', count=1238),
#  Row(word='"science"', count=1237),
#  Row(word='"makeup"', count=1236),
#  Row(word='"humor"', count=1209),
#  Row(word='"celebrity"', count=1130),
#  Row(word='"diy"', count=1109),
#  Row(word='"tutorial"', count=1054),
#  Row(word='"video"', count=1029),
#  Row(word='"television"', count=1021),
#  Row(word='"live"', count=1017),
#  Row(word='"interview"', count=988),
#  Row(word='"vlog"', count=956),
#  Row(word='"entertainment"', count=949),
#  Row(word='"animation"', count=945),
#  Row(word='"beauty"', count=922),
#  Row(word='"movie"', count=908),
#  Row(word='"official"', count=895),
#  Row(word='"comedian"', count=877),
#  Row(word='"cooking"', count=864),
#  Row(word='"fun"', count=848),
#  Row(word='"hollywood"', count=846),
#  Row(word='"cute"', count=826),
#  Row(word='"buzzfeed"', count=800),
#  Row(word='"talk show"', count=788),
#  Row(word='"celebrities"', count=787),
#  Row(word='"late night"', count=782),
#  Row(word='"recipe"', count=778),
#  Row(word='"nbc"', count=758),
#  Row(word='"sports"', count=752),
#  Row(word='"family friendly"', count=751),
#  Row(word='"animals"', count=721),
#  Row(word='"best"', count=718),
#  Row(word='"education"', count=711),
#  Row(word='"music video"', count=711),
#  Row(word='"fashion"', count=695),
#  Row(word='"movies"', count=695),
#  Row(word='"challenge"', count=687),
#  Row(word='"records"', count=685),
#  Row(word='"2017"', count=676),
#  Row(word='"funny video"', count=675),
#  Row(word='"basketball"', count=655),
#  Row(word='"nba"', count=634),
#  Row(word='"jokes"', count=633),
#  Row(word='"film"', count=628),
#  Row(word='"marvel"', count=621),
#  Row(word='"technology"', count=619),
#  Row(word='"makeup tutorial"', count=607),
#  Row(word='"family"', count=603),
#  Row(word='"game"', count=602),
#  Row(word='"dance"', count=599),
#  Row(word='"documentary"', count=588),
#  Row(word='"new"', count=587),
#  Row(word='"christmas"', count=581),
#  Row(word='"show"', count=579),
#  Row(word='"snl"', count=578),
#  Row(word='"disney"', count=578),
#  Row(word='"sketch"', count=572),
#  Row(word='"drama"', count=567),
#  Row(word='"games"', count=566),
#  Row(word='"reaction"', count=551),
#  Row(word='"the"', count=543),
#  Row(word='"youtube"', count=535),
#  Row(word='"clip"', count=534),
#  Row(word='"highlights"', count=534),
#  Row(word='"love"', count=517),
#  Row(word='"football"', count=510),
#  Row(word='"animated"', count=509),
#  Row(word='"star wars"', count=507),
#  Row(word='"hilarious"', count=495),
#  Row(word='"funny videos"', count=494),
#  Row(word='"amazing"', count=480),
#  Row(word='"cbs"', count=479),
#  Row(word='"famous"', count=475),
#  Row(word='"parody"', count=474),
#  Row(word='"action"', count=461),
#  Row(word='"kids"', count=453),
#  Row(word='"politics"', count=452),
#  Row(word='"tv"', count=450),
#  Row(word='"lol"', count=449),
#  Row(word='"song"', count=446),
#  Row(word='"kitchen"', count=444),
#  Row(word='"chef"', count=443),
#  Row(word='"vlogger"', count=436),
#  Row(word='"laugh"', count=421),
#  Row(word='"joke"', count=420),
#  Row(word='"official trailer"', count=419),
#  Row(word='"bts"', count=415),
#  Row(word='"lifestyle"', count=414),
#  Row(word='"cook"', count=409),
#  Row(word='"health"', count=408),
#  Row(word='"cat"', count=407),
#  Row(word='"avengers"', count=404),
#  Row(word='"celeb"', count=400),
#  Row(word='"cosmetics"', count=400),
#  Row(word='"comedic"', count=395),
#  Row(word='"cats"', count=395),
#  Row(word='"to"', count=394),
#  Row(word='"country"', count=390),
#  Row(word='"host"', count=390),
#  Row(word='"james corden"', count=390),
#  Row(word='"react"', count=390),
#  Row(word='"netflix"', count=385),
#  Row(word='"cartoon"', count=381),
#  Row(word='"rap"', count=380),
#  Row(word='"nbc tv"', count=380),
#  Row(word='"olympics"', count=377),
#  Row(word='"highlight"', count=369),
#  Row(word='"unboxing"', count=366),
#  Row(word='"new york"', count=363),
#  Row(word='"alternative"', count=363),
#  Row(word='"official video"', count=357),
#  Row(word='"apple"', count=351),
#  Row(word='"home"', count=350),
#  Row(word='"talk"', count=349),
#  Row(word='"pets"', count=348),
#  Row(word='"black panther"', count=341),
#  Row(word='"alesso"', count=339),
#  Row(word='"watch"', count=338),
#  Row(word='"experiment"', count=335),
#  Row(word='"tech"', count=334),
#  Row(word='"trending"', count=333),
#  Row(word='"kitten"', count=331),
#  Row(word='"fox"', count=330),
#  Row(word='"chocolate"', count=330),
#  Row(word='"test"', count=329),
#  Row(word='"adventure"', count=329),
#  Row(word='"lelepons"', count=328),
#  Row(word='"shots"', count=328),
#  Row(word='"reviews"', count=327),
#  Row(word='"school"', count=326),
#  Row(word='"learn"', count=326),
#  Row(word='"epic"', count=325),
#  Row(word='"hannahstocking"', count=324),
#  Row(word='"rudymancuso"', count=324),
#  Row(word='"breaking news"', count=324),
#  Row(word='"style"', count=323),
#  Row(word='"educational"', count=321),
#  Row(word='"anitta"', count=318),
#  Row(word='"travel"', count=317),
#  Row(word='"talent"', count=317),
#  Row(word='"soccer"', count=316),
#  Row(word='"haul"', count=316),
#  Row(word='"fail"', count=313),
#  Row(word='"shotsstudios"', count=312),
#  Row(word='"bbc"', count=312),
#  Row(word='"anwar"', count=312),
#  Row(word='"donald trump"', count=307),
#  Row(word='"do it yourself"', count=306),
#  Row(word='"kim kardashian"', count=306),
#  Row(word='"nature"', count=306),
#  Row(word='"inanna"', count=305),
#  Row(word='"sarkis"', count=305),
#  Row(word='"how to make"', count=304),
#  Row(word='"brazil"', count=304),
#  Row(word='"history"', count=302),
#  Row(word='"satire"', count=298),
#  Row(word='"house"', count=297),
#  Row(word='"google"', count=296),
#  Row(word='"cardi b"', count=295),
#  Row(word='"us news"', count=295),
#  Row(word='"james charles"', count=295),
#  Row(word='"singing"', count=294),
#  Row(word='"the voice"', count=294),
#  Row(word='"easy"', count=292),
#  Row(word='"viral"', count=291),
#  Row(word='"plays"', count=291),
#  Row(word='"tasty"', count=290),
#  Row(word='"world news"', count=289),
#  Row(word='"james"', count=289),
#  Row(word='"challenges"', count=289),
#  Row(word='"abc"', count=288),
#  Row(word='"actor"', count=286),
#  Row(word='"stephen colbert"', count=285),
#  Row(word='"celebrity news"', count=283),
#  Row(word='"the late late show"', count=282),
#  Row(word='"amazon"', count=281),
#  Row(word='"sketch comedy"', count=280),
#  Row(word='"infinity war"', count=280),
#  Row(word='"super bowl"', count=279),
#  Row(word='"rca records label"', count=279),
#  Row(word='"iphone"', count=277),
#  Row(word='"wildlife"', count=277),
#  Row(word='"cool"', count=276),
#  Row(word='"friends"', count=275),
#  Row(word='"wwe"', count=273),
#  Row(word='"camila cabello"', count=273),
#  Row(word='"kelly clarkson"', count=272),
#  Row(word='"tricks"', count=271),
#  Row(word='"musician"', count=270),
#  Row(word='"trump"', count=268),
#  Row(word='"play"', count=266),
#  Row(word='"homemade"', count=265),
#  Row(word='"saturday night live"', count=263),
#  Row(word='"hd"', count=263),
#  Row(word='"colbert"', count=262),
#  Row(word='"space"', count=262),
#  Row(word='"complex media"', count=261),
#  Row(word='"complex"', count=261),
#  Row(word='"luxury"', count=261),
#  Row(word='"nfl"', count=259),
#  Row(word='"dogs"', count=259),
#  Row(word='"design"', count=258),
#  Row(word='"asmr"', count=258),
#  Row(word='"rhett and link"', count=258),
#  Row(word='"survival"', count=256),
#  Row(word='"late late show"', count=253),
#  Row(word='"corden"', count=253),
#  Row(word='"iphone x"', count=253),
#  Row(word='"kylie jenner"', count=253),
#  Row(word='"fidget spinners"', count=252),
#  Row(word='"wild"', count=251),
#  Row(word='"island"', count=251),
#  Row(word='"fine brothers"', count=250),
#  Row(word='"fbe"', count=250),
#  Row(word='"fine brothers entertainment"', count=250),
#  Row(word='"los angeles"', count=249),
#  Row(word='"how-to"', count=249),
#  Row(word='"thefinebros"', count=247),
#  Row(word='"american idol"', count=247),
#  Row(word='"dog"', count=246),
#  Row(word='"rock"', count=244),
#  Row(word='"hip hop"', count=244),
#  Row(word='"sing"', count=244),
#  Row(word='"espn"', count=243),
#  Row(word='"baking"', count=243),
#  Row(word='"makeover"', count=242),
#  Row(word='"cnn"', count=242),
#  Row(word='"competition"', count=242),
#  Row(word='"promo"', count=241),
#  Row(word='"boyfriend"', count=240),
#  Row(word='"weird"', count=240),
#  Row(word='"dating"', count=240),
#  Row(word='"ellen"', count=240),
#  Row(word='"lyrics"', count=238),
#  Row(word='"teaser"', count=237),
#  Row(word='"reality tv"', count=237),
#  Row(word='"the last jedi"', count=236),
#  Row(word='"r&b"', count=235),
#  Row(word='"youtuber"', count=234),
#  Row(word='"crazy"', count=234),
#  Row(word='"women"', count=233),
#  Row(word='"culture"', count=233),
#  Row(word='"transformation"', count=232),
#  Row(word='"interviews"', count=232),
#  Row(word='"bottle flip"', count=232),
#  Row(word='"streaming"', count=232),
#  Row(word='"fortnite"', count=231),
#  Row(word='"kid friendly"', count=230),
#  Row(word='"season"', count=230),
#  Row(word='"latest news"', count=230),
#  Row(word='"cake"', count=230),
#  Row(word='"gossip"', count=230),
#  Row(word='"holiday"', count=229),
#  Row(word='"hair"', count=229),
#  Row(word='"top 10"', count=228),
#  Row(word='"kanye west"', count=227),
#  Row(word='"tips"', count=227),
#  Row(word='"try"', count=227),
#  Row(word='"fitness"', count=227),
#  Row(word='"simon"', count=226),
#  Row(word='"sp:ty=high"', count=225),
#  Row(word='"future"', count=225),
#  Row(word='"how"', count=224),
#  Row(word='"reality"', count=223),
#  Row(word='"make"', count=223),
#  Row(word='"british"', count=221),
#  Row(word='"meghan markle"', count=221),
#  Row(word='"variety"', count=220),
#  Row(word='"australia"', count=220),
#  Row(word='"drugstore"', count=220),
#  Row(word='"improv"', count=220),
#  Row(word='"cover"', count=220),
#  Row(word='"performance"', count=220),
#  Row(word='"beyonce"', count=219),
#  Row(word='"of"', count=219),
#  Row(word='"comics"', count=218),
#  Row(word='"money"', count=218),
#  Row(word='"relationships"', count=217),
#  Row(word='"stand-up"', count=217),
#  Row(word='"hacks"', count=217),
#  Row(word='"vlogging"', count=215),
#  Row(word='"clean"', count=215),
#  Row(word='"vlogs"', count=215),
#  Row(word='"food porn"', count=214),
#  Row(word='"nbc news"', count=214),
#  Row(word='"screen junkies"', count=213),
#  Row(word='"screenjunkies"', count=213),
#  Row(word='"gaming"', count=213),
#  Row(word='"slow motion"', count=212),
#  Row(word='"tonight"', count=212)]

# %%
# the most popular tags
tags = spark.sql("SELECT tags, COUNT(*) as freq FROM df GROUP BY tags ORDER BY freq DESC")
tags.show(10)
# Out:
# +------------------------+----+
# |                    tags|freq|
# +------------------------+----+
# |                  [none]|1532|
# |    "ABC"|"americanid...|  86|
# |    "Jacksfilms"|"Jac...|  79|
# |    "James Corden"|"T...|  71|
# |    "The Late Show"|"...|  66|
# |"BIGHIT"|"빅히트"|"방...|  54|
# |    "Super Slow Show"...|  50|
# |    "Viral"|"Video"|"...|  46|
# |    "best vines 2018"...|  46|
# |    "Pentatonix"|"Pen...|  43|
# +------------------------+----+
# only showing top 10 rows

# %%
df.filter("tags==''").show(truncate=False)
# Out:
# +-----------+-------------+-----+-------------+------------+----+-----+-----+--------+-------------+--------------+
# |category_id|trending_date|title|channel_title|publish_time|tags|views|likes|dislikes|comment_count|category_title|
# +-----------+-------------+-----+-------------+------------+----+-----+-----+--------+-------------+--------------+
# +-----------+-------------+-----+-------------+------------+----+-----+-----+--------+-------------+--------------+

# %% [markdown]
# ##### other data

# %%
df = spark.read.csv('/Users/zhujinghong/Downloads/5003\ project/pre_data/US_pre.csv',header=True)

# %%
df.createOrReplaceTempView("df")

# %%
from pyspark.sql.types import StringType, DoubleType, IntegerType, StructField, StructType
wordCount = spark.sql("SELECT LOWER(tags) as tags from df")\
                 .rdd.flatMap(lambda line:line['tags'].split("|")).map(lambda word:(word,1)).reduceByKey(lambda a,b:a+b).repartition(1).sortBy(lambda x:x[1],False)
wordCountSchema = StructType([StructField("word", StringType(), True),StructField("count", IntegerType(), True)])
wordCountDF = spark.createDataFrame(wordCount, wordCountSchema)
wordCountDF = wordCountDF.filter(wordCountDF["word"]!='')
wordCountDF.take(300)
# Out:
# [Row(word='"funny"', count=4136),
#  Row(word='"comedy"', count=3642),
#  Row(word='"how to"', count=1700),
#  Row(word='"music"', count=1659),
#  Row(word='"pop"', count=1632),
#  Row(word='[none]', count=1532),
#  Row(word='"trailer"', count=1411),
#  Row(word='"food"', count=1279),
#  Row(word='"2018"', count=1271),
#  Row(word='"news"', count=1253),
#  Row(word='"review"', count=1238),
#  Row(word='"science"', count=1237),
#  Row(word='"makeup"', count=1236),
#  Row(word='"humor"', count=1209),
#  Row(word='"celebrity"', count=1130),
#  Row(word='"diy"', count=1109),
#  Row(word='"tutorial"', count=1054),
#  Row(word='"video"', count=1029),
#  Row(word='"television"', count=1021),
#  Row(word='"live"', count=1017),
#  Row(word='"interview"', count=988),
#  Row(word='"vlog"', count=956),
#  Row(word='"entertainment"', count=949),
#  Row(word='"animation"', count=945),
#  Row(word='"beauty"', count=922),
#  Row(word='"movie"', count=908),
#  Row(word='"official"', count=895),
#  Row(word='"comedian"', count=877),
#  Row(word='"cooking"', count=864),
#  Row(word='"fun"', count=848),
#  Row(word='"hollywood"', count=846),
#  Row(word='"cute"', count=826),
#  Row(word='"buzzfeed"', count=800),
#  Row(word='"talk show"', count=788),
#  Row(word='"celebrities"', count=787),
#  Row(word='"late night"', count=782),
#  Row(word='"recipe"', count=778),
#  Row(word='"nbc"', count=758),
#  Row(word='"sports"', count=752),
#  Row(word='"family friendly"', count=751),
#  Row(word='"animals"', count=721),
#  Row(word='"best"', count=718),
#  Row(word='"education"', count=711),
#  Row(word='"music video"', count=711),
#  Row(word='"fashion"', count=695),
#  Row(word='"movies"', count=695),
#  Row(word='"challenge"', count=687),
#  Row(word='"records"', count=685),
#  Row(word='"2017"', count=676),
#  Row(word='"funny video"', count=675),
#  Row(word='"basketball"', count=655),
#  Row(word='"nba"', count=634),
#  Row(word='"jokes"', count=633),
#  Row(word='"film"', count=628),
#  Row(word='"marvel"', count=621),
#  Row(word='"technology"', count=619),
#  Row(word='"makeup tutorial"', count=607),
#  Row(word='"family"', count=603),
#  Row(word='"game"', count=602),
#  Row(word='"dance"', count=599),
#  Row(word='"documentary"', count=588),
#  Row(word='"new"', count=587),
#  Row(word='"christmas"', count=581),
#  Row(word='"show"', count=579),
#  Row(word='"snl"', count=578),
#  Row(word='"disney"', count=578),
#  Row(word='"sketch"', count=572),
#  Row(word='"drama"', count=567),
#  Row(word='"games"', count=566),
#  Row(word='"reaction"', count=551),
#  Row(word='"the"', count=543),
#  Row(word='"youtube"', count=535),
#  Row(word='"clip"', count=534),
#  Row(word='"highlights"', count=534),
#  Row(word='"love"', count=517),
#  Row(word='"football"', count=510),
#  Row(word='"animated"', count=509),
#  Row(word='"star wars"', count=507),
#  Row(word='"hilarious"', count=495),
#  Row(word='"funny videos"', count=494),
#  Row(word='"amazing"', count=480),
#  Row(word='"cbs"', count=479),
#  Row(word='"famous"', count=475),
#  Row(word='"parody"', count=474),
#  Row(word='"action"', count=461),
#  Row(word='"kids"', count=453),
#  Row(word='"politics"', count=452),
#  Row(word='"tv"', count=450),
#  Row(word='"lol"', count=449),
#  Row(word='"song"', count=446),
#  Row(word='"kitchen"', count=444),
#  Row(word='"chef"', count=443),
#  Row(word='"vlogger"', count=436),
#  Row(word='"laugh"', count=421),
#  Row(word='"joke"', count=420),
#  Row(word='"official trailer"', count=419),
#  Row(word='"bts"', count=415),
#  Row(word='"lifestyle"', count=414),
#  Row(word='"cook"', count=409),
#  Row(word='"health"', count=408),
#  Row(word='"cat"', count=407),
#  Row(word='"avengers"', count=404),
#  Row(word='"celeb"', count=400),
#  Row(word='"cosmetics"', count=400),
#  Row(word='"comedic"', count=395),
#  Row(word='"cats"', count=395),
#  Row(word='"to"', count=394),
#  Row(word='"country"', count=390),
#  Row(word='"host"', count=390),
#  Row(word='"james corden"', count=390),
#  Row(word='"react"', count=390),
#  Row(word='"netflix"', count=385),
#  Row(word='"cartoon"', count=381),
#  Row(word='"rap"', count=380),
#  Row(word='"nbc tv"', count=380),
#  Row(word='"olympics"', count=377),
#  Row(word='"highlight"', count=369),
#  Row(word='"unboxing"', count=366),
#  Row(word='"new york"', count=363),
#  Row(word='"alternative"', count=363),
#  Row(word='"official video"', count=357),
#  Row(word='"apple"', count=351),
#  Row(word='"home"', count=350),
#  Row(word='"talk"', count=349),
#  Row(word='"pets"', count=348),
#  Row(word='"black panther"', count=341),
#  Row(word='"alesso"', count=339),
#  Row(word='"watch"', count=338),
#  Row(word='"experiment"', count=335),
#  Row(word='"tech"', count=334),
#  Row(word='"trending"', count=333),
#  Row(word='"kitten"', count=331),
#  Row(word='"fox"', count=330),
#  Row(word='"chocolate"', count=330),
#  Row(word='"test"', count=329),
#  Row(word='"adventure"', count=329),
#  Row(word='"lelepons"', count=328),
#  Row(word='"shots"', count=328),
#  Row(word='"reviews"', count=327),
#  Row(word='"school"', count=326),
#  Row(word='"learn"', count=326),
#  Row(word='"epic"', count=325),
#  Row(word='"hannahstocking"', count=324),
#  Row(word='"rudymancuso"', count=324),
#  Row(word='"breaking news"', count=324),
#  Row(word='"style"', count=323),
#  Row(word='"educational"', count=321),
#  Row(word='"anitta"', count=318),
#  Row(word='"travel"', count=317),
#  Row(word='"talent"', count=317),
#  Row(word='"soccer"', count=316),
#  Row(word='"haul"', count=316),
#  Row(word='"fail"', count=313),
#  Row(word='"shotsstudios"', count=312),
#  Row(word='"bbc"', count=312),
#  Row(word='"anwar"', count=312),
#  Row(word='"donald trump"', count=307),
#  Row(word='"do it yourself"', count=306),
#  Row(word='"kim kardashian"', count=306),
#  Row(word='"nature"', count=306),
#  Row(word='"inanna"', count=305),
#  Row(word='"sarkis"', count=305),
#  Row(word='"how to make"', count=304),
#  Row(word='"brazil"', count=304),
#  Row(word='"history"', count=302),
#  Row(word='"satire"', count=298),
#  Row(word='"house"', count=297),
#  Row(word='"google"', count=296),
#  Row(word='"cardi b"', count=295),
#  Row(word='"us news"', count=295),
#  Row(word='"james charles"', count=295),
#  Row(word='"singing"', count=294),
#  Row(word='"the voice"', count=294),
#  Row(word='"easy"', count=292),
#  Row(word='"viral"', count=291),
#  Row(word='"plays"', count=291),
#  Row(word='"tasty"', count=290),
#  Row(word='"world news"', count=289),
#  Row(word='"james"', count=289),
#  Row(word='"challenges"', count=289),
#  Row(word='"abc"', count=288),
#  Row(word='"actor"', count=286),
#  Row(word='"stephen colbert"', count=285),
#  Row(word='"celebrity news"', count=283),
#  Row(word='"the late late show"', count=282),
#  Row(word='"amazon"', count=281),
#  Row(word='"sketch comedy"', count=280),
#  Row(word='"infinity war"', count=280),
#  Row(word='"super bowl"', count=279),
#  Row(word='"rca records label"', count=279),
#  Row(word='"iphone"', count=277),
#  Row(word='"wildlife"', count=277),
#  Row(word='"cool"', count=276),
#  Row(word='"friends"', count=275),
#  Row(word='"wwe"', count=273),
#  Row(word='"camila cabello"', count=273),
#  Row(word='"kelly clarkson"', count=272),
#  Row(word='"tricks"', count=271),
#  Row(word='"musician"', count=270),
#  Row(word='"trump"', count=268),
#  Row(word='"play"', count=266),
#  Row(word='"homemade"', count=265),
#  Row(word='"saturday night live"', count=263),
#  Row(word='"hd"', count=263),
#  Row(word='"colbert"', count=262),
#  Row(word='"space"', count=262),
#  Row(word='"complex media"', count=261),
#  Row(word='"complex"', count=261),
#  Row(word='"luxury"', count=261),
#  Row(word='"nfl"', count=259),
#  Row(word='"dogs"', count=259),
#  Row(word='"design"', count=258),
#  Row(word='"asmr"', count=258),
#  Row(word='"rhett and link"', count=258),
#  Row(word='"survival"', count=256),
#  Row(word='"late late show"', count=253),
#  Row(word='"corden"', count=253),
#  Row(word='"iphone x"', count=253),
#  Row(word='"kylie jenner"', count=253),
#  Row(word='"fidget spinners"', count=252),
#  Row(word='"wild"', count=251),
#  Row(word='"island"', count=251),
#  Row(word='"fine brothers"', count=250),
#  Row(word='"fbe"', count=250),
#  Row(word='"fine brothers entertainment"', count=250),
#  Row(word='"los angeles"', count=249),
#  Row(word='"how-to"', count=249),
#  Row(word='"thefinebros"', count=247),
#  Row(word='"american idol"', count=247),
#  Row(word='"dog"', count=246),
#  Row(word='"rock"', count=244),
#  Row(word='"hip hop"', count=244),
#  Row(word='"sing"', count=244),
#  Row(word='"espn"', count=243),
#  Row(word='"baking"', count=243),
#  Row(word='"makeover"', count=242),
#  Row(word='"cnn"', count=242),
#  Row(word='"competition"', count=242),
#  Row(word='"promo"', count=241),
#  Row(word='"boyfriend"', count=240),
#  Row(word='"weird"', count=240),
#  Row(word='"dating"', count=240),
#  Row(word='"ellen"', count=240),
#  Row(word='"lyrics"', count=238),
#  Row(word='"teaser"', count=237),
#  Row(word='"reality tv"', count=237),
#  Row(word='"the last jedi"', count=236),
#  Row(word='"r&b"', count=235),
#  Row(word='"youtuber"', count=234),
#  Row(word='"crazy"', count=234),
#  Row(word='"women"', count=233),
#  Row(word='"culture"', count=233),
#  Row(word='"transformation"', count=232),
#  Row(word='"interviews"', count=232),
#  Row(word='"bottle flip"', count=232),
#  Row(word='"streaming"', count=232),
#  Row(word='"fortnite"', count=231),
#  Row(word='"kid friendly"', count=230),
#  Row(word='"season"', count=230),
#  Row(word='"latest news"', count=230),
#  Row(word='"cake"', count=230),
#  Row(word='"gossip"', count=230),
#  Row(word='"holiday"', count=229),
#  Row(word='"hair"', count=229),
#  Row(word='"top 10"', count=228),
#  Row(word='"kanye west"', count=227),
#  Row(word='"tips"', count=227),
#  Row(word='"try"', count=227),
#  Row(word='"fitness"', count=227),
#  Row(word='"simon"', count=226),
#  Row(word='"sp:ty=high"', count=225),
#  Row(word='"future"', count=225),
#  Row(word='"how"', count=224),
#  Row(word='"reality"', count=223),
#  Row(word='"make"', count=223),
#  Row(word='"british"', count=221),
#  Row(word='"meghan markle"', count=221),
#  Row(word='"variety"', count=220),
#  Row(word='"australia"', count=220),
#  Row(word='"drugstore"', count=220),
#  Row(word='"improv"', count=220),
#  Row(word='"cover"', count=220),
#  Row(word='"performance"', count=220),
#  Row(word='"beyonce"', count=219),
#  Row(word='"of"', count=219),
#  Row(word='"comics"', count=218),
#  Row(word='"money"', count=218),
#  Row(word='"relationships"', count=217),
#  Row(word='"stand-up"', count=217),
#  Row(word='"hacks"', count=217),
#  Row(word='"vlogging"', count=215),
#  Row(word='"clean"', count=215),
#  Row(word='"vlogs"', count=215),
#  Row(word='"food porn"', count=214),
#  Row(word='"nbc news"', count=214),
#  Row(word='"screen junkies"', count=213),
#  Row(word='"screenjunkies"', count=213),
#  Row(word='"gaming"', count=213),
#  Row(word='"slow motion"', count=212),
#  Row(word='"tonight"', count=212)]

# %% [markdown]
# ### pubilish_time

# %%
pubTime = spark.sql("SELECT publish_time as pub from df")\
               .rdd.flatMap(lambda x: x).map(lambda x: (x,x[11:13]))
pubTimeSchema = StructType([StructField("publish_time", StringType(), True),\
                            StructField("time", StringType(), True)])
pubTimeDF = spark.createDataFrame(pubTime, pubTimeSchema)
pubTimeDF = pubTimeDF.filter(pubTimeDF["time"]!='')
pubTimeDF.createOrReplaceTempView("pubTimeDF")
time_distribution = spark.sql("SELECT time, COUNT(*) as freq FROM pubTimeDF\
                               GROUP BY time, time ORDER BY freq DESC")
time_distribution.show()
# Out:
# +----+----+
# |time|freq|
# +----+----+
# |  16|3664|
# |  15|3478|
# |  17|3446|
# |  18|2885|
# |  14|2805|
# |  20|2133|
# |  19|2124|
# |  21|2101|
# |  13|2098|
# |  22|1957|
# |  12|1550|
# |  23|1495|
# |  00|1436|
# |  01|1318|
# |  04|1259|
# |  05|1252|
# |  03| 944|
# |  02| 935|
# |  11| 855|
# |  08| 790|
# +----+----+
# only showing top 20 rows
