# %%
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.feature import VectorIndexer
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml import Pipeline
from pyspark.ml.linalg import Vectors
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import *
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.sql import Row
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import functions as F
from pyspark.mllib.evaluation import RegressionMetrics
from pyspark.ml.evaluation import RegressionEvaluator

# %%
vids = spark.read.csv('./US_pre.csv', inferSchema=True, header='True')

# %%
vids.printSchema()
# Out:
# root
#  |-- category_id: integer (nullable = true)
#  |-- trending_date: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- publish_time: timestamp (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- views: integer (nullable = true)
#  |-- likes: integer (nullable = true)
#  |-- dislikes: integer (nullable = true)
#  |-- comment_count: integer (nullable = true)
#  |-- category_title: string (nullable = true)

# %%
vids.show()
# Out:
# +-----------+-------------+--------------------+------------------+-------------------+--------------------+-------+------+--------+-------------+--------------------+
# |category_id|trending_date|               title|     channel_title|       publish_time|                tags|  views| likes|dislikes|comment_count|      category_title|
# +-----------+-------------+--------------------+------------------+-------------------+--------------------+-------+------+--------+-------------+--------------------+
# |         10|     18.30.01|DJ Khaled, Rihann...|      Super Netvid|2018-01-29 11:11:56|              [none]|3014847| 42556|    2791|            0|               Music|
# |         22|     18.03.01|The Queen's Chris...|  The Royal Family|2017-12-25 23:02:43|              [none]|2497549| 51959|    6265|            0|      People & Blogs|
# |         24|     17.10.12|Little Mix bring ...|   The X Factor UK|2017-12-04 03:47:01|"the x factor"|"x...|5275288|169795|    3706|            0|       Entertainment|
# |         27|     18.03.01|Oh What a Feeling...|      Kevin Noonan|2013-05-28 08:02:49|              [none]|  13630|    42|       1|            8|           Education|
# |         25|     17.23.11|Additional Remain...|         CBS Miami|2017-11-22 01:26:32|"CBS 4 News Morni...|   1095|     8|       2|           13|     News & Politics|
# |         17|     18.23.01|  Urban opera singer|    Marcos Horacio|2018-01-20 01:26:11|              [none]|   7288|   145|       6|           17|              Sports|
# |         17|     17.20.11|Ben Simmons | Hig...|Philadelphia 76ers|2017-11-16 14:26:28|"Philadelphia"|"7...|  14609|    89|       5|           36|              Sports|
# |         23|     18.07.02|Barstool Rundown ...|   Barstool Sports|2018-02-06 11:01:37|"barstool sports"...|  20063|   168|      21|           43|              Comedy|
# |          1|     17.05.12|Josh Gordon - I'm...|  Vote The Process|2017-11-30 09:29:36|"iMovie"|"Clevela...|  88657|   593|      27|           52|    Film & Animation|
# |         24|     18.12.01|Gerard Butler le ...| Despierta América|2018-01-11 23:24:38|"ana patricia gam...|  16976|   314|      13|           53|       Entertainment|
# |         24|     17.30.11|Los Angeles’s Dan...|    The New Yorker|2017-11-29 01:00:29|"car chase"|"los ...|  41471|   388|      39|           67|       Entertainment|
# |         26|     17.02.12|Free Fall Ride In...|           INSIDER|2017-12-01 00:37:38|"travel"|"stunt"|...|  18246|   510|       1|           79|       Howto & Style|
# |         26|     17.17.12|Makeup Bag Lets Y...|           INSIDER|2017-12-14 01:07:49|"travel smarter"|...|  41265|   881|      25|           81|       Howto & Style|
# |         10|     18.06.02|TROY AVE - 2 LEGI...|       DopeBoyTroy|2018-02-01 10:01:32|"drake"|"21 savag...|  19722|   203|      80|           92|               Music|
# |          1|     17.08.12|A VERY SPECIAL DA...|        Arden Rose|2017-12-03 02:14:51|"day in my life"|...|  75279|  3424|      77|          108|    Film & Animation|
# |         10|     17.20.12|Ciara - Santa Bab...|   cicigoodies2011|2017-12-15 13:13:47|"Ciara"|"cici"|"c...|  27765|   580|      25|          109|               Music|
# |         17|     17.13.12|NBA Daily Show: D...|               NBA|2017-12-09 08:46:19|"nba"|"basketball...| 117586|  1566|      60|          150|              Sports|
# |         26|     17.09.12|I Got Transformed...|        Refinery29|2017-12-08 00:00:07|"refinery29"|"ref...|  50538|  1584|      39|          152|       Howto & Style|
# |         24|     18.05.01|Jessica Chastain'...| Jimmy Kimmel Live|2018-01-04 18:00:00|"jimmy"|"kimmel"|...|  82052|  1519|      68|          182|       Entertainment|
# |         28|     18.26.01|01/24/2018 - Falc...|    Dennis Kapatos|2018-01-25 01:39:31|"SpaceX"|"Test Fi...| 147899|  1441|      45|          184|Science & Technology|
# +-----------+-------------+--------------------+------------------+-------------------+--------------------+-------+------+--------+-------------+--------------------+
# only showing top 20 rows

# %%
# Drop columns we are not using.
df = vids.select('category_id','tags','views').withColumnRenamed("views","label")
df.cache()
df.show()
# Out:
# +-----------+--------------------+-------+
# |category_id|                tags|  label|
# +-----------+--------------------+-------+
# |         10|              [none]|3014847|
# |         22|              [none]|2497549|
# |         24|"the x factor"|"x...|5275288|
# |         27|              [none]|  13630|
# |         25|"CBS 4 News Morni...|   1095|
# |         17|              [none]|   7288|
# |         17|"Philadelphia"|"7...|  14609|
# |         23|"barstool sports"...|  20063|
# |          1|"iMovie"|"Clevela...|  88657|
# |         24|"ana patricia gam...|  16976|
# |         24|"car chase"|"los ...|  41471|
# |         26|"travel"|"stunt"|...|  18246|
# |         26|"travel smarter"|...|  41265|
# |         10|"drake"|"21 savag...|  19722|
# |          1|"day in my life"|...|  75279|
# |         10|"Ciara"|"cici"|"c...|  27765|
# |         17|"nba"|"basketball...| 117586|
# |         26|"refinery29"|"ref...|  50538|
# |         24|"jimmy"|"kimmel"|...|  82052|
# |         28|"SpaceX"|"Test Fi...| 147899|
# +-----------+--------------------+-------+
# only showing top 20 rows

# %%
tokenizer = RegexTokenizer(inputCol="tags", outputCol="words", pattern="\|")
tokenized = tokenizer.transform(df)
tokenized.cache()
tokenized.show()
# Out:
# +-----------+--------------------+-------+--------------------+
# |category_id|                tags|  label|               words|
# +-----------+--------------------+-------+--------------------+
# |         10|              [none]|3014847|            [[none]]|
# |         22|              [none]|2497549|            [[none]]|
# |         24|"the x factor"|"x...|5275288|["the x factor", ...|
# |         27|              [none]|  13630|            [[none]]|
# |         25|"CBS 4 News Morni...|   1095|["cbs 4 news morn...|
# |         17|              [none]|   7288|            [[none]]|
# |         17|"Philadelphia"|"7...|  14609|["philadelphia", ...|
# |         23|"barstool sports"...|  20063|["barstool sports...|
# |          1|"iMovie"|"Clevela...|  88657|["imovie", "cleve...|
# |         24|"ana patricia gam...|  16976|["ana patricia ga...|
# |         24|"car chase"|"los ...|  41471|["car chase", "lo...|
# |         26|"travel"|"stunt"|...|  18246|["travel", "stunt...|
# |         26|"travel smarter"|...|  41265|["travel smarter"...|
# |         10|"drake"|"21 savag...|  19722|["drake", "21 sav...|
# |          1|"day in my life"|...|  75279|["day in my life"...|
# |         10|"Ciara"|"cici"|"c...|  27765|["ciara", "cici",...|
# |         17|"nba"|"basketball...| 117586|["nba", "basketba...|
# |         26|"refinery29"|"ref...|  50538|["refinery29", "r...|
# |         24|"jimmy"|"kimmel"|...|  82052|["jimmy", "kimmel...|
# |         28|"SpaceX"|"Test Fi...| 147899|["spacex", "test ...|
# +-----------+--------------------+-------+--------------------+
# only showing top 20 rows

# %%
word = tokenized.withColumn("exp", F.explode('words')).select('exp')
word.show()
# Out:
# +--------------------+
# |                 exp|
# +--------------------+
# |              [none]|
# |              [none]|
# |      "the x factor"|
# |          "x factor"|
# |       "x factor uk"|
# |     "x factor 2017"|
# |      "simon cowell"|
# |            "nicole"|
# |            "sharon"|
# |             "louis"|
# |            "talent"|
# |         "auditions"|
# |            "judges"|
# |         "season 14"|
# |         "series 14"|
# |  "x factor uk 2017"|
# |"x factor 2017 au...|
# | "the x factor 2017"|
# |      "xfactor 2017"|
# |               "itv"|
# +--------------------+
# only showing top 20 rows

# %%
fq = word.groupby('exp').count()
fq = fq.filter(col('count') > 10).collect()
fq = [i['exp'] for i in fq]
print(fq)
# Out:
# ['"yachty"', '"soccer"', '"king tutorial"', '"pink cakes"', '"kelp shake"', '"नृत्य"', '"pll"', '"merrelltwins"', '"jack ryan"', '"doughnuts"', '"black friday tech deals"', '"television online"', '"plvahqwmqn4m0mgkarahh7scvveepibvye"', '"street food in mexico"', '"era istrefi"', '"elastigirl"', '"뮤비"', '"idris elba"', '"antoni"', '"shawn mendes singing"', '"watch vines"', '"the 10s"', '"atm"', '"brilliant"', '"sanchez"', '"grant gustin"', '"foster the people"', '"ham"', '"dog asmr"', '"hijacks dating account"', '"padilla"', '"nike lebron 15"', '"love tweet"', '"salt"', '"danisnotonfire"', '"supercomputer"', '"normani"', '"gymnastics tricks"', '"weird korean beauty products"', '"orc"', '"sims 4 trailer"', '"hogwarts"', '"the voice new season"', '"gramercy tavern"', '"marcus and lucas"', '"activision"', '"chapstick"', '"end scene"', '"cooker"', '"이대휘"', '"everyday struggle"', '"jersey city"', '"the triple crown"', '"lignum vitae"', '"lil xan color blind"', '"rotten tomatoes"', '"rio"', '"bowling ball oobleck"', '"willa fitzgerald"', '"stolen money"', '"strength training"', '"it\'s alive"', '"food mukbang"', '"papers please game"', '"ultra music"', '"posh"', '"key and peele"', '"fahrenheit 451"', '"epic/nuyorican productions"', '"processor"', '"funny puppy videos"', '"90th academy awards"', '"flood"', '"hysteria"', '"prime"', '"autopilot"', '"john f. kennedy"', '"18 million subscribers"', '"whats in the box dude perfect"', '"iphone x hands on"', '"갓세븐 뮤비"', '"#hurtbae video"', '"5 min makeup challenge"', '"unicorn poop"', '"hands"', '"utah jazz"', '"bayern munich"', '"pregnancy"', '"album"', '"jane bond"', '"plectronoceras"', '"deli meat how it\'s made"', '"slow motion"', '"pretty girl"', '"the spectre"', '"release"', '"nail art"', '"christopher robin"', '"doctor watches the good doctor"', '"edition"', '"el anillo letra"', '"fnaf ending"', '"lewis"', '"stylish hats for men"', '"international space station"', '"purchased"', '"vr"', '"rose tico"', '"daimler"', '"suit"', '"신곡"', '"sivan"', '"full episode"', '"fitness"', '"mca"', '"yardie"', '"shawn mendes essential"', '"selena gomez kidney"', '"10 signs you\'re more intelligent than you think"', '"songs"', '"lsd vevo"', '"pokemon champion"', '"pokedex game theory"', '"savory"', '"hijacks tinder"', '"implosion"', '"daily tour vlog"', '"invisible box"', '"ie trending"', '"sampler"', '"hardy boyz"', '"엔시티 드림"', '"thismightget"', '"forging elite fitness"', '"rachel demita"', '"headphones"', '"melting"', '"what i eat"', '"faze rug emotional"', '"wolverine"', '"hilarious clips"', '"tasty food india"', '"destination wedding trailer 2018"', '"diy activities"', '"afc"', '"vs fashion show"', '"comparison"', '"truck"', '"yg"', '"kylie cosmetics swatches"', '"figure skating 2018 winter olympics"', '"tampa bay lightning"', '"funk bros"', '"bully"', '"jess and gabriel"', '"electric"', '"minnnie mouse"', '"blocks"', '"symbol"', '"fermented"', '"natti natasha video"', '"champions"', '"sweet southern sugar"', '"73 questions interview"', '"costume designer"', '"90th"', '"flights"', '"odd"', '"gas engine"', '"edward snowden"', '"ghost hunting"', '"stevecash83"', '"canciones"', '"coffee benefits"', '"iphone 6"', '"dyson vacuum"', '"illumination"', '"ted ed"', '"rucker classic"', '"nerf challenge"', '"hi 5 studios"', '"eruption"', '"laugh challenge"', '"bitten by a lizard"', '"meghan markle 2018"', '"sp:st=wrestling"', '"xbox one"', '"figures"', '"entertainment tonight"', '"of"', '"men"', '"best street food"', '"house shopping"', '"bedroom tour"', '"vevo"', '"i tried to recreate my favorite artist\'s work with makeup"', '"pop country"', '"manjeet"', '"white power"', '"how to speak"', '"str"', '"single"', '"snoop dogg"', '"casino"', '"george ezra graham norton"', '"tobias harris"', '"bleecker street media"', '"cozy apartment"', '"documentary trailer"', '"shiba"', '"dogs are awesome"', '"designer vs artist"', '"all-star"', '"tlc"', '"nature documentary"', '"ryland"', '"stitiches"', '"fancy vlogs by gab"', ...

# %%
final = tokenized.rdd.map(lambda x: (x.category_id, [i for i in x.words if i in fq], x.label))
final = spark.createDataFrame(final).toDF('id', 'words','label')
final = final.rdd.map(lambda x: (x.id, x.words if (len(x.words)>0) else ['[none]'] , x.label))
final = spark.createDataFrame(final).toDF('id', 'words','label')
final.show()
# Out:
# +---+--------------------+-------+
# | id|               words|  label|
# +---+--------------------+-------+
# | 10|            [[none]]|3014847|
# | 22|            [[none]]|2497549|
# | 24|["the x factor", ...|5275288|
# | 27|            [[none]]|  13630|
# | 25|            [[none]]|   1095|
# | 17|            [[none]]|   7288|
# | 17|["philadelphia", ...|  14609|
# | 23|["sports news", "...|  20063|
# |  1|["weed", "addicti...|  88657|
# | 24|["gerard butler",...|  16976|
# | 24|["los angeles", "...|  41471|
# | 26|["travel", "stunt...|  18246|
# | 26|["travel smarter"...|  41265|
# | 10|["drake", "21 sav...|  19722|
# |  1|["vlog", "vloggin...|  75279|
# | 10|["ciara", "christ...|  27765|
# | 17|["nba", "basketba...| 117586|
# | 26|["refinery29", "r...|  50538|
# | 24|["jimmy", "kimmel...|  82052|
# | 28|["spacex", "nasa"...| 147899|
# +---+--------------------+-------+
# only showing top 20 rows

# %%
final = final.withColumn('id_list', F.array(final.id))
final = final.withColumn('merged', concat(final.id_list, final.words))
final.show()
# Out:
# +---+--------------------+-------+-------+--------------------+
# | id|               words|  label|id_list|              merged|
# +---+--------------------+-------+-------+--------------------+
# | 10|            [[none]]|3014847|   [10]|        [10, [none]]|
# | 22|            [[none]]|2497549|   [22]|        [22, [none]]|
# | 24|["the x factor", ...|5275288|   [24]|[24, "the x facto...|
# | 27|            [[none]]|  13630|   [27]|        [27, [none]]|
# | 25|            [[none]]|   1095|   [25]|        [25, [none]]|
# | 17|            [[none]]|   7288|   [17]|        [17, [none]]|
# | 17|["philadelphia", ...|  14609|   [17]|[17, "philadelphi...|
# | 23|["sports news", "...|  20063|   [23]|[23, "sports news...|
# |  1|["weed", "addicti...|  88657|    [1]|[1, "weed", "addi...|
# | 24|["gerard butler",...|  16976|   [24]|[24, "gerard butl...|
# | 24|["los angeles", "...|  41471|   [24]|[24, "los angeles...|
# | 26|["travel", "stunt...|  18246|   [26]|[26, "travel", "s...|
# | 26|["travel smarter"...|  41265|   [26]|[26, "travel smar...|
# | 10|["drake", "21 sav...|  19722|   [10]|[10, "drake", "21...|
# |  1|["vlog", "vloggin...|  75279|    [1]|[1, "vlog", "vlog...|
# | 10|["ciara", "christ...|  27765|   [10]|[10, "ciara", "ch...|
# | 17|["nba", "basketba...| 117586|   [17]|[17, "nba", "bask...|
# | 26|["refinery29", "r...|  50538|   [26]|[26, "refinery29"...|
# | 24|["jimmy", "kimmel...|  82052|   [24]|[24, "jimmy", "ki...|
# | 28|["spacex", "nasa"...| 147899|   [28]|[28, "spacex", "n...|
# +---+--------------------+-------+-------+--------------------+
# only showing top 20 rows

# %%
hashingTF = HashingTF(inputCol='merged', outputCol="features", numFeatures = 2048)
hashed = hashingTF.transform(final)
hashed.show()
# Out:
# +---+--------------------+-------+-------+--------------------+--------------------+
# | id|               words|  label|id_list|              merged|            features|
# +---+--------------------+-------+-------+--------------------+--------------------+
# | 10|            [[none]]|3014847|   [10]|        [10, [none]]|(2048,[465,1969],...|
# | 22|            [[none]]|2497549|   [22]|        [22, [none]]|(2048,[465,1325],...|
# | 24|["the x factor", ...|5275288|   [24]|[24, "the x facto...|(2048,[45,51,94,2...|
# | 27|            [[none]]|  13630|   [27]|        [27, [none]]|(2048,[465,1928],...|
# | 25|            [[none]]|   1095|   [25]|        [25, [none]]|(2048,[465,1497],...|
# | 17|            [[none]]|   7288|   [17]|        [17, [none]]|(2048,[465,1551],...|
# | 17|["philadelphia", ...|  14609|   [17]|[17, "philadelphi...|(2048,[261,696,77...|
# | 23|["sports news", "...|  20063|   [23]|[23, "sports news...|(2048,[181,193,14...|
# |  1|["weed", "addicti...|  88657|    [1]|[1, "weed", "addi...|(2048,[491,615,74...|
# | 24|["gerard butler",...|  16976|   [24]|[24, "gerard butl...|(2048,[314,567],[...|
# | 24|["los angeles", "...|  41471|   [24]|[24, "los angeles...|(2048,[156,224,31...|
# | 26|["travel", "stunt...|  18246|   [26]|[26, "travel", "s...|(2048,[492,753,15...|
# | 26|["travel smarter"...|  41265|   [26]|[26, "travel smar...|(2048,[95,1121,11...|
# | 10|["drake", "21 sav...|  19722|   [10]|[10, "drake", "21...|(2048,[41,252,348...|
# |  1|["vlog", "vloggin...|  75279|    [1]|[1, "vlog", "vlog...|(2048,[321,491,51...|
# | 10|["ciara", "christ...|  27765|   [10]|[10, "ciara", "ch...|(2048,[1,480,708,...|
# | 17|["nba", "basketba...| 117586|   [17]|[17, "nba", "bask...|(2048,[916,1373,1...|
# | 26|["refinery29", "r...|  50538|   [26]|[26, "refinery29"...|(2048,[317,440,45...|
# | 24|["jimmy", "kimmel...|  82052|   [24]|[24, "jimmy", "ki...|(2048,[1,14,222,2...|
# | 28|["spacex", "nasa"...| 147899|   [28]|[28, "spacex", "n...|(2048,[23,177,120...|
# +---+--------------------+-------+-------+--------------------+--------------------+
# only showing top 20 rows

# %%
trainingData, testData = hashed.randomSplit([0.8, 0.2])

rf = RandomForestRegressor(featuresCol="features", maxDepth=8)

model = rf.fit(trainingData)

predictionsDf = model.transform(testData)
predictionsDf.show()
# Out:
# +---+--------------------+-------+-------+--------------------+--------------------+------------------+
# | id|               words|  label|id_list|              merged|            features|        prediction|
# +---+--------------------+-------+-------+--------------------+--------------------+------------------+
# |  1|["a wrinkle in ti...|  14197|    [1]|[1, "a wrinkle in...|(2048,[34,60,491,...|1561525.7843502255|
# |  1|["a wrinkle in ti...|  17253|    [1]|[1, "a wrinkle in...|(2048,[34,60,491,...|1561525.7843502255|
# |  1|["a wrinkle in ti...|  18006|    [1]|[1, "a wrinkle in...|(2048,[34,60,491,...|1561525.7843502255|
# |  1|["a wrinkle in ti...|1921050|    [1]|[1, "a wrinkle in...|(2048,[60,343,411...|1561525.7843502255|
# |  1|["a24", "a24 film...|1500855|    [1]|[1, "a24", "a24 f...|(2048,[25,230,291...|1680840.2286862873|
# |  1|["a24", "a24 film...|1797044|    [1]|[1, "a24", "a24 f...|(2048,[25,230,291...|1680840.2286862873|
# |  1|["a24", "a24 film...| 703513|    [1]|[1, "a24", "a24 f...|(2048,[25,230,291...|1561525.7843502255|
# |  1|["a24", "a24 film...| 764021|    [1]|[1, "a24", "a24 f...|(2048,[25,230,291...|1561525.7843502255|
# |  1|["a24", "a24 film...| 801616|    [1]|[1, "a24", "a24 f...|(2048,[25,230,291...|1561525.7843502255|
# |  1|["a24", "a24 film...| 892869|    [1]|[1, "a24", "a24 f...|(2048,[25,230,291...|1561525.7843502255|
# |  1|["a24", "a24 film...| 948893|    [1]|[1, "a24", "a24 f...|(2048,[25,230,291...|1561525.7843502255|
# |  1|["a24", "a24 film...| 588196|    [1]|[1, "a24", "a24 f...|(2048,[25,124,230...|1680840.2286862873|
# |  1|["allen pan", "su...| 349102|    [1]|[1, "allen pan", ...|(2048,[115,199,34...|1561525.7843502255|
# |  1|["amazon studios"...|  83237|    [1]|[1, "amazon studi...|(2048,[72,83,109,...|1561525.7843502255|
# |  1|["amazon studios"...| 931686|    [1]|[1, "amazon studi...|(2048,[12,22,72,8...|1561525.7843502255|
# |  1|["amazon studios"...|1168313|    [1]|[1, "amazon studi...|(2048,[72,83,109,...|1358754.1988059909|
# |  1|["amazon studios"...|1173372|    [1]|[1, "amazon studi...|(2048,[72,83,109,...|1358754.1988059909|
# |  1|["amazon studios"...|1115224|    [1]|[1, "amazon studi...|(2048,[12,72,83,1...|1680840.2286862873|
# |  1|["amazon", "sing"...|  15476|    [1]|[1, "amazon", "si...|(2048,[188,371,44...|1561525.7843502255|
# |  1|["andré the giant...|1216139|    [1]|[1, "andré the gi...|(2048,[30,111,149...|1680840.2286862873|
# +---+--------------------+-------+-------+--------------------+--------------------+------------------+
# only showing top 20 rows

# %%
tupl = predictionsDf.withColumn('rating', F.struct(predictionsDf.prediction, predictionsDf.label))
tupl = tupl.select(tupl.rating)
tupl.show()
# Out:
# +--------------------+
# |              rating|
# +--------------------+
# |[1854167.24813995...|
# |[1320217.57966757...|
# |[1320217.57966757...|
# |[3033768.04201716...|
# |[972018.881174920...|
# |[972018.881174920...|
# |[3413029.98778842...|
# |[3413029.98778842...|
# |[3413029.98778842...|
# |[3413029.98778842...|
# |[3079057.92764185...|
# |[3079057.92764185...|
# |[3079057.92764185...|
# |[3049448.71549754...|
# |[1831435.46182333...|
# |[2104210.73858578...|
# |[2104210.73858578...|
# |[2104210.73858578...|
# |[2683292.90973709...|
# |[2683292.90973709...|
# +--------------------+
# only showing top 20 rows

# %%
metrics = RegressionMetrics(tupl.rdd)

# %%
rf_evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="label",metricName="r2")
rf_evaluator.evaluate(predictionsDf)
# Out:
# 0.6111431927056059
