# %%
df = spark.read.csv('/Users/zhujinghong/Downloads/5003\ project/pre_data/CA_pre.csv',header=True)

# %%
df.cache()
# Out:
# DataFrame[category_id: string, trending_date: string, title: string, channel_title: string, publish_time: string, tags: string, views: string, likes: string, dislikes: string, comment_count: string, category_title: string]

# %%
df.printSchema()
# Out:
# root
#  |-- category_id: string (nullable = true)
#  |-- trending_date: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- publish_time: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- views: string (nullable = true)
#  |-- likes: string (nullable = true)
#  |-- dislikes: string (nullable = true)
#  |-- comment_count: string (nullable = true)
#  |-- category_title: string (nullable = true)

# %%
from pyspark.sql.functions import col , column
cols=['category_id','views','likes','dislikes','comment_count']
for col in cols:
    df=df.withColumn('%s'%col ,df[col].cast('int'))

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
import pyspark.sql.functions as f
import os

# %%
# dataframe需要先注册成是一个Table或者View才能继续用SQL语言处理
df.createOrReplaceTempView("df")

# %% [markdown]
# ### preprocessing of category_title

# %%
# category_title存在null：原因category_id=29不存在
df.select('category_title').distinct().show()
df.select('category_title').distinct().count()
df.select('category_title','category_id').filter(f.isnull('category_title')).show()
# Out:
# +--------------------+
# |      category_title|
# +--------------------+
# |               Shows|
# |           Education|
# |              Gaming|
# |       Entertainment|
# |     Travel & Events|
# |Science & Technology|
# |              Sports|
# |                null|
# |       Howto & Style|
# |    Film & Animation|
# |      People & Blogs|
# |     News & Politics|
# |      Pets & Animals|
# |              Movies|
# |    Autos & Vehicles|
# |               Music|
# |              Comedy|
# +--------------------+
#
# +--------------+-----------+
# |category_title|category_id|
# +--------------+-----------+
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# |          null|         29|
# +--------------+-----------+
# only showing top 20 rows

# %%
df.count()
# Out:
# 40870

# %%
df.filter(df["category_title"]!='').count()
# Out:
# 40796

# %%
df=df.filter(df["category_title"]!='')

# %%
df.createOrReplaceTempView("df")

# %% [markdown]
# # Analysis

# %% [markdown]
# ### channel_title

# %%
# the most popular channel_title
channel = spark.sql("SELECT channel_title, COUNT(*) as freq FROM df GROUP BY channel_title ORDER BY freq DESC")
channel.show(10, False)
# Out:
# +----------------------------------+----+
# |channel_title                     |freq|
# +----------------------------------+----+
# |SET India                         |191 |
# |MSNBC                             |189 |
# |FBE                               |188 |
# |The Young Turks                   |186 |
# |REACT                             |183 |
# |VikatanTV                         |182 |
# |CNN                               |180 |
# |The Late Show with Stephen Colbert|172 |
# |ARY Digital                       |168 |
# |RadaanMedia                       |168 |
# +----------------------------------+----+
# only showing top 10 rows

# %%
# Top popular channel_title every day
cha_day = spark.sql("SELECT trending_date, channel_title, COUNT(*) as freq FROM df GROUP BY trending_date, channel_title ORDER BY freq DESC")
cha_day.show()
# Out:
# +-------------+-------------------+----+
# |trending_date|      channel_title|freq|
# +-------------+-------------------+----+
# |     17.17.12|    Merry Christmas|   3|
# |     18.15.04|        Nicki Minaj|   2|
# |     18.14.04|        Nicki Minaj|   2|
# |     17.18.12|    Merry Christmas|   2|
# |     17.24.11|        Ximo Pierto|   2|
# |     17.19.12|    Merry Christmas|   2|
# |     18.24.05|       TheEllenShow|   1|
# |     17.26.11|purported freelance|   1|
# |     17.15.12|                 GQ|   1|
# |     18.26.04|    Channel Awesome|   1|
# |     18.19.03|        Guava Juice|   1|
# |     17.17.11| The King of Random|   1|
# |     18.17.02|            DALLMYD|   1|
# |     18.20.03|   ikawikawikawikaw|   1|
# |     18.26.01| TheStaticShiftVEVO|   1|
# |     18.14.02|           NBA Show|   1|
# |     18.22.05|   Lucas and Marcus|   1|
# |     18.18.04|       Talent Recap|   1|
# |     17.29.12|    Linus Tech Tips|   1|
# |     18.10.02|      Nick Crompton|   1|
# +-------------+-------------------+----+
# only showing top 20 rows

# %%
# Average comment_count by channel_title
avg_comment = spark.sql(
    "SELECT channel_title, AVG(comment_count)as avg_comment FROM df GROUP BY channel_title ORDER BY avg_comment DESC")
avg_comment.show()
# Out:
# +--------------------+------------------+
# |       channel_title|       avg_comment|
# +--------------------+------------------+
# |             ibighit|481934.36842105264|
# |   YouTube Spotlight| 415868.3076923077|
# |Sơn Tùng M-TP Off...|          350702.0|
# |        David Dobrik|          234461.5|
# | ChildishGambinoVEVO|         193142.75|
# |    ArianaGrandeVevo|155179.16666666666|
# |     SuperMarioLogan|          145083.0|
# |      The ACE Family|          144699.0|
# |    Logan Paul Vlogs|          143946.1|
# |         Collins Key|          136154.4|
# |           DrakeVEVO|133422.33333333334|
# |     TaylorSwiftVEVO|109415.86666666667|
# |         Queen Naija|108976.33333333333|
# |    jypentertainment|          106640.1|
# |Marvel Entertainment|105739.64102564103|
# |          Bruno Mars|           89598.0|
# |            Lil pump| 88006.84615384616|
# |   Salman Khan Films|           72696.2|
# |Saad Lamjarred | ...|           72228.2|
# |         TheOdd1sOut|           70243.4|
# +--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ### category_title

# %%
# the number of category_title
distinct_ct = spark.sql("SELECT COUNT(DISTINCT(category_title)) FROM df")
distinct_ct.show()
# Out:
# +------------------------------+
# |count(DISTINCT category_title)|
# +------------------------------+
# |                            16|
# +------------------------------+

# %%
# 1-1 Top 10 category_title
top_cat = spark.sql("SELECT category_title, COUNT(*) as freq FROM df GROUP BY category_title ORDER BY freq DESC")
top_cat.show(10)
# Out:
# +--------------------+-----+
# |      category_title| freq|
# +--------------------+-----+
# |       Entertainment|13447|
# |     News & Politics| 4159|
# |      People & Blogs| 4103|
# |              Comedy| 3771|
# |               Music| 3731|
# |              Sports| 2786|
# |    Film & Animation| 2060|
# |       Howto & Style| 2006|
# |              Gaming| 1344|
# |Science & Technology| 1155|
# +--------------------+-----+
# only showing top 10 rows

# %%
# 1-2 Top popular category_title every day
top_cat_day = spark.sql("SELECT trending_date, category_title, COUNT(*) as freq FROM df GROUP BY trending_date, category_title ORDER BY freq DESC")
top_cat_day.show()
# Out:
# +-------------+--------------+----+
# |trending_date|category_title|freq|
# +-------------+--------------+----+
# |     18.20.03| Entertainment|  89|
# |     18.16.05| Entertainment|  85|
# |     18.17.05| Entertainment|  83|
# |     18.15.05| Entertainment|  80|
# |     18.27.05| Entertainment|  80|
# |     18.18.05| Entertainment|  78|
# |     18.01.06| Entertainment|  76|
# |     18.29.05| Entertainment|  76|
# |     18.08.05| Entertainment|  76|
# |     18.31.05| Entertainment|  76|
# |     18.06.06| Entertainment|  76|
# |     18.09.05| Entertainment|  75|
# |     18.18.03| Entertainment|  75|
# |     18.27.03| Entertainment|  74|
# |     18.20.05| Entertainment|  74|
# |     18.19.03| Entertainment|  74|
# |     18.19.05| Entertainment|  74|
# |     18.23.04| Entertainment|  74|
# |     18.24.03| Entertainment|  74|
# |     18.09.01| Entertainment|  74|
# +-------------+--------------+----+
# only showing top 20 rows

# %%
# 2-1 Average views count by category_title
avg_views = spark.sql(
    "SELECT category_title, AVG(views)as avg_views FROM df GROUP BY category_title ORDER BY avg_views DESC")
avg_views.show()
# Out:
# +--------------------+------------------+
# |      category_title|         avg_views|
# +--------------------+------------------+
# |               Music|3532524.8442776734|
# |              Movies|         2853415.0|
# |    Film & Animation|1426728.5650485437|
# |Science & Technology|1233844.5203463202|
# |              Sports|1075963.6051687007|
# |       Entertainment|1016599.6940581542|
# |              Comedy| 982248.0766374967|
# |              Gaming| 923759.2150297619|
# |      People & Blogs| 786733.5622715086|
# |       Howto & Style| 781356.9496510469|
# |      Pets & Animals| 638461.1734417344|
# |               Shows| 577012.1612903225|
# |    Autos & Vehicles| 567784.2840909091|
# |           Education| 536602.7679112008|
# |     News & Politics| 388220.7364751142|
# |     Travel & Events| 366701.4081632653|
# +--------------------+------------------+

# %%
# 2-2 Average likes count by category_title
avg_likes = spark.sql(
    "SELECT category_title, AVG(likes)as avg_likes FROM df GROUP BY category_title ORDER BY avg_likes DESC")
avg_likes.show()
# Out:
# +--------------------+------------------+
# |      category_title|         avg_likes|
# +--------------------+------------------+
# |               Music|151285.85633878317|
# |              Comedy|51895.282683638296|
# |              Movies|42150.833333333336|
# |              Gaming|38487.017857142855|
# |    Film & Animation| 37767.96262135922|
# |Science & Technology| 37068.91601731602|
# |       Entertainment|28797.192979846805|
# |      People & Blogs| 25685.11991225932|
# |       Howto & Style|25494.451146560317|
# |      Pets & Animals|23931.533875338755|
# |              Sports|21338.610552763817|
# |           Education|21162.867810292635|
# |    Autos & Vehicles| 13439.15909090909|
# |     Travel & Events| 9568.658163265307|
# |     News & Politics| 7863.682135128637|
# |               Shows| 4752.120967741936|
# +--------------------+------------------+

# %%
# 2-3 Average dislikes count by category_title
avg_dislikes = spark.sql(
    "SELECT category_title, AVG(dislikes)as avg_dislikes FROM df GROUP BY category_title ORDER BY avg_dislikes DESC")
avg_dislikes.show()
# Out:
# +--------------------+------------------+
# |      category_title|      avg_dislikes|
# +--------------------+------------------+
# |               Music| 5922.859823103726|
# |      People & Blogs| 2310.640506946137|
# |              Movies|2046.6666666666667|
# |       Entertainment|1917.9835651074588|
# |              Gaming|1820.5967261904761|
# |Science & Technology|1550.7818181818182|
# |    Film & Animation|1510.3199029126213|
# |              Comedy|1422.7022010076903|
# |              Sports|1179.5987078248386|
# |               Shows|  971.258064516129|
# |       Howto & Style| 861.2218344965105|
# |           Education| 800.6538849646821|
# |     News & Politics| 784.8138975715316|
# |    Autos & Vehicles| 561.6676136363636|
# |      Pets & Animals| 501.3631436314363|
# |     Travel & Events| 331.2780612244898|
# +--------------------+------------------+

# %% [markdown]
# #### Create df1: trending_date->year, month

# %%
from pyspark.sql.functions import split, explode, concat
df = df.withColumn('trending_date' ,df['trending_date'].cast('string'))
# year
df1 = df.withColumn("date", split(df['trending_date'],''))\
        .withColumn("date", concat(f.col("date")[0], f.col("date")[1]))\
        .withColumnRenamed('date','year')
df1.printSchema()
# Out:
# root
#  |-- category_id: integer (nullable = true)
#  |-- trending_date: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- publish_time: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- views: integer (nullable = true)
#  |-- likes: integer (nullable = true)
#  |-- dislikes: integer (nullable = true)
#  |-- comment_count: integer (nullable = true)
#  |-- category_title: string (nullable = true)
#  |-- year: string (nullable = true)

# %%
# month
df1 = df1.withColumn("date", split(df['trending_date'],''))\
         .withColumn("date", concat(f.col("date")[6], f.col("date")[7]))\
         .withColumnRenamed('date','month')
df1.printSchema()
# Out:
# root
#  |-- category_id: integer (nullable = true)
#  |-- trending_date: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- channel_title: string (nullable = true)
#  |-- publish_time: string (nullable = true)
#  |-- tags: string (nullable = true)
#  |-- views: integer (nullable = true)
#  |-- likes: integer (nullable = true)
#  |-- dislikes: integer (nullable = true)
#  |-- comment_count: integer (nullable = true)
#  |-- category_title: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- month: string (nullable = true)

# %%
df1.createOrReplaceTempView("df1")

# %%
# Top popular category title in every year
top_cat_year = spark.sql("SELECT year, category_title, COUNT(*) as freq FROM df1 GROUP BY year, category_title ORDER BY freq DESC")
top_cat_year.show()
# Out:
# +----+--------------------+-----+
# |year|      category_title| freq|
# +----+--------------------+-----+
# |  18|       Entertainment|10426|
# |  18|     News & Politics| 3284|
# |  18|      People & Blogs| 3092|
# |  17|       Entertainment| 3021|
# |  18|               Music| 2847|
# |  18|              Comedy| 2747|
# |  18|              Sports| 2179|
# |  18|    Film & Animation| 1566|
# |  18|       Howto & Style| 1557|
# |  17|              Comedy| 1024|
# |  17|      People & Blogs| 1011|
# |  18|              Gaming|  994|
# |  17|               Music|  884|
# |  17|     News & Politics|  875|
# |  18|Science & Technology|  864|
# |  18|           Education|  736|
# |  17|              Sports|  607|
# |  17|    Film & Animation|  494|
# |  17|       Howto & Style|  449|
# |  17|              Gaming|  350|
# +----+--------------------+-----+
# only showing top 20 rows

# %%
top_cat_year.filter(top_cat_year['year']=='17').show()
top_cat_year.filter(top_cat_year['year']=='18').show()
# Out:
# +----+--------------------+----+
# |year|      category_title|freq|
# +----+--------------------+----+
# |  17|       Entertainment|3021|
# |  17|              Comedy|1024|
# |  17|      People & Blogs|1011|
# |  17|               Music| 884|
# |  17|     News & Politics| 875|
# |  17|              Sports| 607|
# |  17|    Film & Animation| 494|
# |  17|       Howto & Style| 449|
# |  17|              Gaming| 350|
# |  17|Science & Technology| 291|
# |  17|           Education| 255|
# |  17|     Travel & Events| 102|
# |  17|      Pets & Animals|  96|
# |  17|    Autos & Vehicles|  72|
# |  17|               Shows|  41|
# +----+--------------------+----+
#
# +----+--------------------+-----+
# |year|      category_title| freq|
# +----+--------------------+-----+
# |  18|       Entertainment|10426|
# |  18|     News & Politics| 3284|
# |  18|      People & Blogs| 3092|
# |  18|               Music| 2847|
# |  18|              Comedy| 2747|
# |  18|              Sports| 2179|
# |  18|    Film & Animation| 1566|
# |  18|       Howto & Style| 1557|
# |  18|              Gaming|  994|
# |  18|Science & Technology|  864|
# |  18|           Education|  736|
# |  18|     Travel & Events|  290|
# |  18|    Autos & Vehicles|  280|
# |  18|      Pets & Animals|  273|
# |  18|               Shows|   83|
# |  18|              Movies|    6|
# +----+--------------------+-----+

# %%
# Top popular category title in 2017 and 2018
df2 = df1.filter(df1['year']=='17')
df3 = df1.filter(df1['year']=='18')
df2.createOrReplaceTempView("df2") 
df3.createOrReplaceTempView("df3")

# %%
# 2017
top_cat_month_17 = spark.sql("SELECT month, category_title,\
                              COUNT(*) as freq FROM df2 GROUP BY month,\
                              category_title ORDER BY freq DESC")
top_cat_month_17.show()
# Out:
# +-----+--------------------+----+
# |month|      category_title|freq|
# +-----+--------------------+----+
# |   12|       Entertainment|1949|
# |   11|       Entertainment|1072|
# |   12|      People & Blogs| 649|
# |   12|              Comedy| 638|
# |   12|               Music| 592|
# |   12|     News & Politics| 568|
# |   11|              Comedy| 386|
# |   12|              Sports| 371|
# |   11|      People & Blogs| 362|
# |   12|    Film & Animation| 328|
# |   11|     News & Politics| 307|
# |   12|       Howto & Style| 302|
# |   11|               Music| 292|
# |   12|              Gaming| 257|
# |   11|              Sports| 236|
# |   12|           Education| 173|
# |   11|    Film & Animation| 166|
# |   12|Science & Technology| 164|
# |   11|       Howto & Style| 147|
# |   11|Science & Technology| 127|
# +-----+--------------------+----+
# only showing top 20 rows

# %%
# 2017.12
top_cat_month_17.select('*').filter(top_cat_month_17['month']=='12').show()
# Out:
# +-----+--------------------+----+
# |month|      category_title|freq|
# +-----+--------------------+----+
# |   12|       Entertainment|1949|
# |   12|      People & Blogs| 649|
# |   12|              Comedy| 638|
# |   12|               Music| 592|
# |   12|     News & Politics| 568|
# |   12|              Sports| 371|
# |   12|    Film & Animation| 328|
# |   12|       Howto & Style| 302|
# |   12|              Gaming| 257|
# |   12|           Education| 173|
# |   12|Science & Technology| 164|
# |   12|     Travel & Events|  68|
# |   12|      Pets & Animals|  61|
# |   12|    Autos & Vehicles|  37|
# |   12|               Shows|  24|
# +-----+--------------------+----+

# %%
# 2018
top_cat_month_18 = spark.sql("SELECT month, category_title, COUNT(*) as freq FROM df3 GROUP BY month, category_title ORDER BY freq DESC")
top_cat_month_18.show()
# Out:
# +-----+---------------+----+
# |month| category_title|freq|
# +-----+---------------+----+
# |   05|  Entertainment|2230|
# |   03|  Entertainment|2132|
# |   01|  Entertainment|1841|
# |   02|  Entertainment|1736|
# |   04|  Entertainment|1520|
# |   06|  Entertainment| 967|
# |   01|News & Politics| 678|
# |   03| People & Blogs| 670|
# |   05|News & Politics| 641|
# |   01| People & Blogs| 628|
# |   05|          Music| 612|
# |   02|News & Politics| 598|
# |   02| People & Blogs| 580|
# |   03|         Comedy| 549|
# |   04|News & Politics| 535|
# |   05|         Comedy| 531|
# |   01|          Music| 526|
# |   04| People & Blogs| 518|
# |   03|News & Politics| 515|
# |   02|         Comedy| 507|
# +-----+---------------+----+
# only showing top 20 rows

# %%
# 2018.05
top_cat_month_18.select('*').filter(top_cat_month_18['month']=='05').show()
# Out:
# +-----+--------------------+----+
# |month|      category_title|freq|
# +-----+--------------------+----+
# |   05|       Entertainment|2230|
# |   05|     News & Politics| 641|
# |   05|               Music| 612|
# |   05|              Comedy| 531|
# |   05|      People & Blogs| 490|
# |   05|              Sports| 346|
# |   05|    Film & Animation| 317|
# |   05|       Howto & Style| 311|
# |   05|Science & Technology| 220|
# |   05|              Gaming| 148|
# |   05|           Education| 126|
# |   05|     Travel & Events|  56|
# |   05|      Pets & Animals|  54|
# |   05|    Autos & Vehicles|  49|
# |   05|               Shows|  34|
# |   05|              Movies|   1|
# +-----+--------------------+----+

# %% [markdown]
# ### title_length

# %%
from pyspark.sql.types import StringType, DoubleType, IntegerType, StructField, StructType
titleLength = spark.sql("SELECT title as title from df")\
                   .rdd.map(lambda x: list(x)).flatMap(lambda x: x)\
                   .map(lambda x: (x,len(x))).reduceByKey(lambda a,b:a)\
                   .repartition(1).sortBy(lambda x:x[1],False)
titleLengthSchema = StructType([StructField("Title", StringType(), True),\
                                StructField("Length", IntegerType(), True)])                                                           
titleLengthDF = spark.createDataFrame(titleLength, titleLengthSchema)
titleLengthDF = titleLengthDF.filter(titleLengthDF["Title"]!='')
titleLengthDF.collect()
# Out:
# [Row(Title='Stephen A. asks Ray Allen about relationship with Rajon Rondo and former Celtics | First Take | ESPN', Length=100),
#  Row(Title='Emotional Virat Kohli CRIES In Front Of Anushka Sharma Night Before Wedding. Watch What Anushka Does', Length=100),
#  Row(Title='88RISING - midsummer madness ft. Joji, Rich Brian, Higher Brothers, AUGUST 08 (official music video)', Length=100),
#  Row(Title='Guitar Music Cover - Greatest Love Songs Of All Time -Love Songs Greatest Hits - Most Beautiful Love', Length=100),
#  Row(Title='Hát mãi ước mơ 2| tập 4 full:Cẩm Ly ngưỡng mộ niềm lạc quan của đôi vợ chồng 40 năm làm nghề vớt xác', Length=100),
#  Row(Title="LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce, Fabien Olicard, Nad Rich' Hard, Max Bird, Studio Vrac", Length=100),
#  Row(Title='About that life (Full Video) Elly Mangat I Vadda Grewal | Only Jashan |  | Latest Punjabi Songs 2018', Length=100),
#  Row(Title='Charlotte Flair & Carmella sign contract for their match at Backlash: SmackDown LIVE, April 24, 2018', Length=100),
#  Row(Title='INDIAN FOOD HEAVEN at the BIGGEST MEGA KITCHEN 2018! AMAZING TRAVEL DOCUMENTARY in the GOLDEN TEMPLE', Length=100),
#  Row(Title='Morning Coffee Piano Music 2018 – Hour Of Beautiful Piano Music For Wake Up and Gain Positive Energy', Length=100),
#  Row(Title='DISGUSTING! Huge Scam Exposed, Spotify Crackdown Stirs 6ix9ine Debate, Jake Paul Challenge, And More', Length=100),
#  Row(Title="Trace the Father of Meghan Markle? The information never revealed about Prince Harry's wife's father", Length=100),
#  Row(Title='Marvel Studios’ Avengers: Infinity War Tom Holland Aka Spider-Man Eating British And American Snacks', Length=100),
#  Row(Title='E3 2018 SONY PLAYSTATION & UBISOFT & NINTENDO PRESS CONFERENCES LIVE (E3 2018 SQUARE ENIX LIVESTREAM', Length=100),
#  Row(Title='Cardi B Being Sued by Former Manager for $10 mil. She Claims He Stole $. GUEST COMMENTARY BY 6ix9INE', Length=100),
#  Row(Title='Why Women Shouldn’t Wear Yoga Pants, Jennifer Lawrence Backlash, and Trump’s Armed Teachers Proposal', Length=100),
#  Row(Title='Live with Dr Shahid Masood |24-12-2017|  #NawazSharif  #ShehbazSharif  #QuaideAzam  24 December 2017', Length=100),
#  Row(Title='Thách thức danh hài 4 |tập 2 full: cô gái muốn triệt sản Tiến Luật làm Trấn Thành,Trường Giang lo sợ', Length=100),
#  Row(Title='WolfieRaps - Check the Statistics Ft. Ricegum (Official Music Video) (Big Shaq Diss Track) REACTION!', Length=100),
#  Row(Title='Nikki Haley to UN on Jerusalem. Dec 21, 2017. UN General Assembly meeting on US embassy move in Isra', Length=100),
#  Row(Title="Trippie Redd disses xxxtentacion for 'switching sides' & being friends with 6ix9ine because of Drake", Length=100),
#  Row(Title='Yaaran Da Yaar | Harf Cheema | Deep Jandu | Sukh Sanghera | Latest Punjabi Song 2017 | Speed Records', Length=100),
#  Row(Title='LeBron James AMAZING Full Game 6 Highlights vs Celtics 2018 Playoffs ECF - 46 Pts, 11 Reb, LeCLUTCH!', Length=100),
#  Row(Title="Max: Cavaliers' playoff run should impact LeBron James' decision for next season | First Take | ESPN", Length=100),
#  Row(Title='Watch out Judges: Robert White is coming for you in this HILARIOUS routine! | Semi-Finals | BGT 2018', Length=100),
#  Row(Title="Nick Wright on how Jazz' Donovan Mitchell just joined Michael Jordan and Kareem | FIRST THINGS FIRST", Length=100),
#  Row(Title="Well...I Don't Know What To Believe Anymore. Trump's Due Process Controversy, Huge Strikes, and More", Length=100),
#  Row(Title="[RADIO STAR] 라디오스타 Idol Psychoanalyst Seungri Annual psychological state is 'roller coaster'20180321", Length=100),
#  Row(Title="State of the Union w/ Jake Tapper 04/29/18| Stormy Dan!els' lawsuit delayed over Cohen investigation", Length=100),
#  Row(Title='TEASER | DESIGNER | NIMRAT KHAIRA | DEEP JANDU| HAPPY RAIKOTI | HUMBLE MUSIC | RELEASING ON 20TH NOV', Length=100),
#  Row(Title="President Donald Trump Responds To Steve Bannon: 'He Not Only Lost His Job, He Lost His Mind' | CNBC", Length=100),
#  Row(Title='List of Celebrities Who Died In FEBRUARY 2018 | Latest Celebrity News 2018 (Celebrity Breaking News)', Length=100),
#  Row(Title="BONUS VID! - What's Going On With Conor Lamb... And Why It Doesn't Matter... But It Actually Does...", Length=100),
#  Row(Title="EXACTLY WHAT I'M EATING ONE WEEK AWAY FROM PHYSIQUE SHOW | SHREDDING EASY |  *NO FOOD RESTRICTIONS!!", Length=100),
#  Row(Title='Vitalyzdtv & FouseyTUBE EXPOSE EACH OTHER! #DramaAlert WoahVicky VS Lil Wayne Daughter, David Dobrik', Length=100),
#  Row(Title='102 Not Out | Official Trailer | Amitabh Bachchan | Rishi Kapoor | Umesh Shukla | In Cinemas May 4th', Length=100),
#  Row(Title='Thần Tượng Bolero 2018 Tập 5 Full HD | Vòng Tinh Hoa: Bộ 3 HLV đã tìm được những mảnh ghép cuối cùng', Length=100),
#  Row(Title='Reporter Grills Sarah Sanders & she starts FUMING when asked on Trump & Mueller Russia Investigation', Length=100),
#  Row(Title='Japanese Street Food Tour in Tokyo, Japan - AMAZING Street Food + BEST BBQ Wagyu Beef Steak in Tokyo', Length=100),
#  Row(Title="#Trump's #ExecutiveOrder Has #EricSchmidt and Other Evil #DeepState Swamp Dwellers Running for Cover", Length=100),
#  Row(Title='TESTING VIRAL INSTAGRAM SLIME TRENDS! RAINBOW GLITTER SLIME, INSTANT CLEAR SLIME, NAPPY SLIME + MORE', Length=100),
#  Row(Title="LeBron James Decided To Leave The Cavs After Getting Swept ：I' VE Never Been So Heartbroken Before ！", Length=100),
#  Row(Title='OMG *FREE* HOW TO GET ANY SKIN EVER IN FORTNITE! VBUCKS GLITCH HACK? NEW SKIN FORTNITE BATTLE ROYALE', Length=100),
#  Row(Title='The emotional moments when Capitals players reunited with their loved ones after the Stanley Cup win', Length=100),
#  Row(Title='BREAKING NEWS TODAY JANUARY 02, 2018 PRESIDENT DUTERTE l TRILLANES l DE LIMA l LP SENATORS l DILAWAN', Length=100),
#  Row(Title="Cris Carter's reason KD's Warriors will sweep LeBron's Cavs in NBA Finals | NBA | FIRST THINGS FIRST", Length=100),
#  Row(Title="Cardi B says 'I Refuse to Get Extorted' after People tell her to Not come to LA over 'FLUE' comment.", Length=100),
#  Row(Title='The Twelfth Doctor Regenerates: Peter Capaldi to Jodie Whittaker - Doctor Who Christmas Special 2017', Length=100),
#  Row(Title='WOW: Trey Gowdy to AG Jeff Sessions: Its NOT Appropriate for Trump to speaks on a Open Investigation', Length=100),
#  Row(Title='REACTING TO WolfieRaps Check the Statistics FT. Ricegum (Official Music Video) (Big Shaq Diss Track)', Length=100),
#  Row(Title='Head Coach Dwane Casey FURIOUS with Hawks Coach - Raptors vs Hawks | Dec 29, 2017 | 17-18 NBA Season', Length=100),
#  Row(Title='Portland Trail Blazers vs Houston Rockets - Full Game Highlights | Jan 10, 2018 | NBA Season 2017-18', Length=100),
#  Row(Title='Là Vợ Phải Thế 2018 l Tập 9 Full: Lâm Vỹ Dạ bật mí hay đứng trước gương tập tỏ tình với Hứa Minh Đạt', Length=100),
#  Row(Title='श्रीदेवी की मौत की सच, अमिताभ बच्चन ने पहले ही बता दिया था SHREE DEVI DIED IN DUBAI / RIP SHREE DEVI', Length=100),
#  Row(Title='Laung Laachi Title Track  Mannat Noor | Ammy Virk, Neeru Bajwa,Amberdeep | Latest Punjabi Movie 2018', Length=100),
#  Row(Title='Thách thức danh hài 4 |gala 2: Hết “bỏ túi” 100 triệu, cô sinh viên Nông Lâm lại “ẵm trọn” 150 triệu', Length=100),
#  Row(Title="'Bachelor's Becca Kufrin Breaks Her Silence After Arie Luyendyk Jr. Ends Their Engagement | PeopleTV", Length=100),
#  Row(Title='Chris Broussard thinks the Cavs would’ve won East anyway, but LeBron is now rejuvenated | UNDISPUTED', Length=100),
#  Row(Title='【EP.7】跑男团VS百人工友团力量对决！李晨“负伤”超能力上线参赛！范丞丞Rap实力被大赞 邓超大秀老年迪斯科《奔跑吧2》 20180525 Keep Running S2 [ 浙江卫视官方HD ]', Length=100),
#  Row(Title='Ninja WORLD RECORD! #DramaAlert YouTube BANS GUNS, FaZe Adapt Thief EXPOSED, Tana Mongeau FaZe House', Length=100),
#  Row(Title='Car Nachdi/Hornn Blow (Video) | T-Series Mixtape Punjabi | Gippy Grewal ,Harrdy Sandhu & Neha Kakkar', Length=100),
#  Row(Title='Theher Ja | October | Varun Dhawan & Banita Sandhu | Armaan Malik | Abhishek Arora | Abhiruchi Chand', Length=100),
#  Row(Title='Jim Jackson on why Steph Curry isn’t to blame for Warriors Game 2 loss to Rockets | NBA | UNDISPUTED', Length=100),
#  Row(Title='Naragasooran - Official Teaser | Arvind Swami | Shriya Saran | Sundeep Kishan | Indrajith | Aathmika', Length=100),
#  Row(Title='Pedestrians struck by van in Toronto Canada near Yonge Sheppard/Finch driver Alek Minassian arrested', Length=100),
#  Row(Title='Childish Gambino -  THIS IS AMERICA VIDEO BREAKDOWN! Behold a Pale Horse! [WOW] The Hidden Messages!', Length=100),
#  Row(Title='De Niro Was Warned About Trashing Trump At Tony Awards & Didn’t Listen Got What He Deserved On Stage', Length=100),
#  Row(Title='EPIC MARRIAGE PROPOSAL GOES WRONG! **WIFE ACCUSES HUSBAND OF CHEATING!** [BIG B**TY LATINA EDITION!]', Length=100),
#  Row(Title="'The Bachelorette': Ashley Iaconetti & Jared Haibon Rate Becca's Suitors In Season Premiere | Access", Length=100),
#  Row(Title='Minnesota Timberwolves vs Toronto Raptors - Full Game Highlights | Jan 30, 2018 | NBA Season 2017-18', Length=100),
#  Row(Title='Pusha T Exposes Drake as a Deadbeat Dad and Disses his Mother, Father and Sick Producer/Best Friend.', Length=100),
#  Row(Title='Black Panther Cast Touches a Chameleon, a Guinea Pig, and Other Weird Stuff | Fear Box | Vanity Fair', Length=100),
#  Row(Title='Donald Trump Camp Ties To Russia A Transition Quandary For Barack Obama Team | Rachel Maddow | MSNBC', Length=100),
#  Row(Title='Stephen A., Vince Carter, Max Kellerman on LeBron James eclipsing Michael Jordan | First Take | ESPN', Length=100),
#  Row(Title="Chinese Street Food HEAVEN in Xi'an, China - Spinach Noodles, BEST Dumplings and MUSLIM Chinese Food", Length=100),
#  Row(Title="'The Bachelor: Roses & Rose': Does Krystal Keep Going One Step Too Far? Is Bekah Too Young For Arie?", Length=100),
#  Row(Title='Logan Paul 100% CONFIRMS KSI Fight #DramaAlert TheOdd1sOut ROASTS RiceGum, Scammer CATFISHED & OWNED', Length=100),
#  Row(Title='Official Trailer: Hate Story IV | Urvashi Rautela | Vivan Bhathena | Karan Wahi | IhanaVISHAL PANDYA', Length=100),
#  Row(Title="Simon Olivier Fecteau créateur des derniers Bye Bye pour sa série ''En audition avec Simon'' à TLMEP", Length=100),
#  Row(Title='Should Cavaliers try to trade LeBron James? Stephen A., Max and Will Cain debate | First Take | ESPN', Length=100),
#  Row(Title='20 Saal (Full Video) | Kambi | Sukh - E (Muzical Doctorz) | Latest Punjabi Song 2018 | Speed Records', Length=100),
#  Row(Title='Marvel Studios’ Avengers: Infinity War Tom Hiddleston, Letitia Wright And Sebastian Stan Rate Stunts', Length=100),
#  Row(Title='BTS | RM, SUGA, J-HOPE - DDAENG | LYRIC BREAKDOWN (땡) (Color Coded Lyrics Eng/Rom/Han) | REACTION!!!', Length=100),
#  Row(Title='Ơn Giời Cậu Đây Rồi Tập 10 Full: Đệ tử Gil Lê nghẹn lời trước cảnh sư phụ Trường Giang bị ChiPu nhập', Length=100),
#  Row(Title='Veere Di Wedding Trailer | Kareena Kapoor Khan, Sonam Kapoor, Swara Bhasker, Shikha Talsania| June 1', Length=100),
#  Row(Title='Jazbaat - Amantej Hundal |Randeep Gill |Rahul Chahal | PB 26 Records I Full Official Video Song 2017', Length=100),
#  Row(Title='AE du 05.04 : Eliézer Ntambwe transféré à Makala + Ministres et 46 sénateurs avec  nationalité belge', Length=100),
#  Row(Title='Barstool Pizza Review- Don Antonio w/ Jon Hamm,Ed Helms,Jeremy Renner,Jake Johnson & Hannibal Buress', Length=100),
#  Row(Title='Zero | Title Announcement | Shah Rukh Khan | Aanand L Rai | Anushka Sharma | Katrina Kaif | 21 Dec18', Length=100),
#  Row(Title='INDIAN STREET FOOD of YOUR DREAMS in Kolkata, INDIA | BEST CURRY and SEAFOOD + Street Food in India!', Length=100),
#  Row(Title="Children tried to save these puppies... they didn't realize their homeless mom was looking for food.", Length=100),
#  Row(Title='How Cohen’s Money Trail Could Capsize The Donald Trump Presidency | The Beat With Ari Melber | MSNBC', Length=100),
#  Row(Title='PRADA - JASS MANAK (Official Video) Satti Dhillon | Latest Punjabi Song 2018 | GK.DIGITAL | Geet MP3', Length=100),
#  Row(Title='REUPLOAD Logan Paul Vlogs   We found a dead body in the Japanese Suicide Forest (NOT THE FULL VIDEO)', Length=100),
#  Row(Title='BTS COMEBACKSHOW - HIGHLIGHT REEL [BTS의 충전법 Part.3] 이럴 슈가!! 한 번 잠들면 깨지 않는다!│BTS COMEBACK SHOW 180524', Length=100),
#  Row(Title='NAKAKAGULAT NA BALITA - DECEMBER 29, 2017 | PAOLO DUTERTE | TRILLANES | SERENO | ROBREDO | DELA ROSA', Length=100),
#  Row(Title='Love Songs Piano Music 2018 - Love makes the world go around- Relaxing Piano Instrumental Music 2018', Length=100),
#  Row(Title='Stephen A. and Max react to Warriors defeating Cavaliers in Game 2 of NBA Finals | First Take | ESPN', Length=100),
#  Row(Title='Người Bí Ẩn 2018 | Tập 8 Full: Vũ Cát Tường, Chi Dân làm xiếc Hoài Linh, Việt Hương phấn khích cổ vũ', Length=100),
#  Row(Title="Stephen A. Smith on Vikings' winning touchdown: I've never seen anything like it | First Take | ESPN", Length=100),
#  Row(Title="Canada Soccer's Women's National Team v USA International Friendly LIVE from Avaya Stadium, San Jose", Length=100),
#  Row(Title='Lae Dooba - Aiyaary | Sidharth Malhotra, Rakul Preet |Sunidhi Chauhan |Rochak Kohli |Manoj Muntashir', Length=100),
#  Row(Title='Rabb Khair Kare - Full Video | DAANA PAANI | Prabh Gill | Shipra Goyal |Jimmy Sheirgill |Simi Chahal', Length=100),
#  Row(Title='Thách thức danh hài 4 |tập 12 full: Trấn Thành “méo mặt” khi thí sinh hát chế hit của bà xã Hari Won', Length=100),
#  Row(Title='A Christian pastor just broke the internet with a scathing open letter to Huckabee Sanders and Trump', Length=100),
#  Row(Title="#DeepState Panic: #QAnon, #Schmidt's Exit and #Trump's #HumanRights Asset Forfeiture #ExecutiveOrder", Length=100),
#  Row(Title='Stephen A. sides with Reggie Miller: Magic Johnson should speak up on LaVar Ball | First Take | ESPN', Length=100),
#  Row(Title='YBN Almighty Jay Pulls up on Rich the Kid for a Fade. But Rich the Kid gave him a address 2 the mall', Length=100),
#  Row(Title='This may well be the reason why GSP experienced UFO sightings/loss of memory,Lobov on his MMA Record', Length=100),
#  Row(Title="Lil Wayne is Finally Free from Birdman. He Gets $10 + Mil settlement + He's NO longer on CASH MONEY!", Length=100),
#  Row(Title='[Cập nhật] TIN NÓNG TRỰC TIẾP TỪ SYRIA 15/4 - VIỆT NAM SƠ TÁN KHẨN CẤP CÔNG DÂN khi MỸ T.Ấ.N C.Ô.N.G', Length=100),
#  Row(Title='Love You - Sharry Mann (Full Video Song) | Parmish Verma | Mista Baaz | Punjabi Songs 2017 | Lokdhun', Length=100),
#  Row(Title="I'm síck of Jon Jones,Romero,Silva these guys know what they are putting in their bodies,GSP on Dana", Length=100),
#  Row(Title='*NEW* Fortnite Season 4 DANCES IN REAL LIFE LEAKED! (Pop Lock,Red Card, Cry, Soccer Juggling, T-rex)', Length=100),
#  Row(Title='Mexican Food MEAT NINJA | Trying to Eat A WHOLE 80 KG Lamb ⚔️The Most SATISFYING Mexican Street Food', Length=100),
#  Row(Title="Allen Iverson on Thunder's playoff struggles: They need to make something happen | First Take | ESPN", Length=100),
#  Row(Title="Jon's OUTRAGEOUS Comment About Lee Mack's Nan! | 8 Out Of 10 Cats Does Countdown | Best of Lee Pt. 2", Length=100),
#  Row(Title='Jake Paul comments on fight with KSI’s brother Deji Olatunki as he arrives for dinner at Craigs in W', Length=100),
#  Row(Title='Suspect Nikolas Cruz Charged With Premeditated Murder In Parkland Florida School Shooting | NBC News', Length=100),
#  Row(Title='MUSICAL.LY COMPILATION VIDEOS! FUNnel Vision Skits & Songs w/ Mike & Lex (Funny & Cute Short Videos)', Length=100),
#  Row(Title='Former US Attorneys Mimi Rocah And Daniel Goldman Weigh In On Judicial Attacks | Morning Joe | MSNBC', Length=100),
#  Row(Title='Auston Matthews Disallowed Goal - Matthews Upset - Toronto Maple Leafs vs Colorado Avalanche 1.22.18', Length=100),
#  Row(Title='(BONUS!) Sean Evans Reveals How He Truly Feels About Hot Ones, Hot Wings, Kevin Hart, and Much More!', Length=100),
#  Row(Title='Baaghi 2: Ek Do Teen Song | Jacqueline Fernandez |Tiger Shroff | Disha P| Ahmed K | Sajid Nadiadwala', Length=100),
#  Row(Title='LA Clippers vs Golden State Warriors - Full Game Highlights | February 22, 2018 | 2017-18 NBA Season', Length=100),
#  Row(Title="Inside Video: Anand Ahuja Fills Sonam Kapoor's Maang With Sindoor And Sonam Gives Him A Kiss Of Love", Length=100),
#  Row(Title='Secret Memo Warned Donald Trump Data Firm About Breaking U.S. Law | The Beat With Ari Melber | MSNBC', Length=100),
#  Row(Title='Live with Dr.Shahid Masood | 01-Febrary-2018 | Mir Hazar Khan Bijarani | AD Khawaja | Nawaz Sharif |', Length=100),
#  Row(Title='I Built a Fort out of Red Cups & Spent the Night... It Was Funny AF (Sleep in a Cup House Challenge)', Length=100),
#  Row(Title='The Real History Behind Mermaids | 5 Fascinating Facts About These Underwater Mythological Creatures', Length=100),
#  Row(Title='STRAIGHT OUTTA MOHALI || JIMMY KALER ft. MISTA BAAZ & GURLEJ AKHTER  ||FULL VIDEO|| CROWN RECORDS ||', Length=100),
#  Row(Title='FORTNITE ! ON RÉUSSI A FAIRE TOP 1 SUR LA NOUVELLE MISE A JOUR FORTNITE BATTLE ROYALE AVEC BOBBY !!!', Length=100),
#  Row(Title='If you’re missing someone this Christmas this song’s dedicated to you - The Piano Guys ft Craig Aven', Length=100),
#  Row(Title='Pusha T claims that Drake is behind the scenes offering $100k for any Dirt on him for his diss track', Length=100),
#  Row(Title='BAAGHI - Last Episode 28 | Last Ep | Urdu1 Drama | Saba Qamar, Osman Khalid, Khalid Malik, Ali Kazmi', Length=100),
#  Row(Title="Stephen A. Smith blames LeBron James, Tyronn Lue, J.R. Smith for Cavs' struggles | First Take | ESPN", Length=100),
#  Row(Title='Human calls lowered 3 octaves might be what dinosaurs actually sounded like. Haunting yet beautiful!', Length=100),
#  Row(Title='Minnesota Timberwolves vs Milwaukee Bucks - Full Game Highlights | Dec 28, 2017 | NBA Season 2017-18', Length=100),
#  Row(Title='MANKIRT AULAKH - JATT DI CLIP (Full Song) Dj Flow | Singga | Latest Punjabi Songs 2017 | GME.DIGITAL', Length=100),
#  Row(Title='HTV VÌ YÊU MÀ ĐẾN | DJ Mie từ chối Bảo Kun để tỏ tình chàng trai khác | VYMD #13 FULL | 7/12/2017', Length=100),
#  Row(Title='Washington Wizards vs Toronto Raptors - Full Game Highlights | Game 2 | April 17, 2018 | NBAPlayoffs', Length=100),
#  Row(Title='Ex CIA- Robert David Steele - Trump Counter Coup In Play, Deep State, Pedophiles, Satanist Are Toast', Length=100),
#  Row(Title='Oklahoma City Thunder vs Portland Trail Blazers Full Game Highlights / March 25 / 2017-18 NBA Season', Length=100),
#  Row(Title='Red Alert: Trump Has Declared Martial Law / MSM’s Total Blackout On Developments: 12/31/17 Full Show', Length=100),
#  Row(Title='Brooklyn Nets vs Cleveland Cavaliers - Full Game Highlights | November 22, 2017 | NBA Season 2017-18', Length=100),
#  Row(Title="Skip and Shannon react to the Patriots' 24-20 win over the Jags in the AFC Championship | UNDISPUTED", Length=100),
#  Row(Title='Hát mãi ước mơ 2 | tập 13 full:Cụ bà 70 khiến giám khảo cười ngất khi sợ thí sinh bỏ lại phim trường', Length=100),
#  Row(Title='Shane McMahon calls out Daniel Bryan for his treatment of Owens & Zayn: SmackDown LIVE, Feb. 6, 2018', Length=100),
#  Row(Title='President Trump and First Lady Melania Trump arrive in Cincinnati, OH  Feb 5, 2018  Cincinnati Munic', Length=100),
#  Row(Title='Thần Tượng Bolero 2018 Tập 9 Full HD - Vòng Mini Liveshow: Đội Quang Lê chiếm trọn tình cảm khán giả', Length=100),
#  Row(Title='President Donald Trump gives URGENT Announcement on the Inspector general Report and Trade At Gaggle', Length=100),
#  Row(Title='Montreal Canadiens vs Vancouver Canucks – Dec. 19, 2017 | Game Highlights | NHL 2017/18. Обзор матча', Length=100),
#  Row(Title="Marvel's Avengers Infinity War cast reacts to the mean trolls about them on tweet || Cast Gone Crazy", Length=100),
#  Row(Title='Nhanh Như Chớp | Tập 2 Full: Trường Giang Thách Ninh Dương Lan Ngọc Vượt Qua Câu Đố Khó Nhất Quả Đất', Length=100),
#  Row(Title='A Mom Gave Her Quadruplets DNA Tests To Discover Whether Ancestry Kits Actually Do What They Say', Length=96),
#  Row(Title='اعلان نتایج ۳ بهترین - فصل سیزدهم ستاره افغان / Top 3 Elimination - Afghan Star S13 - Episode 31', Length=96),
#  Row(Title='Trump PRICELESS facial reaction when Governor tells him he needs to do Less Tweeting to his face', Length=96),
#  Row(Title="Les Denis Drolet pour le spectacle ''En attendant le beau temps'' à TLMEP Tout Le Monde En Parle", Length=96),
#  Row(Title="POST FIGHT INTERVIEW: Anthony Joshua says he would knock Wilder 'spark out' after beating Parker", Length=96),
#  Row(Title='Stephen A. Smith: ‘Players questioning legitimacy’ of Kawhi Leonard’s injury | First Take | ESPN', Length=96),
#  Row(Title='Thách thức danh hài 4 | tập 14 full: Trấn Thành khoái chí khi Trường Giang hứng đòn chổi lông gà', Length=96),
#  Row(Title='🔴 LIVE: WORLDWIDE New Years Eve Coverage - Times Square Ball Drop, LA, London, Nashville & More!', Length=96),
#  Row(Title='Insane (Full Song)  Sukhe - Jaani - Arvindr Khaira - White Hill Music - Latest Punjabi Song 2017', Length=96),
#  Row(Title='A Boogie Wit Da Hoodie - Best Friend feat. Tory Lanez [Official Audio] (Prod. by Jaegen & Nahum)', Length=96),
#  Row(Title='Why Did Rudy Giuliani Admit President Donald Trump Reimbursed Michael Cohen? | Megyn Kelly TODAY', Length=96),
#  Row(Title='#277 CROWDER IS BACK! TRUMP DID WHAT?! Ben Shapiro and Gavin McInnes Guest | Louder With Crowder', Length=96),
#  Row(Title='اعلان نتایج ۸ بهترین - فصل سیزدهم ستاره افغان / Top 8 Elimination - Afghan Star S13 - Episode 17', Length=96),
#  Row(Title='Joe Rogan is just a shill who thinks The Earth is flat,Dana White-We will get rid of Early W-ins', Length=96),
#  Row(Title="The Last Word with Lawrence O'Donnell November 21, 2017 | Lawrence O'Donnell MSNBC Today 11/21/1", Length=96),
#  Row(Title='PART 1 | RACHEL: IT WAS A HIGHLY CONTENTIOUS CAMPAIGN... | TRUMP WHITE HOUSE NEWS March 29, 2018', Length=96),
#  Row(Title='Vanderpump Rules: Tom Sandoval Actually Impresses Lisa Vanderpump (Season 6, Episode 21) | Bravo', Length=96),
#  Row(Title='Stephen A. Smith says LeBron James ‘virtually non-existent’ in Game 1 loss | SportsCenter | ESPN', Length=96),
#  Row(Title='arrest of the driver who struck pedestrians at yonge st. at sheppard and finch in toronto canada', Length=96),
#  Row(Title='Alicia Vikander: “My Breasts Are Not As Pointy As The First Lara Croft” | The Graham Norton Show', Length=96),
#  Row(Title='Sridevi In Dubai | Marriage Video | శ్రీదేవి చనిపోవటానికి ముందు పెళ్లిలో సందడి చూడండి | #SRIDEVI', Length=96),
#  Row(Title='Van hits pedestrians in Toronto, Nashville Waffle House suspect caught | ABC News special report', Length=96),
#  Row(Title='Robert Mueller Adds New Piece To Plot With New Manafort Gates Indictment | Rachel Maddow | MSNBC', Length=96),
#  Row(Title='Thần Tượng Bolero 2018 Tập 6 Full HD | Vòng Thách Đấu: Lộ diện top 6 xuất sắc nhất team Quang Lê', Length=96),
#  Row(Title="Drake Wrote Kanye's 'Yikes', Pusha T Beef Might Be Over  + Are You Still Offended By Kanye West?", Length=96),
#  Row(Title='Lil Pump - Gucci Gang Remix Ft. Bad Bunny, French Montana, J Balvin, 21, Gucci Mane, Ozuna, Remy', Length=96),
#  Row(Title='Q Clearance Patriot AKA Q Anon - Breaking Down the Coming Storm! HRC, Saudi Arabia, Trump & More', Length=96),
#  Row(Title="Sarah 'Huckabee' Sanders gets PissedOff & ANNOYED on Trump taxes question & gop tax bill passing", Length=96),
#  Row(Title="Stephen A. and Max debate: Warriors' injuries to blame if Rockets win title? | First Take | ESPN", Length=96),
#  Row(Title="SAGITTARIUS SHAWTY Gives the Real! The 6ix List (WLHH) Exclusive Interview! Toronto's Top Thotty", Length=96),
#  Row(Title='Scientists Discovered A Skin-Crawling Secret That This Strange Island Had Concealed For 80 Years', Length=96),
#  Row(Title='Escape Dog Returns To Shelter 11 Times— Then They Realized He Was Trying To Tell Them Something…', Length=96),
#  Row(Title='LiAngelo Ball and LaMelo Ball GIVE UP BASKETBALL FOREVER!! Lavar Ball Just Killed Their Careers.', Length=96),
#  Row(Title='Greatest Feminists In Feminism Herstory: Sarah Sanders | May 2, 2018 Act 1 | Full Frontal on TBS', Length=96),
#  Row(Title="Inside Zedd's $16 Million Mansion That Has a Skittles Machine | Open Door | Architectural Digest", Length=96),
#  Row(Title='Cleveland Cavaliers vs Philadelphia Sixers - Full Highlights | Nov 27, 2017 | 2017-18 NBA Season', Length=96),
#  Row(Title='Why Is YouTube Shutting Down These Channels, Kelly Sadler Backlash, PG Ninja, Malaysia, and More', Length=96),
#  Row(Title='Amrit Maan Ft Dj Flow Peg Di Washna ( Full Video)  | Himanshi Khurana | Latest Punjabi Song 2017', Length=96),
#  Row(Title='Just Listen | Official Music Video | Sidhu Moose Wala ft. Sunny Malton | BYG BYRD | Humble Music', Length=96),
#  Row(Title='UNKNOWN Mexican Street Foods You MUST Try! MEGA Mexican Pizza, BEST BBQ, and 7 Mole’s in OAXACA!', Length=96),
#  ...]

# %%
titleLengthDF.createOrReplaceTempView("titleLengthDF")
length = spark.sql("SELECT Length, COUNT(*) as freq FROM titleLengthDF GROUP BY Length, Length ORDER BY freq DESC")
length.show()
# Out:
# +------+----+
# |Length|freq|
# +------+----+
# |    43| 556|
# |    41| 473|
# |    47| 467|
# |    51| 461|
# |    48| 461|
# |    42| 459|
# |    45| 455|
# |    46| 455|
# |    34| 450|
# |    44| 449|
# |    50| 444|
# |    39| 428|
# |    58| 422|
# |    49| 419|
# |    40| 414|
# |    54| 409|
# |    53| 398|
# |    35| 397|
# |    36| 397|
# |    52| 392|
# +------+----+
# only showing top 20 rows

# %%
# word count
from pyspark.sql.types import StringType, DoubleType, IntegerType, StructField, StructType
wordCount = spark.sql("SELECT LOWER(title) as title from df")\
                 .rdd.flatMap(lambda line:line['title'].split()).map(lambda word:(word,1)).reduceByKey(lambda a,b:a+b).repartition(1).sortBy(lambda x:x[1],False)
wordCountSchema = StructType([StructField("word", StringType(), True),StructField("count", IntegerType(), True)])
wordCountDF = spark.createDataFrame(wordCount, wordCountSchema)
wordCountDF = wordCountDF.filter(wordCountDF["word"]!='')
wordCountDF.take(300)
# Out:
# [Row(word='-', count=12659),
#  Row(word='|', count=12546),
#  Row(word='the', count=8318),
#  Row(word='2018', count=3748),
#  Row(word='to', count=3740),
#  Row(word='in', count=2948),
#  Row(word='a', count=2800),
#  Row(word='of', count=2670),
#  Row(word='episode', count=2445),
#  Row(word='&', count=2284),
#  Row(word='with', count=2222),
#  Row(word='on', count=2221),
#  Row(word='and', count=2217),
#  Row(word='for', count=1504),
#  Row(word='is', count=1453),
#  Row(word='vs', count=1430),
#  Row(word='full', count=1395),
#  Row(word='you', count=1268),
#  Row(word='2017', count=1194),
#  Row(word='game', count=1172),
#  Row(word='new', count=1141),
#  Row(word='trump', count=1037),
#  Row(word='2', count=1030),
#  Row(word='video)', count=973),
#  Row(word='official', count=965),
#  Row(word='i', count=944),
#  Row(word='trailer', count=917),
#  Row(word='at', count=897),
#  Row(word='10', count=871),
#  Row(word='my', count=835),
#  Row(word='all', count=812),
#  Row(word='(official', count=811),
#  Row(word='music', count=801),
#  Row(word='from', count=783),
#  Row(word='highlights', count=774),
#  Row(word='ft.', count=751),
#  Row(word='how', count=733),
#  Row(word='top', count=702),
#  Row(word='season', count=701),
#  Row(word='best', count=696),
#  Row(word='this', count=696),
#  Row(word='what', count=679),
#  Row(word='/', count=665),
#  Row(word='songs', count=664),
#  Row(word='by', count=638),
#  Row(word='out', count=615),
#  Row(word='why', count=583),
#  Row(word='vs.', count=581),
#  Row(word='about', count=578),
#  Row(word='de', count=568),
#  Row(word='food', count=550),
#  Row(word='3', count=549),
#  Row(word='drama', count=545),
#  Row(word='nba', count=542),
#  Row(word='show', count=534),
#  Row(word='his', count=528),
#  Row(word='punjabi', count=524),
#  Row(word='video', count=522),
#  Row(word='الحلقة', count=515),
#  Row(word='latest', count=513),
#  Row(word='part', count=509),
#  Row(word='time', count=502),
#  Row(word='your', count=502),
#  Row(word='hd', count=501),
#  Row(word='ep', count=495),
#  Row(word='that', count=493),
#  Row(word='it', count=493),
#  Row(word='first', count=476),
#  Row(word='real', count=468),
#  Row(word='5', count=465),
#  Row(word='1', count=463),
#  Row(word='tv', count=460),
#  Row(word='news', count=454),
#  Row(word='live', count=453),
#  Row(word='we', count=450),
#  Row(word='song', count=449),
#  Row(word='christmas', count=445),
#  Row(word='not', count=444),
#  Row(word='la', count=443),
#  Row(word='are', count=437),
#  Row(word='day', count=434),
#  Row(word='after', count=432),
#  Row(word='do', count=418),
#  Row(word='paul', count=418),
#  Row(word='(full', count=409),
#  Row(word='will', count=399),
#  Row(word='joe', count=394),
#  Row(word='life', count=392),
#  Row(word='or', count=392),
#  Row(word='me', count=386),
#  Row(word='up', count=384),
#  Row(word='–', count=369),
#  Row(word='her', count=364),
#  Row(word='most', count=362),
#  Row(word='4', count=352),
#  Row(word='challenge', count=347),
#  Row(word='movie', count=336),
#  Row(word='+', count=328),
#  Row(word='!', count=328),
#  Row(word='awards', count=323),
#  Row(word='le', count=320),
#  Row(word='who', count=320),
#  Row(word='logan', count=314),
#  Row(word='love', count=312),
#  Row(word='more', count=311),
#  Row(word='get', count=311),
#  Row(word='march', count=306),
#  Row(word='try', count=304),
#  Row(word='les', count=303),
#  Row(word='last', count=298),
#  Row(word='مسلسل', count=298),
#  Row(word='can', count=298),
#  Row(word='test', count=296),
#  Row(word='know', count=296),
#  Row(word='be', count=292),
#  Row(word=':', count=291),
#  Row(word='ever', count=289),
#  Row(word='may', count=288),
#  Row(word='react', count=285),
#  Row(word='black', count=279),
#  Row(word='teaser', count=279),
#  Row(word='super', count=278),
#  Row(word='over', count=278),
#  Row(word='make', count=278),
#  Row(word='house', count=278),
#  Row(word='as', count=277),
#  Row(word='youtube', count=276),
#  Row(word='john', count=274),
#  Row(word='people', count=272),
#  Row(word='series', count=271),
#  Row(word='was', count=270),
#  Row(word='6', count=270),
#  Row(word='everything', count=268),
#  Row(word='lil', count=266),
#  Row(word='(2018)', count=264),
#  Row(word='cavaliers', count=261),
#  Row(word='one', count=261),
#  Row(word='donald', count=260),
#  Row(word='they', count=260),
#  Row(word='makeup', count=257),
#  Row(word='got', count=253),
#  Row(word='star', count=253),
#  Row(word='kitchen', count=253),
#  Row(word='toronto', count=251),
#  Row(word='8', count=249),
#  Row(word='stephen', count=247),
#  Row(word='feat.', count=246),
#  Row(word='7', count=245),
#  Row(word='look', count=244),
#  Row(word='comment', count=244),
#  Row(word="trump's", count=243),
#  Row(word='things', count=243),
#  Row(word='x', count=242),
#  Row(word='when', count=240),
#  Row(word='no', count=239),
#  Row(word='battle', count=239),
#  Row(word='big', count=238),
#  Row(word='war', count=238),
#  Row(word='an', count=237),
#  Row(word='he', count=236),
#  Row(word='giant', count=236),
#  Row(word='juan', count=236),
#  Row(word='interview', count=235),
#  Row(word='off', count=234),
#  Row(word='school', count=233),
#  Row(word='raptors', count=233),
#  Row(word='kids', count=232),
#  Row(word='world', count=231),
#  Row(word='wrong', count=230),
#  Row(word="it's", count=230),
#  Row(word='april', count=230),
#  Row(word='[official', count=229),
#  Row(word='2017-18', count=228),
#  Row(word='january', count=227),
#  Row(word='msnbc', count=225),
#  Row(word='golden', count=225),
#  Row(word='view', count=225),
#  Row(word='warriors', count=222),
#  Row(word='president', count=222),
#  Row(word='promo', count=222),
#  Row(word='infinity', count=221),
#  Row(word='white', count=220),
#  Row(word='||', count=218),
#  Row(word='100', count=218),
#  Row(word='michael', count=217),
#  Row(word='into', count=217),
#  Row(word='family', count=216),
#  Row(word='royal', count=216),
#  Row(word='have', count=215),
#  Row(word='goals', count=215),
#  Row(word='watch', count=213),
#  Row(word='james', count=212),
#  Row(word='their', count=211),
#  Row(word='street', count=210),
#  Row(word='if', count=210),
#  Row(word='wedding', count=208),
#  Row(word='crime', count=208),
#  Row(word='week', count=206),
#  Row(word='take', count=205),
#  Row(word='12', count=204),
#  Row(word='reacts', count=204),
#  Row(word='jake', count=203),
#  Row(word='bad', count=203),
#  Row(word='diy', count=201),
#  Row(word='funny', count=200),
#  Row(word='11', count=200),
#  Row(word='cleveland', count=198),
#  Row(word='our', count=198),
#  Row(word='video]', count=197),
#  Row(word='et', count=197),
#  Row(word='voice', count=197),
#  Row(word='patrol', count=196),
#  Row(word='makes', count=196),
#  Row(word='chris', count=196),
#  Row(word='song)', count=195),
#  Row(word='like', count=194),
#  Row(word='has', count=194),
#  Row(word='man', count=194),
#  Row(word='gets', count=193),
#  Row(word='meghan', count=191),
#  Row(word='december', count=187),
#  Row(word='14', count=187),
#  Row(word='down', count=187),
#  Row(word='state', count=187),
#  Row(word='review', count=187),
#  Row(word='so', count=186),
#  Row(word='hot', count=185),
#  Row(word='ka', count=185),
#  Row(word='des', count=185),
#  Row(word='•', count=183),
#  Row(word='back', count=183),
#  Row(word='ball', count=182),
#  Row(word='goes', count=181),
#  Row(word='extended', count=181),
#  Row(word="don't", count=181),
#  Row(word='jimmy', count=179),
#  Row(word='rani', count=178),
#  Row(word='bowl', count=177),
#  Row(word='rogan', count=177),
#  Row(word='drake', count=177),
#  Row(word='film', count=176),
#  Row(word='did', count=175),
#  Row(word='breaking', count=175),
#  Row(word='challenge!', count=175),
#  Row(word='15', count=174),
#  Row(word='digital', count=170),
#  Row(word='made', count=170),
#  Row(word='(hd)', count=169),
#  Row(word='en', count=169),
#  Row(word='hum', count=169),
#  Row(word='vaani', count=168),
#  Row(word='cardi', count=168),
#  Row(word='வாணி', count=168),
#  Row(word='ராணி', count=168),
#  Row(word='ary', count=168),
#  Row(word='year', count=167),
#  Row(word='fortnite', count=166),
#  Row(word='bill', count=166),
#  Row(word='american', count=166),
#  Row(word='face', count=166),
#  Row(word='february', count=165),
#  Row(word='16', count=165),
#  Row(word='kevin', count=165),
#  Row(word='daily', count=165),
#  Row(word='secret', count=165),
#  Row(word='un', count=164),
#  Row(word='us', count=163),
#  Row(word='b', count=162),
#  Row(word='13', count=162),
#  Row(word='tour', count=161),
#  Row(word='lebron', count=161),
#  Row(word='podcast', count=161),
#  Row(word='[hd]', count=161),
#  Row(word='sa', count=159),
#  Row(word='morning', count=159),
#  Row(word='à', count=158),
#  Row(word='20', count=157),
#  Row(word='theory:', count=156),
#  Row(word='explained', count=155),
#  Row(word='justin', count=154),
#  Row(word='w/', count=154),
#  Row(word='laugh', count=154),
#  Row(word='see', count=154),
#  Row(word='(', count=154),
#  Row(word='today', count=152),
#  Row(word='2018)', count=152),
#  Row(word='story', count=152),
#  Row(word='team', count=150),
#  Row(word='old', count=150),
#  Row(word='9', count=150),
#  Row(word='never', count=150),
#  Row(word='minutes', count=149),
#  Row(word='says', count=149),
#  Row(word='just', count=149),
#  Row(word='harry', count=148),
#  Row(word='every', count=146),
#  Row(word='final', count=146),
#  Row(word='closer', count=146),
#  Row(word='movies', count=145),
#  Row(word='ooltah', count=145)]

# %% [markdown]
# ### tags

# %%
from pyspark.sql.types import StringType, DoubleType, IntegerType, StructField, StructType
wordCount = spark.sql("SELECT LOWER(tags) as tags from df")\
                 .rdd.flatMap(lambda line:line['tags'].split("|"))\
                 .map(lambda word:(word,1)).reduceByKey(lambda a,b:a+b)\
                 .repartition(1).sortBy(lambda x:x[1],False)
wordCountSchema = StructType([StructField("word", StringType(), True),\
                              StructField("count", IntegerType(), True)])
wordCountDF = spark.createDataFrame(wordCount, wordCountSchema)
wordCountDF = wordCountDF.filter(wordCountDF["word"]!='')
wordCountDF.take(300)
# Out:
# [Row(word='"funny"', count=3890),
#  Row(word='"comedy"', count=2953),
#  Row(word='[none]', count=2384),
#  Row(word='"news"', count=2180),
#  Row(word='"politics"', count=1471),
#  Row(word='"donald trump"', count=1345),
#  Row(word='"music"', count=1153),
#  Row(word='"2018"', count=1147),
#  Row(word='"video"', count=1141),
#  Row(word='"entertainment"', count=1123),
#  Row(word='"trump"', count=1120),
#  Row(word='"food"', count=1090),
#  Row(word='"humor"', count=1033),
#  Row(word='"review"', count=1013),
#  Row(word='"talk show"', count=947),
#  Row(word='"nba"', count=918),
#  Row(word='"reaction"', count=918),
#  Row(word='"interview"', count=884),
#  Row(word='"television"', count=851),
#  Row(word='"trailer"', count=848),
#  Row(word='"rap"', count=839),
#  Row(word='"drama"', count=828),
#  Row(word='"family friendly"', count=775),
#  Row(word='"2017"', count=767),
#  Row(word='"comedian"', count=757),
#  Row(word='"how to"', count=732),
#  Row(word='"tv"', count=713),
#  Row(word='"react"', count=697),
#  Row(word='"basketball"', count=695),
#  Row(word='"diy"', count=694),
#  Row(word='"sports"', count=688),
#  Row(word='"hollywood"', count=672),
#  Row(word='"celebrity"', count=663),
#  Row(word='"funny videos"', count=660),
#  Row(word='"movie"', count=648),
#  Row(word='"family"', count=630),
#  Row(word='"science"', count=628),
#  Row(word='"animation"', count=625),
#  Row(word='"new"', count=613),
#  Row(word='"jokes"', count=596),
#  Row(word='"cooking"', count=595),
#  Row(word='"highlights"', count=593),
#  Row(word='"best"', count=589),
#  Row(word='"podcast"', count=586),
#  Row(word='"canada"', count=578),
#  Row(word='"show"', count=566),
#  Row(word='"game"', count=565),
#  Row(word='"buzzfeed"', count=564),
#  Row(word='"vlog"', count=560),
#  Row(word='"hip hop"', count=558),
#  Row(word='"breaking news"', count=558),
#  Row(word='"youtube"', count=552),
#  Row(word='"late night"', count=536),
#  Row(word='"fun"', count=535),
#  Row(word='"tutorial"', count=530),
#  Row(word='"cnn"', count=527),
#  Row(word='"celebrities"', count=527),
#  Row(word='"official"', count=523),
#  Row(word='"hilarious"', count=520),
#  Row(word='"love"', count=508),
#  Row(word='"funny video"', count=507),
#  Row(word='"president trump"', count=507),
#  Row(word='"challenge"', count=506),
#  Row(word='"clip"', count=503),
#  Row(word='"movies"', count=500),
#  Row(word='"live"', count=490),
#  Row(word='"pop"', count=481),
#  Row(word='"kids"', count=475),
#  Row(word='"nbc"', count=472),
#  Row(word='"film"', count=471),
#  Row(word='"top 10"', count=471),
#  Row(word='"logan paul"', count=469),
#  Row(word='"makeup"', count=447),
#  Row(word='"recipe"', count=437),
#  Row(word='"us news"', count=437),
#  Row(word='"punjabi songs"', count=425),
#  Row(word='"games"', count=420),
#  Row(word='"humour"', count=413),
#  Row(word='"christmas"', count=411),
#  Row(word='"music video"', count=410),
#  Row(word='"beauty"', count=405),
#  Row(word='"sketch"', count=402),
#  Row(word='"famous"', count=393),
#  Row(word='"liberal"', count=391),
#  Row(word='"gordon ramsay"', count=386),
#  Row(word='"gordon"', count=379),
#  Row(word='"viral"', count=375),
#  Row(word='"satire"', count=374),
#  Row(word='"fbe"', count=371),
#  Row(word='"marvel"', count=368),
#  Row(word='"joke"', count=367),
#  Row(word='"fine brothers entertainment"', count=366),
#  Row(word='"fine brothers"', count=364),
#  Row(word='"thefinebros"', count=361),
#  Row(word='"watch"', count=358),
#  Row(word='"nba highlights"', count=353),
#  Row(word='"mystery"', count=350),
#  Row(word='"try not to laugh"', count=350),
#  Row(word='"investigation"', count=348),
#  Row(word='"parody"', count=344),
#  Row(word='"football"', count=341),
#  Row(word='"disney"', count=340),
#  Row(word='"chef"', count=337),
#  Row(word='"rhett and link"', count=336),
#  Row(word='"cbs"', count=334),
#  Row(word='"promo"', count=334),
#  Row(word='"kid friendly"', count=333),
#  Row(word='"meme"', count=330),
#  Row(word='"the"', count=329),
#  Row(word='"unboxing"', count=328),
#  Row(word='"jake paul"', count=326),
#  Row(word='"msnbc"', count=324),
#  Row(word='"james corden"', count=324),
#  Row(word='"latest news"', count=324),
#  Row(word='"reactions"', count=322),
#  Row(word='"ufc"', count=318),
#  Row(word='"technology"', count=316),
#  Row(word='"toronto"', count=315),
#  Row(word='"sp:ty=high"', count=313),
#  Row(word='"current events"', count=313),
#  Row(word='"paul"', count=313),
#  Row(word='"kitchen"', count=313),
#  Row(word='"laugh"', count=310),
#  Row(word='"celebrity news"', count=310),
#  Row(word='"fashion"', count=310),
#  Row(word='"chef ramsay"', count=310),
#  Row(word='"gameplay"', count=310),
#  Row(word='"challenges"', count=309),
#  Row(word='"host"', count=307),
#  Row(word='"gaming"', count=305),
#  Row(word='"india"', count=304),
#  Row(word='"kids react"', count=303),
#  Row(word='"vs"', count=303),
#  Row(word='"dance"', count=302),
#  Row(word='"fox"', count=301),
#  Row(word='"reviews"', count=300),
#  Row(word='"world"', count=299),
#  Row(word='"education"', count=298),
#  Row(word='"police"', count=298),
#  Row(word='"adventure"', count=297),
#  Row(word='"fortnite"', count=297),
#  Row(word='"elders react"', count=294),
#  Row(word='"conspiracy"', count=294),
#  Row(word='"sp:vl=en-us"', count=294),
#  Row(word='"teens react"', count=293),
#  Row(word='"lebron james"', count=293),
#  Row(word='"fox news"', count=291),
#  Row(word='"drake"', count=290),
#  Row(word='"celeb"', count=289),
#  Row(word='"nbc tv"', count=287),
#  Row(word='"mma"', count=287),
#  Row(word='"facebook"', count=287),
#  Row(word='"comedic"', count=286),
#  Row(word='"lol"', count=284),
#  Row(word='"punjabi"', count=283),
#  Row(word='"prank"', count=279),
#  Row(word='"russia"', count=279),
#  Row(word='"compilation"', count=278),
#  Row(word='"latest punjabi songs 2018"', count=277),
#  Row(word='"ramsay"', count=277),
#  Row(word='"instagram"', count=275),
#  Row(word='"stephen colbert"', count=270),
#  Row(word='"travel"', count=269),
#  Row(word='"animated"', count=269),
#  Row(word='"hockey"', count=266),
#  Row(word='"cbc"', count=265),
#  Row(word='"future"', count=265),
#  Row(word='"animals"', count=265),
#  Row(word='"james"', count=264),
#  Row(word='"snl"', count=264),
#  Row(word='"trending"', count=264),
#  Row(word='"nhl"', count=263),
#  Row(word='"punjabi music"', count=263),
#  Row(word='"reddit"', count=263),
#  Row(word='"cleveland cavaliers"', count=263),
#  Row(word='"avengers"', count=261),
#  Row(word='"fine bros"', count=261),
#  Row(word='"facts"', count=258),
#  Row(word='"world news"', count=257),
#  Row(word='"space"', count=257),
#  Row(word='"hd"', count=256),
#  Row(word='"fail"', count=255),
#  Row(word='"game highlights"', count=253),
#  Row(word='"talk"', count=253),
#  Row(word='"white house"', count=253),
#  Row(word='"memes"', count=252),
#  Row(word='"learn"', count=251),
#  Row(word='"crazy"', count=250),
#  Row(word='"progressive"', count=249),
#  Row(word='"twitter"', count=248),
#  Row(word='"play"', count=245),
#  Row(word='"variety"', count=245),
#  Row(word='"talent"', count=244),
#  Row(word='"finebros"', count=243),
#  Row(word='"cavaliers"', count=241),
#  Row(word='"song"', count=240),
#  Row(word='"top"', count=238),
#  Row(word='"action"', count=238),
#  Row(word='"amazing"', count=235),
#  Row(word='"latest"', count=235),
#  Row(word='"cook"', count=235),
#  Row(word='"highlight"', count=234),
#  Row(word='"the late late show"', count=234),
#  Row(word='"latest punjabi songs"', count=234),
#  Row(word='"the voice"', count=233),
#  Row(word='"awards"', count=233),
#  Row(word='"cute"', count=233),
#  Row(word='"house"', count=232),
#  Row(word='"to"', count=231),
#  Row(word='"school"', count=230),
#  Row(word='"team edge"', count=229),
#  Row(word='"internet"', count=228),
#  Row(word='"culture"', count=228),
#  Row(word='"rhett"', count=227),
#  Row(word='"h3h3"', count=227),
#  Row(word='"do it yourself"', count=226),
#  Row(word='"tricks"', count=226),
#  Row(word='"star wars"', count=226),
#  Row(word='"robert mueller"', count=226),
#  Row(word='"colbert"', count=225),
#  Row(word='"ramsey"', count=225),
#  Row(word='"infinity war"', count=224),
#  Row(word='"link"', count=224),
#  Row(word='"lifestyle"', count=223),
#  Row(word='"seth"', count=223),
#  Row(word='"logan"', count=222),
#  Row(word='"black panther"', count=222),
#  Row(word='"videos"', count=221),
#  Row(word='"pranks"', count=221),
#  Row(word='"murder"', count=220),
#  Row(word='"mythical"', count=219),
#  Row(word='"cardi b"', count=218),
#  Row(word='"season"', count=218),
#  Row(word='"daily"', count=217),
#  Row(word='"conservative"', count=217),
#  Row(word='"punjabi latest songs"', count=217),
#  Row(word='"how to make"', count=216),
#  Row(word='"health"', count=216),
#  Row(word='"scary"', count=215),
#  Row(word='"series"', count=215),
#  Row(word='"star"', count=213),
#  Row(word='"battle"', count=213),
#  Row(word='"iphone"', count=212),
#  Row(word='"respond"', count=212),
#  Row(word='"for the first time"', count=211),
#  Row(word='"test"', count=211),
#  Row(word='"top 5"', count=211),
#  Row(word='"fails"', count=210),
#  Row(word='"late late show"', count=210),
#  Row(word='"video games"', count=210),
#  Row(word='"responds"', count=209),
#  Row(word='"reacts"', count=208),
#  Row(word='"comment"', count=208),
#  Row(word='"warriors"', count=207),
#  Row(word='"cavs"', count=207),
#  Row(word='"makeup tutorial"', count=207),
#  Row(word='"laugh challenge"', count=205),
#  Row(word='"women"', count=205),
#  Row(word='"plays"', count=205),
#  Row(word='"kitchen nightmares"', count=205),
#  Row(word='"monologue"', count=204),
#  Row(word='"kanye west"', count=204),
#  Row(word='"new york"', count=203),
#  Row(word='"daytime"', count=202),
#  Row(word='"girls"', count=201),
#  Row(word='"media"', count=201),
#  Row(word='"kevin durant"', count=200),
#  Row(word='"jimmy"', count=199),
#  Row(word='"the philip defranco show"', count=199),
#  Row(word='"joe rogan"', count=199),
#  Row(word='"songs"', count=198),
#  Row(word='"florida"', count=197),
#  Row(word='"bts"', count=197),
#  Row(word='"radio"', count=197),
#  Row(word='"lyrics"', count=197),
#  Row(word='"crime patrol"', count=197),
#  Row(word='"vlogger"', count=197),
#  Row(word='"us"', count=195),
#  Row(word='"corden"', count=195),
#  Row(word='"team"', count=195),
#  Row(word='"netflix"', count=194),
#  Row(word='"fight"', count=194),
#  Row(word='"ellen degeneres"', count=194),
#  Row(word='"episode"', count=193),
#  Row(word='"sketch comedy"', count=193),
#  Row(word='"ellen"', count=193),
#  Row(word='"competition"', count=193),
#  Row(word='"philip defranco show"', count=193),
#  Row(word='"republican"', count=192),
#  Row(word='"desi"', count=192),
#  Row(word='"weird"', count=192),
#  Row(word='"meyers"', count=192),
#  Row(word='"h3h3productions"', count=191),
#  Row(word='"abs-cbn"', count=191),
#  Row(word='"tips"', count=191),
#  Row(word='"the young turks"', count=191),
#  Row(word='"vice"', count=191),
#  Row(word='"records"', count=190),
#  Row(word='"youtubers react"', count=190),
#  Row(word='"setindia"', count=189)]

# %%
# the most popular tags
tags = spark.sql("SELECT tags, COUNT(*) as freq FROM df GROUP BY tags ORDER BY freq DESC")
tags.show(10)
# Out:
# +------------------------------+----+
# |                          tags|freq|
# +------------------------------+----+
# |                        [none]|2378|
# |          "the real"|"dayti...| 127|
# |          "best vines 2018"...| 120|
# |          "Vaani rani"|"ran...| 116|
# |          "senegal"|"video"...|  85|
# |          "hkayet tounsia"|...|  74|
# |          "reaction time"|"...|  72|
# |"江苏卫视"|"非诚勿扰"|"姜振...|  72|
# |          "sab tv channel"|...|  70|
# |          "The Late Show"|"...|  69|
# +------------------------------+----+
# only showing top 10 rows

# %%
df.filter("tags==''").show(truncate=False)
# Out:
# +-----------+-------------+-----+-------------+------------+----+-----+-----+--------+-------------+--------------+
# |category_id|trending_date|title|channel_title|publish_time|tags|views|likes|dislikes|comment_count|category_title|
# +-----------+-------------+-----+-------------+------------+----+-----+-----+--------+-------------+--------------+
# +-----------+-------------+-----+-------------+------------+----+-----+-----+--------+-------------+--------------+

# %% [markdown]
# ##### other data

# %%
df = spark.read.csv('/Users/zhujinghong/Downloads/5003\ project/pre_data/US_pre.csv',header=True)

# %%
df.createOrReplaceTempView("df")

# %%
from pyspark.sql.types import StringType, DoubleType, IntegerType, StructField, StructType
wordCount = spark.sql("SELECT LOWER(tags) as tags from df")\
                 .rdd.flatMap(lambda line:line['tags'].split("|")).map(lambda word:(word,1)).reduceByKey(lambda a,b:a+b).repartition(1).sortBy(lambda x:x[1],False)
wordCountSchema = StructType([StructField("word", StringType(), True),StructField("count", IntegerType(), True)])
wordCountDF = spark.createDataFrame(wordCount, wordCountSchema)
wordCountDF = wordCountDF.filter(wordCountDF["word"]!='')
wordCountDF.take(300)
# Out:
# [Row(word='"funny"', count=4136),
#  Row(word='"comedy"', count=3642),
#  Row(word='"how to"', count=1700),
#  Row(word='"music"', count=1659),
#  Row(word='"pop"', count=1632),
#  Row(word='[none]', count=1532),
#  Row(word='"trailer"', count=1411),
#  Row(word='"food"', count=1279),
#  Row(word='"2018"', count=1271),
#  Row(word='"news"', count=1253),
#  Row(word='"review"', count=1238),
#  Row(word='"science"', count=1237),
#  Row(word='"makeup"', count=1236),
#  Row(word='"humor"', count=1209),
#  Row(word='"celebrity"', count=1130),
#  Row(word='"diy"', count=1109),
#  Row(word='"tutorial"', count=1054),
#  Row(word='"video"', count=1029),
#  Row(word='"television"', count=1021),
#  Row(word='"live"', count=1017),
#  Row(word='"interview"', count=988),
#  Row(word='"vlog"', count=956),
#  Row(word='"entertainment"', count=949),
#  Row(word='"animation"', count=945),
#  Row(word='"beauty"', count=922),
#  Row(word='"movie"', count=908),
#  Row(word='"official"', count=895),
#  Row(word='"comedian"', count=877),
#  Row(word='"cooking"', count=864),
#  Row(word='"fun"', count=848),
#  Row(word='"hollywood"', count=846),
#  Row(word='"cute"', count=826),
#  Row(word='"buzzfeed"', count=800),
#  Row(word='"talk show"', count=788),
#  Row(word='"celebrities"', count=787),
#  Row(word='"late night"', count=782),
#  Row(word='"recipe"', count=778),
#  Row(word='"nbc"', count=758),
#  Row(word='"sports"', count=752),
#  Row(word='"family friendly"', count=751),
#  Row(word='"animals"', count=721),
#  Row(word='"best"', count=718),
#  Row(word='"education"', count=711),
#  Row(word='"music video"', count=711),
#  Row(word='"fashion"', count=695),
#  Row(word='"movies"', count=695),
#  Row(word='"challenge"', count=687),
#  Row(word='"records"', count=685),
#  Row(word='"2017"', count=676),
#  Row(word='"funny video"', count=675),
#  Row(word='"basketball"', count=655),
#  Row(word='"nba"', count=634),
#  Row(word='"jokes"', count=633),
#  Row(word='"film"', count=628),
#  Row(word='"marvel"', count=621),
#  Row(word='"technology"', count=619),
#  Row(word='"makeup tutorial"', count=607),
#  Row(word='"family"', count=603),
#  Row(word='"game"', count=602),
#  Row(word='"dance"', count=599),
#  Row(word='"documentary"', count=588),
#  Row(word='"new"', count=587),
#  Row(word='"christmas"', count=581),
#  Row(word='"show"', count=579),
#  Row(word='"snl"', count=578),
#  Row(word='"disney"', count=578),
#  Row(word='"sketch"', count=572),
#  Row(word='"drama"', count=567),
#  Row(word='"games"', count=566),
#  Row(word='"reaction"', count=551),
#  Row(word='"the"', count=543),
#  Row(word='"youtube"', count=535),
#  Row(word='"clip"', count=534),
#  Row(word='"highlights"', count=534),
#  Row(word='"love"', count=517),
#  Row(word='"football"', count=510),
#  Row(word='"animated"', count=509),
#  Row(word='"star wars"', count=507),
#  Row(word='"hilarious"', count=495),
#  Row(word='"funny videos"', count=494),
#  Row(word='"amazing"', count=480),
#  Row(word='"cbs"', count=479),
#  Row(word='"famous"', count=475),
#  Row(word='"parody"', count=474),
#  Row(word='"action"', count=461),
#  Row(word='"kids"', count=453),
#  Row(word='"politics"', count=452),
#  Row(word='"tv"', count=450),
#  Row(word='"lol"', count=449),
#  Row(word='"song"', count=446),
#  Row(word='"kitchen"', count=444),
#  Row(word='"chef"', count=443),
#  Row(word='"vlogger"', count=436),
#  Row(word='"laugh"', count=421),
#  Row(word='"joke"', count=420),
#  Row(word='"official trailer"', count=419),
#  Row(word='"bts"', count=415),
#  Row(word='"lifestyle"', count=414),
#  Row(word='"cook"', count=409),
#  Row(word='"health"', count=408),
#  Row(word='"cat"', count=407),
#  Row(word='"avengers"', count=404),
#  Row(word='"celeb"', count=400),
#  Row(word='"cosmetics"', count=400),
#  Row(word='"comedic"', count=395),
#  Row(word='"cats"', count=395),
#  Row(word='"to"', count=394),
#  Row(word='"country"', count=390),
#  Row(word='"host"', count=390),
#  Row(word='"james corden"', count=390),
#  Row(word='"react"', count=390),
#  Row(word='"netflix"', count=385),
#  Row(word='"cartoon"', count=381),
#  Row(word='"rap"', count=380),
#  Row(word='"nbc tv"', count=380),
#  Row(word='"olympics"', count=377),
#  Row(word='"highlight"', count=369),
#  Row(word='"unboxing"', count=366),
#  Row(word='"new york"', count=363),
#  Row(word='"alternative"', count=363),
#  Row(word='"official video"', count=357),
#  Row(word='"apple"', count=351),
#  Row(word='"home"', count=350),
#  Row(word='"talk"', count=349),
#  Row(word='"pets"', count=348),
#  Row(word='"black panther"', count=341),
#  Row(word='"alesso"', count=339),
#  Row(word='"watch"', count=338),
#  Row(word='"experiment"', count=335),
#  Row(word='"tech"', count=334),
#  Row(word='"trending"', count=333),
#  Row(word='"kitten"', count=331),
#  Row(word='"fox"', count=330),
#  Row(word='"chocolate"', count=330),
#  Row(word='"test"', count=329),
#  Row(word='"adventure"', count=329),
#  Row(word='"lelepons"', count=328),
#  Row(word='"shots"', count=328),
#  Row(word='"reviews"', count=327),
#  Row(word='"school"', count=326),
#  Row(word='"learn"', count=326),
#  Row(word='"epic"', count=325),
#  Row(word='"hannahstocking"', count=324),
#  Row(word='"rudymancuso"', count=324),
#  Row(word='"breaking news"', count=324),
#  Row(word='"style"', count=323),
#  Row(word='"educational"', count=321),
#  Row(word='"anitta"', count=318),
#  Row(word='"travel"', count=317),
#  Row(word='"talent"', count=317),
#  Row(word='"soccer"', count=316),
#  Row(word='"haul"', count=316),
#  Row(word='"fail"', count=313),
#  Row(word='"shotsstudios"', count=312),
#  Row(word='"bbc"', count=312),
#  Row(word='"anwar"', count=312),
#  Row(word='"donald trump"', count=307),
#  Row(word='"do it yourself"', count=306),
#  Row(word='"kim kardashian"', count=306),
#  Row(word='"nature"', count=306),
#  Row(word='"inanna"', count=305),
#  Row(word='"sarkis"', count=305),
#  Row(word='"how to make"', count=304),
#  Row(word='"brazil"', count=304),
#  Row(word='"history"', count=302),
#  Row(word='"satire"', count=298),
#  Row(word='"house"', count=297),
#  Row(word='"google"', count=296),
#  Row(word='"cardi b"', count=295),
#  Row(word='"us news"', count=295),
#  Row(word='"james charles"', count=295),
#  Row(word='"singing"', count=294),
#  Row(word='"the voice"', count=294),
#  Row(word='"easy"', count=292),
#  Row(word='"viral"', count=291),
#  Row(word='"plays"', count=291),
#  Row(word='"tasty"', count=290),
#  Row(word='"world news"', count=289),
#  Row(word='"james"', count=289),
#  Row(word='"challenges"', count=289),
#  Row(word='"abc"', count=288),
#  Row(word='"actor"', count=286),
#  Row(word='"stephen colbert"', count=285),
#  Row(word='"celebrity news"', count=283),
#  Row(word='"the late late show"', count=282),
#  Row(word='"amazon"', count=281),
#  Row(word='"sketch comedy"', count=280),
#  Row(word='"infinity war"', count=280),
#  Row(word='"super bowl"', count=279),
#  Row(word='"rca records label"', count=279),
#  Row(word='"iphone"', count=277),
#  Row(word='"wildlife"', count=277),
#  Row(word='"cool"', count=276),
#  Row(word='"friends"', count=275),
#  Row(word='"wwe"', count=273),
#  Row(word='"camila cabello"', count=273),
#  Row(word='"kelly clarkson"', count=272),
#  Row(word='"tricks"', count=271),
#  Row(word='"musician"', count=270),
#  Row(word='"trump"', count=268),
#  Row(word='"play"', count=266),
#  Row(word='"homemade"', count=265),
#  Row(word='"saturday night live"', count=263),
#  Row(word='"hd"', count=263),
#  Row(word='"colbert"', count=262),
#  Row(word='"space"', count=262),
#  Row(word='"complex media"', count=261),
#  Row(word='"complex"', count=261),
#  Row(word='"luxury"', count=261),
#  Row(word='"nfl"', count=259),
#  Row(word='"dogs"', count=259),
#  Row(word='"design"', count=258),
#  Row(word='"asmr"', count=258),
#  Row(word='"rhett and link"', count=258),
#  Row(word='"survival"', count=256),
#  Row(word='"late late show"', count=253),
#  Row(word='"corden"', count=253),
#  Row(word='"iphone x"', count=253),
#  Row(word='"kylie jenner"', count=253),
#  Row(word='"fidget spinners"', count=252),
#  Row(word='"wild"', count=251),
#  Row(word='"island"', count=251),
#  Row(word='"fine brothers"', count=250),
#  Row(word='"fbe"', count=250),
#  Row(word='"fine brothers entertainment"', count=250),
#  Row(word='"los angeles"', count=249),
#  Row(word='"how-to"', count=249),
#  Row(word='"thefinebros"', count=247),
#  Row(word='"american idol"', count=247),
#  Row(word='"dog"', count=246),
#  Row(word='"rock"', count=244),
#  Row(word='"hip hop"', count=244),
#  Row(word='"sing"', count=244),
#  Row(word='"espn"', count=243),
#  Row(word='"baking"', count=243),
#  Row(word='"makeover"', count=242),
#  Row(word='"cnn"', count=242),
#  Row(word='"competition"', count=242),
#  Row(word='"promo"', count=241),
#  Row(word='"boyfriend"', count=240),
#  Row(word='"weird"', count=240),
#  Row(word='"dating"', count=240),
#  Row(word='"ellen"', count=240),
#  Row(word='"lyrics"', count=238),
#  Row(word='"teaser"', count=237),
#  Row(word='"reality tv"', count=237),
#  Row(word='"the last jedi"', count=236),
#  Row(word='"r&b"', count=235),
#  Row(word='"youtuber"', count=234),
#  Row(word='"crazy"', count=234),
#  Row(word='"women"', count=233),
#  Row(word='"culture"', count=233),
#  Row(word='"transformation"', count=232),
#  Row(word='"interviews"', count=232),
#  Row(word='"bottle flip"', count=232),
#  Row(word='"streaming"', count=232),
#  Row(word='"fortnite"', count=231),
#  Row(word='"kid friendly"', count=230),
#  Row(word='"season"', count=230),
#  Row(word='"latest news"', count=230),
#  Row(word='"cake"', count=230),
#  Row(word='"gossip"', count=230),
#  Row(word='"holiday"', count=229),
#  Row(word='"hair"', count=229),
#  Row(word='"top 10"', count=228),
#  Row(word='"kanye west"', count=227),
#  Row(word='"tips"', count=227),
#  Row(word='"try"', count=227),
#  Row(word='"fitness"', count=227),
#  Row(word='"simon"', count=226),
#  Row(word='"sp:ty=high"', count=225),
#  Row(word='"future"', count=225),
#  Row(word='"how"', count=224),
#  Row(word='"reality"', count=223),
#  Row(word='"make"', count=223),
#  Row(word='"british"', count=221),
#  Row(word='"meghan markle"', count=221),
#  Row(word='"variety"', count=220),
#  Row(word='"australia"', count=220),
#  Row(word='"drugstore"', count=220),
#  Row(word='"improv"', count=220),
#  Row(word='"cover"', count=220),
#  Row(word='"performance"', count=220),
#  Row(word='"beyonce"', count=219),
#  Row(word='"of"', count=219),
#  Row(word='"comics"', count=218),
#  Row(word='"money"', count=218),
#  Row(word='"relationships"', count=217),
#  Row(word='"stand-up"', count=217),
#  Row(word='"hacks"', count=217),
#  Row(word='"vlogging"', count=215),
#  Row(word='"clean"', count=215),
#  Row(word='"vlogs"', count=215),
#  Row(word='"food porn"', count=214),
#  Row(word='"nbc news"', count=214),
#  Row(word='"screen junkies"', count=213),
#  Row(word='"screenjunkies"', count=213),
#  Row(word='"gaming"', count=213),
#  Row(word='"slow motion"', count=212),
#  Row(word='"tonight"', count=212)]

# %% [markdown]
# ### pubilish_time

# %%
pubTimeDF.take(300)
# Out:
# [Row(publish_time='2018-03-27T16:08:41.000Z', time='16'),
#  Row(publish_time='2018-04-14T19:53:33.000Z', time='19'),
#  Row(publish_time='2018-05-02T17:43:56.000Z', time='17'),
#  Row(publish_time='2018-02-21T00:55:41.000Z', time='00'),
#  Row(publish_time='2018-01-29T03:11:56.000Z', time='03'),
#  Row(publish_time='2018-03-27T13:00:02.000Z', time='13'),
#  Row(publish_time='2018-05-29T05:37:33.000Z', time='05'),
#  Row(publish_time='2018-02-04T09:16:55.000Z', time='09'),
#  Row(publish_time='2018-01-24T16:22:24.000Z', time='16'),
#  Row(publish_time='2017-12-25T04:29:43.000Z', time='04'),
#  Row(publish_time='2017-12-13T06:52:20.000Z', time='06'),
#  Row(publish_time='2018-01-19T17:00:05.000Z', time='17'),
#  Row(publish_time='2018-04-03T04:52:48.000Z', time='04'),
#  Row(publish_time='2018-03-18T11:47:57.000Z', time='11'),
#  Row(publish_time='2017-12-01T18:41:10.000Z', time='18'),
#  Row(publish_time='2017-12-29T18:30:00.000Z', time='18'),
#  Row(publish_time='2018-01-06T06:23:43.000Z', time='06'),
#  Row(publish_time='2017-12-12T14:30:01.000Z', time='14'),
#  Row(publish_time='2018-05-10T19:00:03.000Z', time='19'),
#  Row(publish_time='2018-02-15T05:17:26.000Z', time='05'),
#  Row(publish_time='2018-01-26T18:05:44.000Z', time='18'),
#  Row(publish_time='2018-02-11T17:47:39.000Z', time='17'),
#  Row(publish_time='2018-01-29T14:50:04.000Z', time='14'),
#  Row(publish_time='2018-01-06T16:00:02.000Z', time='16'),
#  Row(publish_time='2018-02-23T07:40:54.000Z', time='07'),
#  Row(publish_time='2018-04-20T17:01:44.000Z', time='17'),
#  Row(publish_time='2018-02-07T05:09:42.000Z', time='05'),
#  Row(publish_time='2018-01-15T04:00:02.000Z', time='04'),
#  Row(publish_time='2018-04-27T16:30:03.000Z', time='16'),
#  Row(publish_time='2017-11-11T16:00:04.000Z', time='16'),
#  Row(publish_time='2018-03-25T00:23:09.000Z', time='00'),
#  Row(publish_time='2018-05-13T14:45:00.000Z', time='14'),
#  Row(publish_time='2017-12-20T19:00:04.000Z', time='19'),
#  Row(publish_time='2017-12-01T05:03:22.000Z', time='05'),
#  Row(publish_time='2017-12-19T16:34:16.000Z', time='16'),
#  Row(publish_time='2018-05-04T10:00:00.000Z', time='10'),
#  Row(publish_time='2017-12-11T21:31:35.000Z', time='21'),
#  Row(publish_time='2018-04-24T03:30:01.000Z', time='03'),
#  Row(publish_time='2018-03-05T01:15:47.000Z', time='01'),
#  Row(publish_time='2018-04-19T16:08:33.000Z', time='16'),
#  Row(publish_time='2018-01-14T09:10:25.000Z', time='09'),
#  Row(publish_time='2017-11-16T22:00:03.000Z', time='22'),
#  Row(publish_time='2018-03-30T23:00:01.000Z', time='23'),
#  Row(publish_time='2018-03-23T10:00:08.000Z', time='10'),
#  Row(publish_time='2018-02-02T01:00:01.000Z', time='01'),
#  Row(publish_time='2018-05-30T19:00:00.000Z', time='19'),
#  Row(publish_time='2018-03-05T01:00:00.000Z', time='01'),
#  Row(publish_time='2018-05-04T17:41:14.000Z', time='17'),
#  Row(publish_time='2017-11-30T13:00:01.000Z', time='13'),
#  Row(publish_time='2018-05-04T09:58:57.000Z', time='09'),
#  Row(publish_time='2018-02-28T15:45:33.000Z', time='15'),
#  Row(publish_time='2018-06-01T04:00:04.000Z', time='04'),
#  Row(publish_time='2017-12-23T15:00:06.000Z', time='15'),
#  Row(publish_time='2018-04-28T05:06:59.000Z', time='05'),
#  Row(publish_time='2018-02-09T21:12:14.000Z', time='21'),
#  Row(publish_time='2017-11-23T15:30:00.000Z', time='15'),
#  Row(publish_time='2018-05-17T20:00:01.000Z', time='20'),
#  Row(publish_time='2018-05-20T02:37:05.000Z', time='02'),
#  Row(publish_time='2018-04-04T01:00:05.000Z', time='01'),
#  Row(publish_time='2017-11-20T10:53:36.000Z', time='10'),
#  Row(publish_time='2018-03-06T16:07:26.000Z', time='16'),
#  Row(publish_time='2018-02-28T17:00:01.000Z', time='17'),
#  Row(publish_time='2018-03-14T17:16:26.000Z', time='17'),
#  Row(publish_time='2018-03-11T22:14:45.000Z', time='22'),
#  Row(publish_time='2018-01-11T21:18:01.000Z', time='21'),
#  Row(publish_time='2018-03-15T04:53:29.000Z', time='04'),
#  Row(publish_time='2018-04-10T16:36:47.000Z', time='16'),
#  Row(publish_time='2018-04-02T23:34:03.000Z', time='23'),
#  Row(publish_time='2017-12-31T02:13:38.000Z', time='02'),
#  Row(publish_time='2018-04-17T19:00:06.000Z', time='19'),
#  Row(publish_time='2017-12-19T21:58:38.000Z', time='21'),
#  Row(publish_time='2018-02-27T20:38:33.000Z', time='20'),
#  Row(publish_time='2017-12-01T17:00:04.000Z', time='17'),
#  Row(publish_time='2018-05-23T07:35:01.000Z', time='07'),
#  Row(publish_time='2017-12-14T15:00:05.000Z', time='15'),
#  Row(publish_time='2018-02-07T16:00:07.000Z', time='16'),
#  Row(publish_time='2017-12-06T17:00:04.000Z', time='17'),
#  Row(publish_time='2018-06-08T01:21:47.000Z', time='01'),
#  Row(publish_time='2018-03-29T23:56:56.000Z', time='23'),
#  Row(publish_time='2018-03-02T13:15:51.000Z', time='13'),
#  Row(publish_time='2017-12-27T17:26:15.000Z', time='17'),
#  Row(publish_time='2017-11-29T15:01:32.000Z', time='15'),
#  Row(publish_time='2017-12-01T09:06:02.000Z', time='09'),
#  Row(publish_time='2018-05-27T19:50:00.000Z', time='19'),
#  Row(publish_time='2018-01-23T19:00:01.000Z', time='19'),
#  Row(publish_time='2018-03-19T22:02:41.000Z', time='22'),
#  Row(publish_time='2018-04-19T10:00:00.000Z', time='10'),
#  Row(publish_time='2017-12-31T19:00:04.000Z', time='19'),
#  Row(publish_time='2017-11-29T16:15:30.000Z', time='16'),
#  Row(publish_time='2018-03-12T00:03:27.000Z', time='00'),
#  Row(publish_time='2018-05-14T20:00:01.000Z', time='20'),
#  Row(publish_time='2018-05-27T19:15:02.000Z', time='19'),
#  Row(publish_time='2018-05-23T22:18:53.000Z', time='22'),
#  Row(publish_time='2018-03-20T22:56:14.000Z', time='22'),
#  Row(publish_time='2018-01-08T03:44:08.000Z', time='03'),
#  Row(publish_time='2018-03-01T20:27:01.000Z', time='20'),
#  Row(publish_time='2018-04-04T11:10:27.000Z', time='11'),
#  Row(publish_time='2018-02-06T12:00:00.000Z', time='12'),
#  Row(publish_time='2018-03-02T08:30:01.000Z', time='08'),
#  Row(publish_time='2018-04-04T10:00:00.000Z', time='10'),
#  Row(publish_time='2018-03-20T16:20:49.000Z', time='16'),
#  Row(publish_time='2018-06-06T23:36:35.000Z', time='23'),
#  Row(publish_time='2018-01-24T12:03:34.000Z', time='12'),
#  Row(publish_time='2018-02-16T22:05:05.000Z', time='22'),
#  Row(publish_time='2018-05-17T16:47:42.000Z', time='16'),
#  Row(publish_time='2017-12-27T05:00:00.000Z', time='05'),
#  Row(publish_time='2017-12-21T13:26:00.000Z', time='13'),
#  Row(publish_time='2018-04-17T00:11:55.000Z', time='00'),
#  Row(publish_time='2017-11-22T21:09:13.000Z', time='21'),
#  Row(publish_time='2018-02-22T20:05:38.000Z', time='20'),
#  Row(publish_time='2018-01-25T17:00:04.000Z', time='17'),
#  Row(publish_time='2018-04-29T23:14:28.000Z', time='23'),
#  Row(publish_time='2018-04-27T01:00:02.000Z', time='01'),
#  Row(publish_time='2017-12-01T18:00:08.000Z', time='18'),
#  Row(publish_time='2018-02-03T16:30:02.000Z', time='16'),
#  Row(publish_time='2018-05-16T19:00:50.000Z', time='19'),
#  Row(publish_time='2017-11-17T08:27:57.000Z', time='08'),
#  Row(publish_time='2018-04-21T19:50:14.000Z', time='19'),
#  Row(publish_time='2018-04-20T04:00:03.000Z', time='04'),
#  Row(publish_time='2017-12-12T23:34:28.000Z', time='23'),
#  Row(publish_time='2018-05-06T04:22:11.000Z', time='04'),
#  Row(publish_time='2017-12-18T21:30:01.000Z', time='21'),
#  Row(publish_time='2017-12-18T17:00:03.000Z', time='17'),
#  Row(publish_time='2018-03-04T17:00:02.000Z', time='17'),
#  Row(publish_time='2018-03-11T21:14:08.000Z', time='21'),
#  Row(publish_time='2018-05-16T16:00:08.000Z', time='16'),
#  Row(publish_time='2018-03-23T15:00:05.000Z', time='15'),
#  Row(publish_time='2018-03-01T20:46:24.000Z', time='20'),
#  Row(publish_time='2018-02-02T20:00:02.000Z', time='20'),
#  Row(publish_time='2018-03-17T21:48:05.000Z', time='21'),
#  Row(publish_time='2018-02-17T20:27:32.000Z', time='20'),
#  Row(publish_time='2017-11-19T17:59:04.000Z', time='17'),
#  Row(publish_time='2018-04-23T12:09:18.000Z', time='12'),
#  Row(publish_time='2018-01-13T05:24:48.000Z', time='05'),
#  Row(publish_time='2018-03-11T19:00:03.000Z', time='19'),
#  Row(publish_time='2017-12-24T15:14:12.000Z', time='15'),
#  Row(publish_time='2018-01-12T13:36:21.000Z', time='13'),
#  Row(publish_time='2018-05-28T16:30:26.000Z', time='16'),
#  Row(publish_time='2018-04-12T13:00:05.000Z', time='13'),
#  Row(publish_time='2018-02-21T17:00:02.000Z', time='17'),
#  Row(publish_time='2018-01-23T16:10:28.000Z', time='16'),
#  Row(publish_time='2018-05-23T13:00:00.000Z', time='13'),
#  Row(publish_time='2018-02-05T00:45:18.000Z', time='00'),
#  Row(publish_time='2018-06-08T02:32:52.000Z', time='02'),
#  Row(publish_time='2018-05-01T23:39:57.000Z', time='23'),
#  Row(publish_time='2018-02-14T21:01:54.000Z', time='21'),
#  Row(publish_time='2017-11-24T08:00:03.000Z', time='08'),
#  Row(publish_time='2018-05-04T03:30:54.000Z', time='03'),
#  Row(publish_time='2017-12-31T08:09:48.000Z', time='08'),
#  Row(publish_time='2018-03-10T16:02:12.000Z', time='16'),
#  Row(publish_time='2018-02-16T12:58:49.000Z', time='12'),
#  Row(publish_time='2018-05-07T19:50:01.000Z', time='19'),
#  Row(publish_time='2018-03-20T19:29:49.000Z', time='19'),
#  Row(publish_time='2018-02-09T15:42:13.000Z', time='15'),
#  Row(publish_time='2018-04-14T23:22:17.000Z', time='23'),
#  Row(publish_time='2017-12-08T05:44:20.000Z', time='05'),
#  Row(publish_time='2018-04-13T16:51:37.000Z', time='16'),
#  Row(publish_time='2018-02-05T20:47:21.000Z', time='20'),
#  Row(publish_time='2017-12-07T17:26:47.000Z', time='17'),
#  Row(publish_time='2017-12-20T11:00:01.000Z', time='11'),
#  Row(publish_time='2018-01-16T23:11:14.000Z', time='23'),
#  Row(publish_time='2018-03-07T23:30:03.000Z', time='23'),
#  Row(publish_time='2017-12-12T11:35:43.000Z', time='11'),
#  Row(publish_time='2018-02-09T02:25:09.000Z', time='02'),
#  Row(publish_time='2018-01-02T22:00:01.000Z', time='22'),
#  Row(publish_time='2018-05-31T01:00:01.000Z', time='01'),
#  Row(publish_time='2017-11-27T02:24:54.000Z', time='02'),
#  Row(publish_time='2018-01-01T16:11:45.000Z', time='16'),
#  Row(publish_time='2018-04-14T15:00:10.000Z', time='15'),
#  Row(publish_time='2018-06-04T10:00:04.000Z', time='10'),
#  Row(publish_time='2017-12-28T15:00:03.000Z', time='15'),
#  Row(publish_time='2018-01-10T15:06:45.000Z', time='15'),
#  Row(publish_time='2018-05-02T14:57:13.000Z', time='14'),
#  Row(publish_time='2017-12-22T15:15:12.000Z', time='15'),
#  Row(publish_time='2018-05-03T15:00:01.000Z', time='15'),
#  Row(publish_time='2018-01-20T20:39:35.000Z', time='20'),
#  Row(publish_time='2018-05-24T21:24:46.000Z', time='21'),
#  Row(publish_time='2018-01-23T14:53:48.000Z', time='14'),
#  Row(publish_time='2018-03-31T21:00:04.000Z', time='21'),
#  Row(publish_time='2018-06-10T20:34:26.000Z', time='20'),
#  Row(publish_time='2018-04-04T05:16:12.000Z', time='05'),
#  Row(publish_time='2017-12-04T11:06:33.000Z', time='11'),
#  Row(publish_time='2017-11-21T01:21:12.000Z', time='01'),
#  Row(publish_time='2017-12-25T18:28:32.000Z', time='18'),
#  Row(publish_time='2018-04-02T23:36:58.000Z', time='23'),
#  Row(publish_time='2017-12-09T16:12:57.000Z', time='16'),
#  Row(publish_time='2018-03-15T20:35:19.000Z', time='20'),
#  Row(publish_time='2017-12-21T05:25:00.000Z', time='05'),
#  Row(publish_time='2018-02-08T14:00:00.000Z', time='14'),
#  Row(publish_time='2018-03-06T17:00:01.000Z', time='17'),
#  Row(publish_time='2018-04-20T15:59:21.000Z', time='15'),
#  Row(publish_time='2018-05-03T11:00:09.000Z', time='11'),
#  Row(publish_time='2018-01-26T20:42:49.000Z', time='20'),
#  Row(publish_time='2018-03-19T05:30:44.000Z', time='05'),
#  Row(publish_time='2018-02-17T19:58:46.000Z', time='19'),
#  Row(publish_time='2018-06-09T18:07:15.000Z', time='18'),
#  Row(publish_time='2018-01-11T05:00:01.000Z', time='05'),
#  Row(publish_time='2018-01-02T23:38:39.000Z', time='23'),
#  Row(publish_time='2018-05-25T16:40:27.000Z', time='16'),
#  Row(publish_time='2018-01-16T22:14:37.000Z', time='22'),
#  Row(publish_time='2018-05-01T15:57:06.000Z', time='15'),
#  Row(publish_time='2018-05-06T17:27:32.000Z', time='17'),
#  Row(publish_time='2018-01-17T00:57:04.000Z', time='00'),
#  Row(publish_time='2018-06-03T18:25:05.000Z', time='18'),
#  Row(publish_time='2018-04-24T03:06:25.000Z', time='03'),
#  Row(publish_time='2017-11-17T10:22:48.000Z', time='10'),
#  Row(publish_time='2017-12-03T02:41:59.000Z', time='02'),
#  Row(publish_time='2018-02-25T01:33:22.000Z', time='01'),
#  Row(publish_time='2017-12-11T01:00:00.000Z', time='01'),
#  Row(publish_time='2018-02-08T18:00:08.000Z', time='18'),
#  Row(publish_time='2018-02-15T14:33:27.000Z', time='14'),
#  Row(publish_time='2012-12-31T23:14:54.000Z', time='23'),
#  Row(publish_time='2017-11-26T06:58:29.000Z', time='06'),
#  Row(publish_time='2018-03-15T16:40:40.000Z', time='16'),
#  Row(publish_time='2018-02-19T16:29:12.000Z', time='16'),
#  Row(publish_time='2018-04-05T21:54:36.000Z', time='21'),
#  Row(publish_time='2018-01-11T03:00:00.000Z', time='03'),
#  Row(publish_time='2018-02-22T13:05:17.000Z', time='13'),
#  Row(publish_time='2017-11-28T05:00:01.000Z', time='05'),
#  Row(publish_time='2017-12-02T14:30:03.000Z', time='14'),
#  Row(publish_time='2018-03-11T02:33:47.000Z', time='02'),
#  Row(publish_time='2017-12-02T06:12:54.000Z', time='06'),
#  Row(publish_time='2018-06-09T15:31:50.000Z', time='15'),
#  Row(publish_time='2017-11-24T22:00:01.000Z', time='22'),
#  Row(publish_time='2018-04-30T13:44:09.000Z', time='13'),
#  Row(publish_time='2018-05-03T15:45:01.000Z', time='15'),
#  Row(publish_time='2017-12-18T16:13:02.000Z', time='16'),
#  Row(publish_time='2018-03-14T22:00:08.000Z', time='22'),
#  Row(publish_time='2018-03-19T00:05:14.000Z', time='00'),
#  Row(publish_time='2018-03-02T00:11:58.000Z', time='00'),
#  Row(publish_time='2017-12-02T16:00:00.000Z', time='16'),
#  Row(publish_time='2018-03-22T15:00:01.000Z', time='15'),
#  Row(publish_time='2018-04-17T19:00:03.000Z', time='19'),
#  Row(publish_time='2018-01-11T22:06:18.000Z', time='22'),
#  Row(publish_time='2017-11-26T18:38:32.000Z', time='18'),
#  Row(publish_time='2018-01-01T00:38:41.000Z', time='00'),
#  Row(publish_time='2018-05-21T17:15:45.000Z', time='17'),
#  Row(publish_time='2018-05-07T09:57:01.000Z', time='09'),
#  Row(publish_time='2018-01-15T13:14:20.000Z', time='13'),
#  Row(publish_time='2018-04-24T15:23:10.000Z', time='15'),
#  Row(publish_time='2018-03-03T09:28:09.000Z', time='09'),
#  Row(publish_time='2017-11-20T12:54:30.000Z', time='12'),
#  Row(publish_time='2018-01-23T18:45:44.000Z', time='18'),
#  Row(publish_time='2018-05-04T16:00:02.000Z', time='16'),
#  Row(publish_time='2018-06-10T21:07:19.000Z', time='21'),
#  Row(publish_time='2017-11-30T17:16:46.000Z', time='17'),
#  Row(publish_time='2017-12-30T02:11:49.000Z', time='02'),
#  Row(publish_time='2017-11-25T16:15:56.000Z', time='16'),
#  Row(publish_time='2018-05-10T10:30:00.000Z', time='10'),
#  Row(publish_time='2017-12-09T12:02:53.000Z', time='12'),
#  Row(publish_time='2018-05-24T16:00:06.000Z', time='16'),
#  Row(publish_time='2017-12-30T18:12:37.000Z', time='18'),
#  Row(publish_time='2017-11-23T22:00:03.000Z', time='22'),
#  Row(publish_time='2018-02-25T23:15:49.000Z', time='23'),
#  Row(publish_time='2017-12-28T13:42:53.000Z', time='13'),
#  Row(publish_time='2018-05-15T02:18:13.000Z', time='02'),
#  Row(publish_time='2018-06-04T20:00:00.000Z', time='20'),
#  Row(publish_time='2017-11-18T16:14:36.000Z', time='16'),
#  Row(publish_time='2018-01-02T16:20:29.000Z', time='16'),
#  Row(publish_time='2017-11-17T17:00:03.000Z', time='17'),
#  Row(publish_time='2018-02-09T16:40:55.000Z', time='16'),
#  Row(publish_time='2018-03-19T07:01:12.000Z', time='07'),
#  Row(publish_time='2018-02-04T16:31:37.000Z', time='16'),
#  Row(publish_time='2018-05-04T23:14:58.000Z', time='23'),
#  Row(publish_time='2017-12-09T16:07:54.000Z', time='16'),
#  Row(publish_time='2018-01-13T07:32:50.000Z', time='07'),
#  Row(publish_time='2018-05-04T15:00:05.000Z', time='15'),
#  Row(publish_time='2018-05-22T19:38:14.000Z', time='19'),
#  Row(publish_time='2018-01-29T05:04:08.000Z', time='05'),
#  Row(publish_time='2018-03-02T11:00:04.000Z', time='11'),
#  Row(publish_time='2018-05-11T19:00:01.000Z', time='19'),
#  Row(publish_time='2017-12-10T00:41:36.000Z', time='00'),
#  Row(publish_time='2018-04-06T10:00:04.000Z', time='10'),
#  Row(publish_time='2018-01-11T16:38:59.000Z', time='16'),
#  Row(publish_time='2017-11-14T16:32:12.000Z', time='16'),
#  Row(publish_time='2018-04-22T13:11:37.000Z', time='13'),
#  Row(publish_time='2018-05-08T18:59:34.000Z', time='18'),
#  Row(publish_time='2018-03-30T06:12:17.000Z', time='06'),
#  Row(publish_time='2018-01-27T03:56:18.000Z', time='03'),
#  Row(publish_time='2018-02-27T16:10:12.000Z', time='16'),
#  Row(publish_time='2017-12-23T13:10:27.000Z', time='13'),
#  Row(publish_time='2018-05-16T18:27:03.000Z', time='18'),
#  Row(publish_time='2018-01-19T17:00:03.000Z', time='17'),
#  Row(publish_time='2018-05-10T15:11:28.000Z', time='15'),
#  Row(publish_time='2018-02-04T22:31:51.000Z', time='22'),
#  Row(publish_time='2018-02-04T22:18:59.000Z', time='22'),
#  Row(publish_time='2018-06-01T03:57:43.000Z', time='03'),
#  Row(publish_time='2017-11-19T18:00:03.000Z', time='18'),
#  Row(publish_time='2018-03-31T08:54:44.000Z', time='08'),
#  Row(publish_time='2018-01-08T15:00:04.000Z', time='15'),
#  Row(publish_time='2017-11-29T19:58:51.000Z', time='19'),
#  Row(publish_time='2018-02-16T00:22:53.000Z', time='00'),
#  Row(publish_time='2018-02-13T23:16:14.000Z', time='23'),
#  Row(publish_time='2018-03-24T17:30:00.000Z', time='17'),
#  Row(publish_time='2018-02-27T14:00:31.000Z', time='14'),
#  Row(publish_time='2018-01-29T22:19:34.000Z', time='22'),
#  Row(publish_time='2017-11-23T20:04:44.000Z', time='20'),
#  Row(publish_time='2018-02-02T13:00:09.000Z', time='13'),
#  Row(publish_time='2018-03-19T08:25:45.000Z', time='08'),
#  Row(publish_time='2018-02-04T16:38:40.000Z', time='16')]

# %%
pubTime = spark.sql("SELECT publish_time as pub from df")\
               .rdd.flatMap(lambda x: x).map(lambda x: (x,x[11:13]))
pubTimeSchema = StructType([StructField("publish_time", StringType(), True),\
                            StructField("time", StringType(), True)])
pubTimeDF = spark.createDataFrame(pubTime, pubTimeSchema)
pubTimeDF = pubTimeDF.filter(pubTimeDF["time"]!='')
pubTimeDF.createOrReplaceTempView("pubTimeDF")
time_distribution = spark.sql("SELECT time, COUNT(*) as freq FROM pubTimeDF\
                               GROUP BY time, time ORDER BY freq DESC")
time_distribution.show()
# Out:
# +----+----+
# |time|freq|
# +----+----+
# |  16|3988|
# |  17|3206|
# |  15|2679|
# |  19|2595|
# |  20|2595|
# |  18|2346|
# |  21|2330|
# |  22|2284|
# |  14|2194|
# |  13|1730|
# |  23|1698|
# |  01|1441|
# |  12|1361|
# |  04|1325|
# |  03|1324|
# |  02|1314|
# |  00|1265|
# |  05|1062|
# |  11|1023|
# |  08| 690|
# +----+----+
# only showing top 20 rows
